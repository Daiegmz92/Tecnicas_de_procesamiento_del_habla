# %% [markdown]
# ## Pipeline con spacy

# %% [markdown]
# watermark nos da la informacion de las librerias con las que trabajamos.

# %%
# !pip install spacy watermark - q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 24.5 MB/s eta 0:00:00

# %%
# !python -m spacy download es_core_news_lg -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 568.0/568.0 MB 3.2 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy
from spacy import displacy

# %%
# Pipeline de spacy

# cargar el modelo

nlp =spacy.load("es_core_news_lg")
import es_core_news_lg
nlp = es_core_news_lg.load()

# %%
texto_ejemplo = "Reyes Católicos fue la denominación que recibieron los esposos Isabel I de Castilla (1451-1504) y Fernando II de Aragón (1452-1516), monarcas de la Corona de Castilla y de la Corona de Aragón, respectivamente, cuyo matrimonio implicó la unión dinástica de sus reinos y marcó el inicio de la formación territorial de España. Asimismo, Isabel y Fernando fueron los primeros monarcas de Castilla y Aragón en ser llamados «reyes de España»."

# %%
# procesar el texto

doc = nlp(texto_ejemplo) #tokenizacion

# %%
tokens = [token.text for token in doc]
print(tokens)
# Out:
# ['Reyes', 'Católicos', 'fue', 'la', 'denominación', 'que', 'recibieron', 'los', 'esposos', 'Isabel', 'I', 'de', 'Castilla', '(', '1451-1504', ')', 'y', 'Fernando', 'II', 'de', 'Aragón', '(', '1452-1516', ')', ',', 'monarcas', 'de', 'la', 'Corona', 'de', 'Castilla', 'y', 'de', 'la', 'Corona', 'de', 'Aragón', ',', 'respectivamente', ',', 'cuyo', 'matrimonio', 'implicó', 'la', 'unión', 'dinástica', 'de', 'sus', 'reinos', 'y', 'marcó', 'el', 'inicio', 'de', 'la', 'formación', 'territorial', 'de', 'España', '.', 'Asimismo', ',', 'Isabel', 'y', 'Fernando', 'fueron', 'los', 'primeros', 'monarcas', 'de', 'Castilla', 'y', 'Aragón', 'en', 'ser', 'llamados', '«', 'reyes', 'de', 'España', '»', '.']

# %%
# Lematizacion: forma base (raiz) de cada token
for token in doc:
  #ignoramos puntuacion y espacios para mayor claridad
  if not token.is_punct and not token.is_space:
    print(f"{token.text}, {token.lemma_}")
# Out:
# Reyes, Reyes
# Católicos, Católicos
# fue, ser
# la, el
# denominación, denominación
# que, que
# recibieron, recibir
# los, el
# esposos, esposo
# Isabel, Isabel
# I, I
# de, de
# Castilla, Castilla
# 1451-1504, 1451-1504
# y, y
# Fernando, Fernando
# II, II
# de, de
# Aragón, Aragón
# 1452-1516, 1452-1516
# monarcas, monarca
# de, de
# la, el
# Corona, Corona
# de, de
# Castilla, Castilla
# y, y
# de, de
# la, el
# Corona, Corona
# de, de
# Aragón, Aragón
# respectivamente, respectivamente
# cuyo, cuyo
# matrimonio, matrimonio
# implicó, implicar
# la, el
# unión, unión
# dinástica, dinástico
# de, de
# sus, su
# reinos, reino
# y, y
# marcó, marcar
# el, el
# inicio, inicio
# de, de
# la, el
# formación, formación
# territorial, territorial
# de, de
# España, España
# Asimismo, asimismo
# Isabel, Isabel
# y, y
# Fernando, Fernando
# fueron, ser
# los, el
# primeros, primero
# monarcas, monarca
# de, de
# Castilla, Castilla
# y, y
# Aragón, Aragón
# en, en
# ser, ser
# llamados, llamar
# reyes, rey
# de, de
# España, España

# %%
# Etiquetado gramatical
for token in doc:
    if not token.is_space: # Ignoramos espacios
        print(f"'{token.text}' -> {token.pos_} ({spacy.explain(token.pos_)}) -> {token.tag_}")
# Out:
# 'Isabel' -> PROPN (proper noun) -> PROPN
# 'accedió' -> VERB (verb) -> VERB
# 'al' -> ADP (adposition) -> ADP
# 'trono' -> NOUN (noun) -> NOUN
# 'castellano' -> ADJ (adjective) -> ADJ
# 'en' -> ADP (adposition) -> ADP
# '1474' -> NOUN (noun) -> NOUN
# 'al' -> ADP (adposition) -> ADP
# 'autoproclamarse' -> VERB (verb) -> VERB
# 'reina' -> NOUN (noun) -> NOUN
# 'tras' -> ADP (adposition) -> ADP
# 'la' -> DET (determiner) -> DET
# 'muerte' -> NOUN (noun) -> NOUN
# 'de' -> ADP (adposition) -> ADP
# 'su' -> DET (determiner) -> DET
# 'hermano' -> NOUN (noun) -> NOUN
# 'el' -> DET (determiner) -> DET
# 'rey' -> NOUN (noun) -> NOUN
# 'Enrique' -> PROPN (proper noun) -> PROPN
# 'IV' -> PROPN (proper noun) -> PROPN
# 'de' -> ADP (adposition) -> ADP
# 'Castilla' -> PROPN (proper noun) -> PROPN
# 'y' -> CCONJ (coordinating conjunction) -> CCONJ
# 'con' -> ADP (adposition) -> ADP
# 'ello' -> PRON (pronoun) -> PRON
# 'provocar' -> VERB (verb) -> VERB
# 'una' -> DET (determiner) -> DET
# 'guerra' -> NOUN (noun) -> NOUN
# 'de' -> ADP (adposition) -> ADP
# 'sucesión' -> NOUN (noun) -> NOUN
# '(' -> PUNCT (punctuation) -> PUNCT
# '1475-1479' -> NOUN (noun) -> NOUN
# ')' -> PUNCT (punctuation) -> PUNCT
# 'contra' -> ADP (adposition) -> ADP
# 'los' -> DET (determiner) -> DET
# 'partidarios' -> NOUN (noun) -> NOUN
# 'de' -> ADP (adposition) -> ADP
# 'la' -> DET (determiner) -> DET
# 'princesa' -> NOUN (noun) -> NOUN
# 'Juana' -> PROPN (proper noun) -> PROPN
# ',' -> PUNCT (punctuation) -> PUNCT
# 'hija' -> NOUN (noun) -> NOUN
# 'del' -> ADP (adposition) -> ADP
# 'rey' -> NOUN (noun) -> NOUN
# 'Enrique' -> PROPN (proper noun) -> PROPN
# '.' -> PUNCT (punctuation) -> PUNCT
# 'En' -> ADP (adposition) -> ADP
# '1479' -> NOUN (noun) -> NOUN
# 'Fernando' -> PROPN (proper noun) -> PROPN
# 'heredó' -> VERB (verb) -> VERB
# 'el' -> DET (determiner) -> DET
# 'trono' -> NOUN (noun) -> NOUN
# 'de' -> ADP (adposition) -> ADP
# 'Aragón' -> PROPN (proper noun) -> PROPN
# 'al' -> ADP (adposition) -> ADP
# 'morir' -> VERB (verb) -> VERB
# 'su' -> DET (determiner) -> DET
# 'padre' -> NOUN (noun) -> NOUN
# ',' -> PUNCT (punctuation) -> PUNCT
# 'el' -> DET (determiner) -> DET
# 'rey' -> NOUN (noun) -> NOUN
# 'Juan' -> PROPN (proper noun) -> PROPN
# 'II' -> PROPN (proper noun) -> PROPN
# 'de' -> ADP (adposition) -> ADP
# 'Aragón' -> PROPN (proper noun) -> PROPN
# '.' -> PUNCT (punctuation) -> PUNCT
# 'Isabel' -> PROPN (proper noun) -> PROPN
# 'y' -> CCONJ (coordinating conjunction) -> CCONJ
# 'Fernando' -> PROPN (proper noun) -> PROPN
# 'reinaron' -> VERB (verb) -> VERB
# 'juntos' -> ADJ (adjective) -> ADJ
# 'hasta' -> ADP (adposition) -> ADP
# 'la' -> DET (determiner) -> DET
# 'muerte' -> NOUN (noun) -> NOUN
# 'de' -> ADP (adposition) -> ADP
# 'ella' -> PRON (pronoun) -> PRON
# 'en' -> ADP (adposition) -> ADP
# '1504' -> NOUN (noun) -> NOUN
# '.' -> PUNCT (punctuation) -> PUNCT
# 'Entonces' -> ADV (adverb) -> ADV
# 'Fernando' -> PROPN (proper noun) -> PROPN
# 'quedó' -> VERB (verb) -> VERB
# 'únicamente' -> ADV (adverb) -> ADV
# 'como' -> SCONJ (subordinating conjunction) -> SCONJ
# 'rey' -> NOUN (noun) -> NOUN
# 'de' -> ADP (adposition) -> ADP
# 'la' -> DET (determiner) -> DET
# 'Corona' -> PROPN (proper noun) -> PROPN
# 'de' -> ADP (adposition) -> ADP
# 'Aragón' -> PROPN (proper noun) -> PROPN
# ',' -> PUNCT (punctuation) -> PUNCT
# 'pasando' -> VERB (verb) -> VERB
# 'Castilla' -> PROPN (proper noun) -> PROPN
# 'a' -> ADP (adposition) -> ADP
# 'su' -> DET (determiner) -> DET
# 'hija' -> NOUN (noun) -> NOUN
# 'Juana' -> PROPN (proper noun) -> PROPN
# 'y' -> CCONJ (coordinating conjunction) -> CCONJ
# 'al' -> ADP (adposition) -> ADP
# 'marido' -> NOUN (noun) -> NOUN
# 'de' -> ADP (adposition) -> ADP
# 'esta' -> PRON (pronoun) -> PRON
# ',' -> PUNCT (punctuation) -> PUNCT
# 'Felipe' -> PROPN (proper noun) -> PROPN
# 'de' -> ADP (adposition) -> ADP
# 'Habsburgo' -> PROPN (proper noun) -> PROPN
# '.' -> PUNCT (punctuation) -> PUNCT
# 'Sin' -> ADP (adposition) -> ADP
# 'embargo' -> NOUN (noun) -> NOUN
# ',' -> PUNCT (punctuation) -> PUNCT
# 'Fernando' -> PROPN (proper noun) -> PROPN
# 'no' -> ADV (adverb) -> ADV
# 'renunció' -> VERB (verb) -> VERB
# 'a' -> ADP (adposition) -> ADP
# 'controlar' -> VERB (verb) -> VERB
# 'Castilla' -> PROPN (proper noun) -> PROPN
# ':' -> PUNCT (punctuation) -> PUNCT
# 'tras' -> ADP (adposition) -> ADP
# 'morir' -> VERB (verb) -> VERB
# 'Felipe' -> PROPN (proper noun) -> PROPN
# 'en' -> ADP (adposition) -> ADP
# '1506' -> NOUN (noun) -> NOUN
# ',' -> PUNCT (punctuation) -> PUNCT
# 'Juana' -> PROPN (proper noun) -> PROPN
# 'fue' -> AUX (auxiliary) -> AUX
# 'declarada' -> VERB (verb) -> VERB
# 'incapaz' -> ADJ (adjective) -> ADJ
# ',' -> PUNCT (punctuation) -> PUNCT
# 'y' -> CCONJ (coordinating conjunction) -> CCONJ
# 'Fernando' -> PROPN (proper noun) -> PROPN
# 'consiguió' -> VERB (verb) -> VERB
# 'ser' -> AUX (auxiliary) -> AUX
# 'nombrado' -> VERB (verb) -> VERB
# 'regente' -> NOUN (noun) -> NOUN
# 'del' -> ADP (adposition) -> ADP
# 'reino' -> NOUN (noun) -> NOUN
# 'hasta' -> ADP (adposition) -> ADP
# 'su' -> DET (determiner) -> DET
# 'muerte' -> NOUN (noun) -> NOUN
# 'en' -> ADP (adposition) -> ADP
# '1516' -> NOUN (noun) -> NOUN
# '.' -> PUNCT (punctuation) -> PUNCT

# %%
# Analisis de dependencia sintactica
for token in doc:
     if not token.is_space:
        print(f"'{token.text}' -> {token.dep_} ({spacy.explain(token.dep_)}) -> '{token.head.text}'")
# Out:
# 'Isabel' -> nsubj (nominal subject) -> 'accedió'
# 'accedió' -> ROOT (root) -> 'accedió'
# 'al' -> case (case marking) -> 'trono'
# 'trono' -> obl (oblique nominal) -> 'accedió'
# 'castellano' -> amod (adjectival modifier) -> 'trono'
# 'en' -> case (case marking) -> '1474'
# '1474' -> obl (oblique nominal) -> 'accedió'
# 'al' -> case (case marking) -> 'autoproclamarse'
# 'autoproclamarse' -> advcl (adverbial clause modifier) -> 'accedió'
# 'reina' -> obj (object) -> 'autoproclamarse'
# 'tras' -> case (case marking) -> 'muerte'
# 'la' -> det (determiner) -> 'muerte'
# 'muerte' -> obl (oblique nominal) -> 'autoproclamarse'
# 'de' -> case (case marking) -> 'hermano'
# 'su' -> det (determiner) -> 'hermano'
# 'hermano' -> nmod (modifier of nominal) -> 'muerte'
# 'el' -> det (determiner) -> 'rey'
# 'rey' -> appos (appositional modifier) -> 'muerte'
# 'Enrique' -> appos (appositional modifier) -> 'rey'
# 'IV' -> flat (flat multiword expression) -> 'Enrique'
# 'de' -> case (case marking) -> 'Castilla'
# 'Castilla' -> nmod (modifier of nominal) -> 'rey'
# 'y' -> cc (coordinating conjunction) -> 'provocar'
# 'con' -> case (case marking) -> 'ello'
# 'ello' -> obl (oblique nominal) -> 'provocar'
# 'provocar' -> conj (conjunct) -> 'accedió'
# 'una' -> det (determiner) -> 'guerra'
# 'guerra' -> obj (object) -> 'provocar'
# 'de' -> case (case marking) -> 'sucesión'
# 'sucesión' -> nmod (modifier of nominal) -> 'guerra'
# '(' -> punct (punctuation) -> '1475-1479'
# '1475-1479' -> appos (appositional modifier) -> 'guerra'
# ')' -> punct (punctuation) -> '1475-1479'
# 'contra' -> case (case marking) -> 'partidarios'
# 'los' -> det (determiner) -> 'partidarios'
# 'partidarios' -> nmod (modifier of nominal) -> 'guerra'
# 'de' -> case (case marking) -> 'princesa'
# 'la' -> det (determiner) -> 'princesa'
# 'princesa' -> nmod (modifier of nominal) -> 'partidarios'
# 'Juana' -> appos (appositional modifier) -> 'princesa'
# ',' -> punct (punctuation) -> 'hija'
# 'hija' -> appos (appositional modifier) -> 'princesa'
# 'del' -> case (case marking) -> 'rey'
# 'rey' -> nmod (modifier of nominal) -> 'hija'
# 'Enrique' -> appos (appositional modifier) -> 'rey'
# '.' -> punct (punctuation) -> 'accedió'
# 'En' -> case (case marking) -> '1479'
# '1479' -> obl (oblique nominal) -> 'heredó'
# 'Fernando' -> nsubj (nominal subject) -> 'heredó'
# 'heredó' -> ROOT (root) -> 'heredó'
# 'el' -> det (determiner) -> 'trono'
# 'trono' -> obj (object) -> 'heredó'
# 'de' -> case (case marking) -> 'Aragón'
# 'Aragón' -> nmod (modifier of nominal) -> 'trono'
# 'al' -> case (case marking) -> 'morir'
# 'morir' -> advcl (adverbial clause modifier) -> 'heredó'
# 'su' -> det (determiner) -> 'padre'
# 'padre' -> nsubj (nominal subject) -> 'morir'
# ',' -> punct (punctuation) -> 'rey'
# 'el' -> det (determiner) -> 'rey'
# 'rey' -> appos (appositional modifier) -> 'padre'
# 'Juan' -> appos (appositional modifier) -> 'rey'
# 'II' -> flat (flat multiword expression) -> 'Juan'
# 'de' -> case (case marking) -> 'Aragón'
# 'Aragón' -> flat (flat multiword expression) -> 'Juan'
# '.' -> punct (punctuation) -> 'heredó'
# 'Isabel' -> nsubj (nominal subject) -> 'reinaron'
# 'y' -> cc (coordinating conjunction) -> 'Fernando'
# 'Fernando' -> conj (conjunct) -> 'Isabel'
# 'reinaron' -> ROOT (root) -> 'reinaron'
# 'juntos' -> obj (object) -> 'reinaron'
# 'hasta' -> case (case marking) -> 'muerte'
# 'la' -> det (determiner) -> 'muerte'
# 'muerte' -> obl (oblique nominal) -> 'reinaron'
# 'de' -> case (case marking) -> 'ella'
# 'ella' -> nmod (modifier of nominal) -> 'muerte'
# 'en' -> case (case marking) -> '1504'
# '1504' -> obl (oblique nominal) -> 'reinaron'
# '.' -> punct (punctuation) -> 'reinaron'
# 'Entonces' -> advmod (adverbial modifier) -> 'quedó'
# 'Fernando' -> nsubj (nominal subject) -> 'quedó'
# 'quedó' -> ROOT (root) -> 'quedó'
# 'únicamente' -> advmod (adverbial modifier) -> 'quedó'
# 'como' -> mark (marker) -> 'rey'
# 'rey' -> obl (oblique nominal) -> 'quedó'
# 'de' -> case (case marking) -> 'Corona'
# 'la' -> det (determiner) -> 'Corona'
# 'Corona' -> nmod (modifier of nominal) -> 'rey'
# 'de' -> case (case marking) -> 'Aragón'
# 'Aragón' -> flat (flat multiword expression) -> 'Corona'
# ',' -> punct (punctuation) -> 'pasando'
# 'pasando' -> advcl (adverbial clause modifier) -> 'quedó'
# 'Castilla' -> obj (object) -> 'pasando'
# 'a' -> case (case marking) -> 'hija'
# 'su' -> det (determiner) -> 'hija'
# 'hija' -> obj (object) -> 'pasando'
# 'Juana' -> appos (appositional modifier) -> 'hija'
# 'y' -> cc (coordinating conjunction) -> 'marido'
# 'al' -> case (case marking) -> 'marido'
# 'marido' -> conj (conjunct) -> 'hija'
# 'de' -> case (case marking) -> 'esta'
# 'esta' -> nmod (modifier of nominal) -> 'marido'
# ',' -> punct (punctuation) -> 'Felipe'
# 'Felipe' -> obj (object) -> 'quedó'
# 'de' -> case (case marking) -> 'Habsburgo'
# 'Habsburgo' -> flat (flat multiword expression) -> 'Felipe'
# '.' -> punct (punctuation) -> 'quedó'
# 'Sin' -> advmod (adverbial modifier) -> 'renunció'
# 'embargo' -> fixed (fixed multiword expression) -> 'Sin'
# ',' -> punct (punctuation) -> 'Sin'
# 'Fernando' -> nsubj (nominal subject) -> 'renunció'
# 'no' -> advmod (adverbial modifier) -> 'renunció'
# 'renunció' -> ROOT (root) -> 'renunció'
# 'a' -> mark (marker) -> 'controlar'
# 'controlar' -> xcomp (open clausal complement) -> 'renunció'
# 'Castilla' -> obj (object) -> 'controlar'
# ':' -> punct (punctuation) -> 'morir'
# 'tras' -> mark (marker) -> 'morir'
# 'morir' -> advcl (adverbial clause modifier) -> 'declarada'
# 'Felipe' -> nsubj (nominal subject) -> 'morir'
# 'en' -> case (case marking) -> '1506'
# '1506' -> obl (oblique nominal) -> 'morir'
# ',' -> punct (punctuation) -> 'morir'
# 'Juana' -> nsubj (nominal subject) -> 'declarada'
# 'fue' -> aux (auxiliary) -> 'declarada'
# 'declarada' -> advcl (adverbial clause modifier) -> 'renunció'
# 'incapaz' -> obj (object) -> 'declarada'
# ',' -> punct (punctuation) -> 'consiguió'
# 'y' -> cc (coordinating conjunction) -> 'consiguió'
# 'Fernando' -> nsubj (nominal subject) -> 'consiguió'
# 'consiguió' -> conj (conjunct) -> 'declarada'
# 'ser' -> aux (auxiliary) -> 'nombrado'
# 'nombrado' -> ccomp (clausal complement) -> 'consiguió'
# 'regente' -> obj (object) -> 'nombrado'
# 'del' -> case (case marking) -> 'reino'
# 'reino' -> nmod (modifier of nominal) -> 'regente'
# 'hasta' -> case (case marking) -> 'muerte'
# 'su' -> det (determiner) -> 'muerte'
# 'muerte' -> obl (oblique nominal) -> 'nombrado'
# 'en' -> case (case marking) -> '1516'
# '1516' -> nmod (modifier of nominal) -> 'muerte'
# '.' -> punct (punctuation) -> 'renunció'

# %%
displacy.render(doc, style ="dep", jupyter=True, options={"distance": 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="es" id="f41f1092fb0248a3874467e6de38abb2-0" class="displacy" width="8450" height="497.0" direction="ltr" style="max-width: none; height: 497.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Reyes</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">Católicos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">fue</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">la</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">denominación</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">que</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">recibieron</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">los</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">esposos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">Isabel</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">Castilla (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">1451-1504)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">y</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">Fernando</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">II</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">Aragón (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">1452-1516),</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">monarcas</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">la</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2810">Corona</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2810">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2930">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2930">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">Castilla</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="3170">y</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3170">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="3290">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3290">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="3410">la</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3410">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="3530">Corona</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3530">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill

# %%
# Entidades nombradas

if doc.ents:
  print("Entidades encontradas:")
  print("texto de la entidad ... Etiqueta (tipo)")
  for ent in doc.ents:
    print(f"{ent.text} --- {ent.label_} --- {spacy.explain(ent.label_)}")
else:
  print("No se encontraron entidades nombradas")
# Out:
# Entidades encontradas:
# texto de la entidad ... Etiqueta (tipo)
# Reyes Católicos --- PER --- Named person or family.
# Isabel I de Castilla --- PER --- Named person or family.
# Fernando II de Aragón --- PER --- Named person or family.
# Corona de Castilla --- PER --- Named person or family.
# Corona de Aragón --- PER --- Named person or family.
# España --- LOC --- Non-GPE locations, mountain ranges, bodies of water
# Isabel --- PER --- Named person or family.
# Fernando --- PER --- Named person or family.
# Castilla y --- LOC --- Non-GPE locations, mountain ranges, bodies of water
# Aragón --- LOC --- Non-GPE locations, mountain ranges, bodies of water
# España --- LOC --- Non-GPE locations, mountain ranges, bodies of water

# %%
displacy.render(doc, style="ent", jupyter=True, options={"distance": 200})
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reyes Católicos
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  fue la denominación que recibieron los esposos
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Isabel I de Castilla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  (1451-1504) y
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fernando II de Aragón
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  (1452-1516), monarcas de la
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Corona de Castilla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  y de la
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Corona de Aragón
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , respectivamente, cuyo matrimonio implicó la unión dinástica de sus reinos y marcó el inicio de la formación territorial de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     España
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# . Asimismo,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Isabel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  y
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fernando
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  fueron los primeros monarcas de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Castilla y
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Aragón
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  en ser llamados «reyes de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     España
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ».</div></span>

# %% [markdown]
# ## Ejemplo practico

# %%
from collections import Counter

# %%
texto = "Isabel accedió al trono castellano en 1474 al autoproclamarse reina tras la muerte de su hermano el rey Enrique IV de Castilla y con ello provocar una guerra de sucesión (1475-1479) contra los partidarios de la princesa Juana, hija del rey Enrique. En 1479 Fernando heredó el trono de Aragón al morir su padre, el rey Juan II de Aragón. Isabel y Fernando reinaron juntos hasta la muerte de ella en 1504. Entonces Fernando quedó únicamente como rey de la Corona de Aragón, pasando Castilla a su hija Juana y al marido de esta, Felipe de Habsburgo. Sin embargo, Fernando no renunció a controlar Castilla: tras morir Felipe en 1506, Juana fue declarada incapaz, y Fernando consiguió ser nombrado regente del reino hasta su muerte en 1516."

# %%
print(f"""{texto[:150]}...""") #muestra un fragmento
# Out:
# Isabel accedió al trono castellano en 1474 al autoproclamarse reina tras la muerte de su hermano el rey Enrique IV de Castilla y con ello provocar una...

# %%
doc = nlp(texto)
print("!texto procesado!")
# Out:
# !texto procesado!

# %%
palabras_clave = []

# %%
for token in doc:
  if token.is_alpha and not token.is_stop:
    #normalizacion: obtener lema y convertir en minusculas
    palabras_clave.append(token.lemma_.lower())

print(f"se extrajeron {len(palabras_clave)} palabras clave (lemas, sin stop words)")
# Out:
# se extrajeron 126 palabras clave (lemas, sin stop words)

# %%
frecuencia_palabras = Counter(palabras_clave)

# %%
N = 15
palabras_mas_comunes = frecuencia_palabras.most_common(N)

# %%
for palabra, frecuencia in palabras_mas_comunes:
    print(f"- '{palabra}' : {frecuencia}")
# Out:
# - 'fernando' : 10
# - 'rey' : 8
# - 'muerte' : 6
# - 'castilla' : 6
# - 'juana' : 6
# - 'aragón' : 6
# - 'isabel' : 4
# - 'trono' : 4
# - 'enrique' : 4
# - 'hija' : 4
# - 'morir' : 4
# - 'felipe' : 4
# - 'acceder' : 2
# - 'castellano' : 2
# - 'autoproclamar él' : 2

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
wordcloud_generator = WordCloud(
    width=800,
    height=400,
    background_color='white',
    colormap='viridis', # Paleta de colores
    max_words=50,      # Mostrar máximo 50 palabras
    stopwords=None,    # Ya filtramos stop words antes
    collocations=False # Evitar que agrupe palabras (ej. "dióxido carbono")
                       # Si se quisiera, sería mejor hacerlo antes con Spacy/N-gramas
).generate_from_frequencies(frecuencia_palabras) # <-- Usar las frecuencias calculadas

# %%
plt.figure(figsize=(10, 5)) # Tamaño de la figura donde se mostrará
plt.imshow(wordcloud_generator, interpolation='bilinear') # Mostrar la imagen generada
plt.axis("off") # No mostrar los ejes X e Y
plt.tight_layout(pad=0) # Ajustar para que no haya bordes extra
plt.show() # <-- ¡Mostrar la ventana con la nube!

# %% [markdown]
# ## Consigna 1

# %% [markdown]
# Hacer un webscraping de una pagina simple.
# limpiar texto y convertir en objeto spacy.
# nube de palabras.

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.1.31)

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
url = "https://www.perfil.com/noticias/reperfilar/una-mujer-cuadriplejica-volvio-a-hablar-tras-18-anos-gracias-a-la-inteligencia-artificial.phtml"

# %%
contenido = requests.get(url).text

# %%
print(contenido)
# Out:
# <!DOCTYPE html>
#
# <html lang="es">
#     <head>
#         <meta charset="utf-8">
#         <meta name="viewport" content="width=device-width, initial-scale=1">
#         <meta name="description" content="Se publicó en la revista científica Nature Neuroscience y representa un gran paso hacia la recuperación de la comunicación para personas con parálisis severa.">
#         <meta property="fb:admins"              content="1519473672,1483151046,1400476054,1348939261,787200720,665292098,100010617798321,653341927,1381624636,1411317735">
#         <meta property="fb:app_id"              content="641084159376902">
#         <meta property="fb:pages"               content="167965119890296">
#         <title>Una mujer cuadripléjica volvió a hablar tras 18 años gracias a la Inteligencia Artificial | Perfil</title>
#         <script>window["sharedData"]={"light_gallery_images":[{"src":"https:\/\/fotos.perfil.com\/2025\/04\/02\/una-mujer-cuadriplejica-volvio-a-hablar-tras-18-anos-gracias-a-la-inteligencia-artificial-1996489.jpg","thumb":"https:\/\/fotos.perfil.com\/2025\/04\/02\/cropped\/250\/250\/center\/una-mujer-cuadriplejica-volvio-a-hablar-tras-18-anos-gracias-a-la-inteligencia-artificial-1996489.jpg","subHtml":"Una mujer cuadripl\u00e9jica volvi\u00f3 a hablar tras 18 a\u00f1os gracias a la Inteligencia Artificial"}],"paywall":{"type":"metered","content_id":1138356,"content_canal":"reperfilar","content_title":"Una mujer cuadripl\u00e9jica volvi\u00f3 a hablar tras 18 a\u00f1os gracias a la Inteligencia Artificial","content_date":"2025-04-02T11:05:10-03:00","content_length":4391,"content_canonical_url":"https:\/\/www.perfil.com\/noticias\/reperfilar\/una-mujer-cuadriplejica-volvio-a-hablar-tras-18-anos-gracias-a-la-inteligencia-artificial.phtml","show_metered_modal":false,"author_id":1549,"author_username":"acarelli","author_fullname":"Agust\u00edn Carelli"},"eplanning":{"client":"24a92","sec":"reperfilar_articulo"}};window["sharedDataNamespace"]="sharedData";window["shared"]=function(e){var n=void 0!==arguments[1]?arguments[1]:null;return[window.sharedDataNamespace].concat("string"==typeof e?e.split("."):[]).reduce(function(e,t){return e===n||"object"!=typeof e||void 0===e[t]?n:e[t]},window)};</script>
#         <meta name="page-version" content="03-04-2025 19:59:04">
#         	<meta name="article-id" content="1138356">
# 	<meta name="title" content="Una mujer cuadripléjica volvió a hablar tras 18 años gracias a la Inteligencia Artificial">
# 	<meta name="headline" content="Se publicó en la revista científica Nature Neuroscience y representa un gran paso hacia la recuperación de la comunicación para personas con parálisis severa.">
# 	<meta name="featured-image-id" content="1996489">
# 	<meta name="datepublished" content="April, 02 2025 11:05:10 -0300">
#
#
# 	<meta property="article:opinion" content="false" />
# 	<meta property="article:content_tier" content="metered" />
# 	<meta property="article:tag" content="Social Issues" />
# 	<meta property="article:location" content="region:arg" />
#
#
# 			<meta name="vf:container_id" content="1138356" />
# 		<meta name="vf:url" content="https://www.perfil.com/noticias/reperfilar/una-mujer-cuadriplejica-volvio-a-hablar-tras-18-anos-gracias-a-la-inteligencia-artificial.phtml" />
#
#
#
#         <meta name="google-signin-client_id" content="90478180106-ot92vjnrmmq2a5ba26ft1ph5p7u5k0oh.apps.googleusercontent.com" />
#
#         <link rel="apple-touch-icon" sizes="57x57" href="https://www.perfil.com/images/favicon/apple-icon-57x57.png">
#         <link rel="apple-touch-icon" sizes="60x60" href="https://www.perfil.com/images/favicon/apple-icon-60x60.png">
#         <link rel="apple-touch-icon" sizes="72x72" href="https://www.perfil.com/images/favicon/apple-icon-72x72.png">
#         <link rel="apple-touch-icon" sizes="76x76" href="https://www.perfil.com/images/favicon/apple-icon-76x76.png">
#         <link rel="apple-touch-icon" sizes="114x114" href="https://www.perfil.com/images/favicon/apple-icon-114x114.png">
#         <link rel="apple-touch-icon" sizes="120x120" href="https://www.perfil.com/images/favicon/apple-icon-120x120.png">
#         <link rel="apple-touch-icon" sizes="144x144" href="https://www.perfil.com/images/favicon/apple-icon-144x144.png">
#         <link rel="apple-touch-icon" sizes="152x152" href="https://www.perfil.com/images/favicon/apple-icon-152x152.png">
#         <link rel="apple-touch-icon" sizes="180x180" href="https://www.perfil.com/images/favicon/apple-icon-180x180.png">
#         <link rel="icon" type="image/png" sizes="192x192"  href="https://www.perfil.com/images/favicon/android-icon-192x192.png">
#         <link rel="icon" type="image/png" sizes="32x32" href="https://www.perfil.com/images/favicon/favicon-32x32.png">
#         <link rel="icon" type="image/png" sizes="96x96" href="https://www.perfil.com/images/favicon/favicon-96x96.png">
#         <link rel="icon" type="image/png" sizes="16x16" href="https://www.perfil.com/images/favicon/favicon-16x16.png">
#         <link rel="manifest" href="https://www.perfil.com/images/favicon/manifest.json">
#         <meta name="msapplication-TileColor" content="#ffffff">
#         <meta name="msapplication-TileImage" content="https://www.perfil.com/images/favicon/ms-icon-144x144.png">
#         <meta name="theme-color" content="#ffffff">
#
#         <link rel="preconnect" href="https://ads.us.e-planning.net">
#         <link rel="preconnect" href="https://libs.lavoz.com.ar">
#         <link rel="preconnect" href="https://fonts.gstatic.com">
#         <link rel="preconnect" href="https://www.google-analytics.com">
#         	<link rel="canonical" href="https://www.perfil.com/noticias/reperfilar/una-mujer-cuadriplejica-volvio-a-hablar-tras-18-anos-gracias-a-la-inteligencia-artificial.phtml">
# 	<link rel="amphtml" href="https://www.perfil.com/noticias/amp/reperfilar/una-mujer-cuadriplejica-volvio-a-hablar-tras-18-anos-gracias-a-la-inteligencia-artificial.phtml">	<link rel="profile" href="https://gmpg.org/xfn/11">
#
# 		<meta property="og:url"                 content="https://www.perfil.com/noticias/reperfilar/una-mujer-cuadriplejica-volvio-a-hablar-tras-18-anos-gracias-a-la-inteligencia-artificial.phtml" />
# 		<meta property="og:type"                content="article" />
# 		<meta property="og:locale"              content="es_AR">
# 		<meta property="og:site_name"           content="Perfil"/>
# 		<meta property="og:title"               content="Una mujer cuadripléjica volvió a hablar tras 18 años gracias a la Inteligencia Artificial" />
# 		<meta property="og:description"         content="Se publicó en la revista científica Nature Neuroscience y representa un gran paso hacia la recuperación de la comunicación para personas con parálisis severa." />
# 		<meta property="og:updated_time" 		content="2025-04-03T10:20:23-03:00" />
# 		<meta property="og:image"               content="https://fotos.perfil.com/2025/04/02/trim/1140/641/una-mujer-cuadriplejica-volvio-a-hablar-tras-18-anos-gracias-a-la-inteligencia-artificial-1996489.jpg" />
# 		<meta property="og:image:secure_url" 	content="https://fotos.perfil.com/2025/04/02/trim/1140/641/una-mujer-cuadriplejica-volvio-a-hablar-tras-18-anos-gracias-a-la-inteligencia-artificial-1996489.jpg" />
# 		<meta property="og:image:type"          content="image/jpeg" />
# 		<meta property="og:image:width"         content="1140" />
# 		<meta property="og:image:height"        content="641" />
# 		<meta property="article:section"        content="reperfilar">
# 		<meta property="article:published_time" content="2025-04-02T11:05:10-03:00">
# 		<meta property="article:modified_time"  content="2025-04-03T10:20:23-03:00">
# 		<meta property="article:tag" 			content="Inteligencia Artificial" />
# 		<meta property="article:tag" 			content=" mujer cuadripléjica" />
# 		<meta property="article:tag" 			content=" " />
#
# 		<meta name="twitter:card"               content="summary_large_image">
# 		<meta name="twitter:site"               content="@perfilcom">
# 		<meta name="twitter:creator"            content="@perfilcom">
# 		<meta name="twitter:title"              content='Una mujer cuadripléjica volvió a hablar tras 18 años gracias a la Inteligencia Artificial'>
# 		<meta name="twitter:description"        content="Se publicó en la revista científica Nature Neuroscience y representa un gran paso hacia la recuperación de la comunicación para personas con parálisis severa.">
# 		<meta name="twitter:image"              content="https://fotos.perfil.com/2025/04/02/trim/1140/641/una-mujer-cuadriplejica-volvio-a-hablar-tras-18-anos-gracias-a-la-inteligencia-artificial-1996489.jpg">
# 		<meta name="twitter:image:alt"          content='Una mujer cuadripléjica volvió a hablar tras 18 años gracias a la Inteligencia Artificial'>
#
#         <link rel="preload" href="/fonts/crimson/CrimsonPro-Medium.woff2" as="font" type="font/woff2" crossorigin>
#
#         	<link rel="stylesheet" href="/css/news-high.css?id=b8b6d78fd3d3dc861b3c">
# 	<link rel="stylesheet" href="/css/news-low.css?id=0b34618250536a0a50af" media="print" onload="this.media='all'">
#
#         <script type="text/javascript">
#             window.paywall = window.paywall || {}
#             window.paywallConfig = window.paywallConfig || {}
#             window.perfilContent = window.perfilContent || {}
#             paywall.queue = window.paywall.queue || []
#             window.paywallConfig.loginwallLimit = 15
#             window.paywallConfig.paywallLimit = 40
#             window.paywallConfig.enableSocket = true
#             window.paywallConfig.socketHoursPeriodicity = 6
#             window.paywallConfig.socketHoursPeriodicitySubs = 24
#         </script>
#
#
#          <!-- Google Tag Manager (prop: global) -->
#             <script type="text/javascript">
#             window.dataLayer = window.dataLayer || [];
#             window.dataLayer.push({
#     "brand": "perfil",
#     "brandPretty": "Perfil",
#     "environment": "main",
#     "pageCategory": "nota",
#     "articleFormat": "estandar",
#     "articleId": 1138356,
#     "articleTitle": "Una mujer cuadripl\u00e9jica volvi\u00f3 a hablar tras 18 a\u00f1os gracias a la Inteligencia Artificial",
#     "articleShortTitle": "Una mujer cuadripl\u00e9jica volvi\u00f3 a hablar tras 18 a\u00f1os gracias a la Inteligencia Artificial",
#     "articleStyle": "noticia",
#     "articleSection": "reperfilar",
#     "articleTags": "Inteligencia Artificial| mujer cuadripl\u00e9jica| ",
#     "articleLastUpdate": "03-04-2025",
#     "articlePublicationDateLegacy": "April, 02 2025 11:05:10 -0300",
#     "articlePublicationDate": "02-04-2025",
#     "articleLastUpdateLegacy": "April, 03 2025 10:20:23 -0300",
#     "articleHighlightLevel": "",
#     "articleHighlightLevelZone": "",
#     "articleHighlightLevelPosition": "",
#     "articleEditorId": "",
#     "articleEditorUserName": "",
#     "articleEditor": "",
#     "articleAuthorId": 1549,
#     "articleAuthorUserName": "acarelli",
#     "articleAuthor": "Agust\u00edn Carelli",
#     "articleSigned": false,
#     "articleCredit": "",
#     "articleHaveVideo": false,
#     "articleHaveImages": false,
#     "articleHaveGallery": false,
#     "articleHaveAudio": false,
#     "articleHaveSocial": false,
#     "articleHaveComments": false,
#     "articleHaveFiles": false,
#     "articleIsCompressed": "false",
#     "articleHaveRedaction": true,
#     "articleFullLength": 3461,
#     "articleWordCounter": 534,
#     "articleLayout": "default",
#     "articleScrollLimit": "false",
#     "articlePaywallType": "abierto",
#     "pressEditionNumber": "",
#     "pressEditionYear": "",
#     "pressEditionYearRoman": "",
#     "pressEditionSlug": "",
#     "pressEditionDescription": "",
#     "pressEdition": ""
# });
#             console.log('GTM', window.dataLayer);
#             (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#                     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#                 j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#                 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#             })(window,document,'script','dataLayer','GTM-KHWT7BR');
#         </script>
#         <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-KHWT7BR" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
#         <!-- /Google Tag Manager -->
#
#
#          <script>
#           var _comscore = _comscore || [];
#           _comscore.push({ c1: "2", c2: "6906401", options: {enableFirstPartyCookie: true, bypassUserConsentRequirementFor1PCookie: true} });
#           (function() {
#             var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.defer = true;
#             s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#             el.parentNode.insertBefore(s, el);
#           })();
#         </script>
#         <noscript>
#             <img src="https://b.scorecardresearch.com/p?c1=2&c2=6906401&cv=2.0&cj=1" />
#         </noscript>
#
#
#
#          <script type="text/javascript">
#           function e(e){var t=!(arguments.length>1&&void 0!==arguments[1])||arguments[1],c=document.createElement("script");c.src=e,t?c.type="module":(c.async=!0,c.type="text/javascript",c.setAttribute("nomodule",""));var n=document.getElementsByTagName("script")[0];n.parentNode.insertBefore(c,n)}function t(t,c,n){var a,o,r;null!==(a=t.marfeel)&&void 0!==a||(t.marfeel={}),null!==(o=(r=t.marfeel).cmd)&&void 0!==o||(r.cmd=[]),t.marfeel.config=n,t.marfeel.config.accountId=c;var i="https://sdk.mrf.io/statics";e("".concat(i,"/marfeel-sdk.js?id=").concat(c),!0),e("".concat(i,"/marfeel-sdk.es5.js?id=").concat(c),!1)}!function(e,c){var n=arguments.length>2&&void 0!==arguments[2]?arguments[2]:{};t(e,c,n)}(window,1740,{} /*config*/);
#         </script>
#
#
#
#
#
#
#                     <script>
#                 !function(f,b,e,v,n,t,s)
#                 {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#                     n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#                     if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#                     n.queue=[];t=b.createElement(e);t.async=!0;
#                     t.src=v;s=b.getElementsByTagName(e)[0];
#                     s.parentNode.insertBefore(t,s)}(window, document,'script',
#                     'https://connect.facebook.net/en_US/fbevents.js');
#                 window.paywallConfig.facebook_pixel = '1000228364089342'
#             </script>
#             <noscript><img height="1" width="1" style="display:none" src="https://www.facebook.com/tr?id=1000228364089342&ev=PageView&noscript=1"/></noscript>
#
#
#
#
#         <!-- InMobi Choice. Consent Manager Tag v3.0 (for TCF 2.2) -->
# <script type="text/javascript" async=true>
#   (function() {
#     var host = window.location.hostname;
#     var element = document.createElement('script');
#     var firstScript = document.getElementsByTagName('script')[0];
#     var url = 'https://cmp.inmobi.com'
#       .concat('/choice/', 'JLynYhbuKN0hh', '/', host, '/choice.js?tag_version=V3');
#     var uspTries = 0;
#     var uspTriesLimit = 3;
#     element.async = true;
#     element.type = 'text/javascript';
#     element.src = url;
#
#     firstScript.parentNode.insertBefore(element, firstScript);
#
#     function makeStub() {
#       var TCF_LOCATOR_NAME = '__tcfapiLocator';
#       var queue = [];
#       var win = window;
#       var cmpFrame;
#
#       function addFrame() {
#         var doc = win.document;
#         var otherCMP = !!(win.frames[TCF_LOCATOR_NAME]);
#
#         if (!otherCMP) {
#           if (doc.body) {
#             var iframe = doc.createElement('iframe');
#
#             iframe.style.cssText = 'display:none';
#             iframe.name = TCF_LOCATOR_NAME;
#             doc.body.appendChild(iframe);
#           } else {
#             setTimeout(addFrame, 5);
#           }
#         }
#         return !otherCMP;
#       }
#
#       function tcfAPIHandler() {
#         var gdprApplies;
#         var args = arguments;
#
#         if (!args.length) {
#           return queue;
#         } else if (args[0] === 'setGdprApplies') {
#           if (
#             args.length > 3 &&
#             args[2] === 2 &&
#             typeof args[3] === 'boolean'
#           ) {
#             gdprApplies = args[3];
#             if (typeof args[2] === 'function') {
#               args[2]('set', true);
#             }
#           }
#         } else if (args[0] === 'ping') {
#           var retr = {
#             gdprApplies: gdprApplies,
#             cmpLoaded: false,
#             cmpStatus: 'stub'
#           };
#
#           if (typeof args[2] === 'function') {
#             args[2](retr);
#           }
#         } else {
#           if(args[0] === 'init' && typeof args[3] === 'object') {
#             args[3] = Object.assign(args[3], { tag_version: 'V3' });
#           }
#           queue.push(args);
#         }
#       }
#
#       function postMessageEventHandler(event) {
#         var msgIsString = typeof event.data === 'string';
#         var json = {};
#
#         try {
#           if (msgIsString) {
#             json = JSON.parse(event.data);
#           } else {
#             json = event.data;
#           }
#         } catch (ignore) {}
#
#         var payload = json.__tcfapiCall;
#
#         if (payload) {
#           window.__tcfapi(
#             payload.command,
#             payload.version,
#             function(retValue, success) {
#               var returnMsg = {
#                 __tcfapiReturn: {
#                   returnValue: retValue,
#                   success: success,
#                   callId: payload.callId
#                 }
#               };
#               if (msgIsString) {
#                 returnMsg = JSON.stringify(returnMsg);
#               }
#               if (event && event.source && event.source.postMessage) {
#                 event.source.postMessage(returnMsg, '*');
#               }
#             },
#             payload.parameter
#           );
#         }
#       }
#
#       while (win) {
#         try {
#           if (win.frames[TCF_LOCATOR_NAME]) {
#             cmpFrame = win;
#             break;
#           }
#         } catch (ignore) {}
#
#         if (win === window.top) {
#           break;
#         }
#         win = win.parent;
#       }
#       if (!cmpFrame) {
#         addFrame();
#         win.__tcfapi = tcfAPIHandler;
#         win.addEventListener('message', postMessageEventHandler, false);
#       }
#     };
#
#     makeStub();
#
#     var uspStubFunction = function() {
#       var arg = arguments;
#       if (typeof window.__uspapi !== uspStubFunction) {
#         setTimeout(function() {
#           if (typeof window.__uspapi !== 'undefined') {
#             window.__uspapi.apply(window.__uspapi, arg);
#           }
#         }, 500);
#       }
#     };
#
#     var checkIfUspIsReady = function() {
#       uspTries++;
#       if (window.__uspapi === uspStubFunction && uspTries < uspTriesLimit) {
#         console.warn('USP is not accessible');
#       } else {
#         clearInterval(uspInterval);
#       }
#     };
#
#     if (typeof window.__uspapi === 'undefined') {
#       window.__uspapi = uspStubFunction;
#       var uspInterval = setInterval(checkIfUspIsReady, 6000);
#     }
#   })();
# </script>
# <!-- End InMobi Choice. Consent Manager Tag v3.0 (for TCF 2.2) -->
#
#         	<script async src="https://news.google.com/swg/js/v1/swg-gaa.js"></script>
# 	<script async subscriptions-control="manual" src="https://news.google.com/swg/js/v1/swg.js"></script>
# 	<script async src="https://apis.google.com/js/platform.js"></script>
# 	<noscript>
# 		<img src="http://b.scorecardresearch.com/p?c1=2&c2=6906401&cv=2.0&cj=1" />
# 	</noscript>
#
# 			<script async src="https://a.teads.tv/analytics/tag.js"></script>
# 		<script>
# 			window.teads_analytics = window.teads_analytics || {};
# 			window.teads_analytics.analytics_tag_id = "PUB_14293";
# 			window.teads_analytics.share = window.teads_analytics.share || function() {
# 				;(window.teads_analytics.shared_data = window.teads_analytics.shared_data || []).push(arguments)
# 			};
# 		</script>
#
# 	 <!-- Datos estructurados -->
# <script type="application/ld+json">
#     {"@context":"http:\/\/schema.org","@type":"NewsArticle","mainEntityOfPage":"https:\/\/www.perfil.com\/seccion\/reperfilar","headline":"Una mujer cuadripl\u00e9jica volvi\u00f3 a hablar tras 18 a\u00f1os gracias a la Inteligencia Artificial","url":"https:\/\/www.perfil.com\/noticias\/reperfilar\/una-mujer-cuadriplejica-volvio-a-hablar-tras-18-anos-gracias-a-la-inteligencia-artificial.phtml","articleSection":"https:\/\/www.perfil.com\/seccion\/reperfilar","genre":"https:\/\/www.perfil.com\/seccion\/reperfilar","dateline":"Buenos Aires, AR","inLanguage":"es_AR","image":{"@type":"ImageObject","url":"https:\/\/fotos.perfil.com\/2025\/04\/02\/trim\/1280\/720\/una-mujer-cuadriplejica-volvio-a-hablar-tras-18-anos-gracias-a-la-inteligencia-artificial-1996489.jpg","width":1280,"height":720},"datePublished":"2025-04-02T11:05:10-03:00","dateModified":"2025-04-03T10:20:23-03:00","keywords":"Inteligencia Artificial, mujer cuadripl\u00e9jica, ","author":{"@type":"Person","name":"Agust\u00edn Carelli","url":"https:\/\/www.perfil.com\/autores\/acarelli"},"publisher":{"@type":"Organization","name":"Perfil","logo":{"@type":"ImageObject","url":"https:\/\/www.perfil.com\/images\/logo_perfil.png","width":"500","height":"112"}},"isAccessibleForFree":false,"hasPart":{"@type":"WebPageElement","isAccessibleForFree":false,"cssSelector":".supercontenedor"},"isPartOf":{"@type":["CreativeWork","Product"],"name":"Perfil Virtual","productID":"perfil.com:perfil_digital"},"0":[{"@context":"http:\/\/schema.org","@type":"VideoObject","description":"Vuelve a hablar tras 18 a\u00f1os por un implante con inteligencia artificial","name":"Vuelve a hablar tras 18 a\u00f1os por un implante con inteligencia artificial","publisher":{"@type":"Organization","name":"Perfil.com","url":"https:\/\/perfil.com","logo":{"@type":"ImageObject","url":"https:\/\/www.perfil.com\/static\/img\/icons\/apple-touch-icon.png"}},"thumbnailUrl":"https:\/\/cdn.rudo.video\/upload\/us\/canalnet\/1476866\/67ed34bb15ffa_2.jpg","embedUrl":"https:\/\/rudo.video\/vod\/czBHUBSwWYc","duration":"PT9S","interactionCount":8,"uploadDate":"2025-04-02T09:59:23-03:00"}]}
# </script>
#     </head>
#
#     <body id="app-body" class="perfil-noticia">
#          <div class="col bg-w">
#     <div class="row">
#         <div class="preheader max-width-md">
#             <div class="preheader__fecha">jueves 03 de abril de 2025</div>
#             <div class="preheader__data">
#                 <div class="preheader__sites">
#                     <ul class="preheader__sites-list">
#                         <li class="preheader__sites-item preheader__sites-item--bloomberg">
#                             <a href="https://www.perfil.com/seccion/bloomberg">
#                                 Business
#                             </a>
#                         </li>
#                         <li class="preheader__sites-item preheader__sites-item--noticias">
#                             <a href="https://noticias.perfil.com" rel="noreferrer">
#                                 Noticias
#                             </a>
#                         </li>
#                         <li class="preheader__sites-item preheader__sites-item--caras">
#                             <a href="https://caras.perfil.com" rel="noreferrer">
#                                 Caras
#                             </a>
#                         </li>
#                         <li class="preheader__sites-item preheader__sites-item--exitoina">
#                             <a href="https://exitoina.perfil.com" rel="noreferrer">
#                                 Exitoína
#                             </a>
#                         </li>
#                         <li class="preheader__sites-item preheader__sites-item--brasil">
#                             <a href="https://brasil.perfil.com" target="_blank" rel="noreferrer">
#                                 Perfil Brasil
#                             </a>
#                         </li>
#                     </ul>
#                 </div>
#                 <div class="search" id="header-search">
#                     <form method="get" class="search__form" action="https://www.perfil.com/buscador">
#                         <input class="search__control" name="q" type="text" placeholder="Buscar" aria-label="Buscar" value="">
#                         <button type="submit" class="search__button" aria-label="Buscar en Perfil">
#                             <svg width="13.5" height="13.5" viewBox="0 0 13.57 13.44">
#                                 <path d="M13.57,12.43,10.31,9.17a5.68,5.68,0,1,0-1,1l3.24,3.24ZM5.73,10.09a4.36,4.36,0,1,1,4.36-4.36A4.36,4.36,0,0,1,5.73,10.09Z" />
#                             </svg>
#                         </button>
#                     </form>
#                 </div>
#             </div>
#         </div>
#     </div>
# </div>
#
# <header class="main-header col">
#     <div class="row">
#         <div class="max-width-md main-header__wrapper">
#             <div class="main-header__main">
#                 <button class="main-header__toggler-button" id="js-menu-toggler" aria-label="Abrir menu">
#                     <span class="bar"></span><span class="bar"></span><span class="bar"></span>
#                 </button>
#                 <figure class="main-header__brand">
#                     <a href="/" title="Ir al inicio">
#                         <svg viewBox="0 0 293.64 65.76">
#                             <circle cx="32.88" cy="32.88" r="32.88" style="fill:#4f78a8" />
#                             <path d="M292.92,52.7l.72-13.65-2.75-.25C288.74,47,284.73,50,275.87,50c-3.24,0-4.18-.15-4.18-2.65V21.85c0-2,.44-2.65,2.81-2.65H278V16.6H256.18v2.6H259c2.42,0,2.75.65,2.75,2.65v25.6c0,2-.44,2.6-2.8,2.6h-2.81V52.7ZM254.63,16.6H233v2.6h3c2.42,0,2.81.65,2.81,2.65v25.6c0,2-.44,2.6-2.81,2.6h-3V52.7h21.61V50.05H251.5c-2.37,0-2.75-.6-2.75-2.6V21.85c0-2,.38-2.65,2.75-2.65h3.13Zm-24.7,0H194v2.6h2.8c2.42,0,2.81.65,2.81,2.65v25.6c0,2-.44,2.6-2.81,2.6H194V52.7h22V50.05h-4c-2.36,0-2.75-.6-2.75-2.6V35.4h.77c4.84,0,6.88,1.9,7.81,6.9h2.75V25.75h-2.75c-.93,5-2.91,7-7.81,7h-.77V22c0-2.5.83-2.7,4-2.7,8.41,0,12.21,2.65,14.3,10.3h2.69ZM165.52,35.35c.77-.05,1.54-.05,2.2-.05,6.32,0,7.48,1.65,7.86,7.15.17,2.75-.27,5.35,1.16,7.75,1.32,2.25,4,3.4,8,3.4,5.78,0,9.19-3.2,9.19-8.8v-.4h-2.81c-.05,3.25-.71,4.9-2.31,4.9-2.47,0-1.92-3.7-3.52-8.1A8.77,8.77,0,0,0,176.79,35V34.6c7.81-.25,12.27-3.6,12.27-8.85,0-5.95-5-9.15-14.8-9.15H150v2.6h3c2.14,0,2.8.55,2.8,2.65v25.6c0,2.1-.66,2.6-2.8,2.6h-3V52.7h21.23V50.05h-3c-2.09,0-2.75-.45-2.75-2.6V35.35Zm0-13.4c0-2.45.6-2.75,4.23-2.75,6.55,0,9.24,1.5,9.24,6.7,0,5.35-3.3,6.9-11.16,6.9a18.48,18.48,0,0,1-2.32-.1V22ZM109.41,52.7h37.07l.71-13.55-2.75-.2c-2.14,8.3-6.32,11.2-15.56,11.2-3.36,0-4.18-.25-4.18-2.7V35.4h.77c4.84,0,6.87,1.9,7.81,6.9H136V25.75h-2.75c-.94,5-2.92,7-7.81,7h-.77V21.85c0-2.5.82-2.7,4-2.7,8.47,0,12.32,2.7,14.3,10.45h2.7l-.44-13H109.41v2.6h2.75c2.42,0,2.81.65,2.81,2.65v25.6c0,2-.44,2.6-2.81,2.6h-2.75V52.7ZM83.88,47.45V37.2c2,0,3.79,0,5.5,0,12.26,0,18.26-3.25,18.26-10.4,0-6.7-5.17-10.25-15.13-10.25H68.26v2.6h3c2.42,0,2.81.65,2.81,2.65v25.6c0,2-.44,2.6-2.81,2.6h-3V52.7H90V50.05H86.58C84.32,50.05,83.88,49.55,83.88,47.45Zm0-25.1c0-2.8.66-3.15,4.29-3.15,6.43,0,9,1.85,9,7.65,0,6-3,7.65-10.5,7.65a19.08,19.08,0,0,1-2.75-.15Z" class="main-header--contrast" />
#                             <path d="M29.15,33.58c-.06,0-.13-.12-.13-.12a6.83,6.83,0,0,1,.29-3A6.71,6.71,0,0,1,33,26.15a44.86,44.86,0,0,1,5.37-1.9c2.21-.59,6.95-1.71,6.95-1.71s2.43-.56,4.34-.89,3.55-.49,4.27-.71a9.51,9.51,0,0,0,3.47-1.58c-.79.64.21-.14,0-.06.11-.11.15-.11.21-.19s1-1,.82-1.83-1.59-.67-1.59-.67-2.9,0-3.79.13-1,.39-1.61,1a2.78,2.78,0,0,1-2,.93c-1,0-5.54-.65-7.44-.63a44.18,44.18,0,0,0-10.19,1.06,28.85,28.85,0,0,0-5.57,1.88,9.32,9.32,0,0,0-3.54,2.56,6.28,6.28,0,0,0-.87,3.61c0,.78.46,2.19,0,2.69-.69.7-2.58.51-3.21.42a8.57,8.57,0,0,1-2.9-1,3.28,3.28,0,0,1-1.57-2c-.3-2.29-.9-3.25-2.5-3.4a10.86,10.86,0,0,0-3.31.62,18.29,18.29,0,0,1-2.25.46c-1,.11-2.15.07-2.15.33s.7.34,2.66.28,3.24.14,4.15.76a3.47,3.47,0,0,1,1.49,2.24c.52,1.78.33,2.25,1.16,2.7A35.57,35.57,0,0,0,17.54,33a3,3,0,0,1,2.23,2.86c0,.39.14,3,.17,3.85a9.8,9.8,0,0,0,2.12,5s1,1.79,4.82,3.8a44.34,44.34,0,0,0,4.49,2,7.63,7.63,0,0,1,2.23,1.26c.23.28.79,1,1.23,1s13.5.1,13.5.1.87,0,.43-1A3.68,3.68,0,0,0,47,50.11,9.85,9.85,0,0,0,43.68,49a32.28,32.28,0,0,1-6.48-1.75,27.42,27.42,0,0,1-6.36-4c-1.09-.94-2.78-2.27-3.19-4.21a3,3,0,0,1,.43-2,1.3,1.3,0,0,1,.87-.41l2,.12c.93.05,3,.33,4.24.45s5.59.8,7.06,1.1,6.85,1.82,7.57,2,4.44,1.67,4.84,1.19a2.61,2.61,0,0,0,.24-.52c.27-.67,1.66-8.59,1.66-8.59s.17-1-1.16-1.09a17.37,17.37,0,0,0-2.56-.17,53.73,53.73,0,0,0-6,.79c-3,.52-6.13,1.28-6.13,1.28a34.19,34.19,0,0,1-4.09.82,24.47,24.47,0,0,1-7.1-.2,1.77,1.77,0,0,1-.37-.29" style="fill:#fff" />
#                         </svg>
#                     </a>
#                 </figure>
#                 <div class="main-header__ft-menu">
#                     <ul class="ft-menu">
#                         <li>
#                             <a href="https://www.perfil.com/ultimo-momento">Últimas Noticias</a>
#                         </li>
#                         <li>
#                             <a href="https://www.perfil.com/seccion/politica">Política</a>
#                         </li>
#                         <li>
#                             <a href="https://www.perfil.com/seccion/opinion">Opinión</a>
#                         </li>
#                         <li>
#                             <a href="https://www.perfil.com/seccion/sociedad">Sociedad</a>
#                         </li>
#                     </ul>
#                 </div>
#             </div>
#             <div class="main-header__radio">
#                             </div>
#             <div id="paywall-login-container" class="pw-suscripcion">
#                 <a href="https://mi.perfil.com/id/login/?continue=https://www.perfil.com" class="pw-ingresar" rel="nofollow">Ingresar</a>
#                 <a href="https://mi.perfil.com/" class="pw-suscribite" rel="nofollow">Suscribite por $20/día</a>
#             </div>
#             <div class="viafoura">
#                 <vf-tray-trigger></vf-tray-trigger>
#             </div>
#         </div>
#     </div>
# </header>
#
# <div id="js-side-menu" class="side-menu">
#     <div class="side-menu__header">
#         <div class="side-menu__brand">
#             <a href="/" aria-label="Perfil">
#                 <svg width="120" height="27" viewBox="0 0 293.64 65.76">
#                     <circle cx="32.88" cy="32.88" r="32.88" style="fill:#4f78a8" />
#                     <path d="M292.92,52.7l.72-13.65-2.75-.25C288.74,47,284.73,50,275.87,50c-3.24,0-4.18-.15-4.18-2.65V21.85c0-2,.44-2.65,2.81-2.65H278V16.6H256.18v2.6H259c2.42,0,2.75.65,2.75,2.65v25.6c0,2-.44,2.6-2.8,2.6h-2.81V52.7ZM254.63,16.6H233v2.6h3c2.42,0,2.81.65,2.81,2.65v25.6c0,2-.44,2.6-2.81,2.6h-3V52.7h21.61V50.05H251.5c-2.37,0-2.75-.6-2.75-2.6V21.85c0-2,.38-2.65,2.75-2.65h3.13Zm-24.7,0H194v2.6h2.8c2.42,0,2.81.65,2.81,2.65v25.6c0,2-.44,2.6-2.81,2.6H194V52.7h22V50.05h-4c-2.36,0-2.75-.6-2.75-2.6V35.4h.77c4.84,0,6.88,1.9,7.81,6.9h2.75V25.75h-2.75c-.93,5-2.91,7-7.81,7h-.77V22c0-2.5.83-2.7,4-2.7,8.41,0,12.21,2.65,14.3,10.3h2.69ZM165.52,35.35c.77-.05,1.54-.05,2.2-.05,6.32,0,7.48,1.65,7.86,7.15.17,2.75-.27,5.35,1.16,7.75,1.32,2.25,4,3.4,8,3.4,5.78,0,9.19-3.2,9.19-8.8v-.4h-2.81c-.05,3.25-.71,4.9-2.31,4.9-2.47,0-1.92-3.7-3.52-8.1A8.77,8.77,0,0,0,176.79,35V34.6c7.81-.25,12.27-3.6,12.27-8.85,0-5.95-5-9.15-14.8-9.15H150v2.6h3c2.14,0,2.8.55,2.8,2.65v25.6c0,2.1-.66,2.6-2.8,2.6h-3V52.7h21.23V50.05h-3c-2.09,0-2.75-.45-2.75-2.6V35.35Zm0-13.4c0-2.45.6-2.75,4.23-2.75,6.55,0,9.24,1.5,9.24,6.7,0,5.35-3.3,6.9-11.16,6.9a18.48,18.48,0,0,1-2.32-.1V22ZM109.41,52.7h37.07l.71-13.55-2.75-.2c-2.14,8.3-6.32,11.2-15.56,11.2-3.36,0-4.18-.25-4.18-2.7V35.4h.77c4.84,0,6.87,1.9,7.81,6.9H136V25.75h-2.75c-.94,5-2.92,7-7.81,7h-.77V21.85c0-2.5.82-2.7,4-2.7,8.47,0,12.32,2.7,14.3,10.45h2.7l-.44-13H109.41v2.6h2.75c2.42,0,2.81.65,2.81,2.65v25.6c0,2-.44,2.6-2.81,2.6h-2.75V52.7ZM83.88,47.45V37.2c2,0,3.79,0,5.5,0,12.26,0,18.26-3.25,18.26-10.4,0-6.7-5.17-10.25-15.13-10.25H68.26v2.6h3c2.42,0,2.81.65,2.81,2.65v25.6c0,2-.44,2.6-2.81,2.6h-3V52.7H90V50.05H86.58C84.32,50.05,83.88,49.55,83.88,47.45Zm0-25.1c0-2.8.66-3.15,4.29-3.15,6.43,0,9,1.85,9,7.65,0,6-3,7.65-10.5,7.65a19.08,19.08,0,0,1-2.75-.15Z" />
#                     <path d="M29.15,33.58c-.06,0-.13-.12-.13-.12a6.83,6.83,0,0,1,.29-3A6.71,6.71,0,0,1,33,26.15a44.86,44.86,0,0,1,5.37-1.9c2.21-.59,6.95-1.71,6.95-1.71s2.43-.56,4.34-.89,3.55-.49,4.27-.71a9.51,9.51,0,0,0,3.47-1.58c-.79.64.21-.14,0-.06.11-.11.15-.11.21-.19s1-1,.82-1.83-1.59-.67-1.59-.67-2.9,0-3.79.13-1,.39-1.61,1a2.78,2.78,0,0,1-2,.93c-1,0-5.54-.65-7.44-.63a44.18,44.18,0,0,0-10.19,1.06,28.85,28.85,0,0,0-5.57,1.88,9.32,9.32,0,0,0-3.54,2.56,6.28,6.28,0,0,0-.87,3.61c0,.78.46,2.19,0,2.69-.69.7-2.58.51-3.21.42a8.57,8.57,0,0,1-2.9-1,3.28,3.28,0,0,1-1.57-2c-.3-2.29-.9-3.25-2.5-3.4a10.86,10.86,0,0,0-3.31.62,18.29,18.29,0,0,1-2.25.46c-1,.11-2.15.07-2.15.33s.7.34,2.66.28,3.24.14,4.15.76a3.47,3.47,0,0,1,1.49,2.24c.52,1.78.33,2.25,1.16,2.7A35.57,35.57,0,0,0,17.54,33a3,3,0,0,1,2.23,2.86c0,.39.14,3,.17,3.85a9.8,9.8,0,0,0,2.12,5s1,1.79,4.82,3.8a44.34,44.34,0,0,0,4.49,2,7.63,7.63,0,0,1,2.23,1.26c.23.28.79,1,1.23,1s13.5.1,13.5.1.87,0,.43-1A3.68,3.68,0,0,0,47,50.11,9.85,9.85,0,0,0,43.68,49a32.28,32.28,0,0,1-6.48-1.75,27.42,27.42,0,0,1-6.36-4c-1.09-.94-2.78-2.27-3.19-4.21a3,3,0,0,1,.43-2,1.3,1.3,0,0,1,.87-.41l2,.12c.93.05,3,.33,4.24.45s5.59.8,7.06,1.1,6.85,1.82,7.57,2,4.44,1.67,4.84,1.19a2.61,2.61,0,0,0,.24-.52c.27-.67,1.66-8.59,1.66-8.59s.17-1-1.16-1.09a17.37,17.37,0,0,0-2.56-.17,53.73,53.73,0,0,0-6,.79c-3,.52-6.13,1.28-6.13,1.28a34.19,34.19,0,0,1-4.09.82,24.47,24.47,0,0,1-7.1-.2,1.77,1.77,0,0,1-.37-.29" style="fill:#fff" />
#                 </svg>
#             </a>
#         </div>
#         <button class="main-header__toggler-button" id="js-side-menu-toggler" aria-label="Menu Toggler">
#             &#x2715;
#         </button>
#     </div>
#     <ul class="side-menu__group">
#         <li><a href="/ultimo-momento/"><span class="side-menu__subject">Último momento</span></a></li>
#                 <li>
#             <span class="side-menu__subject">Secciones</span>
#             <ul class="side-menu__channels">
#                                                 <li class="side-menu__item"><a href="https://www.perfil.com/ultimo-momento/" target="_self" class="ultimo-momento" title="Noticias de Último Momento" rel="noreferrer">Ahora</a></li>
#                                                                 <li class="side-menu__item side-menu__item--parent">
#                     <a href="https://www.perfil.com/columnistas/" target="_self" class="columnistas" title="Las ultimas notas de nuestros Columnistas" rel="noreferrer">Columnistas</a>
#                     <input type="checkbox" class="side-menu__item-toggler-checkbox" name="item-1" id="item-1">
#                     <label for="item-1" class="side-menu__item-button" id="label-menu"> <span class="chevron"></span> </label>
#                     <ul class="side-menu__item-children">
#                                                 <li><a href="/seccion/opinion/" target="_self" rel="noreferrer">Opinión</a></li>
#                                             </ul>
#                 </li>
#                                                                 <li class="side-menu__item"><a href="https://www.perfil.com/seccion/politica/" target="_self" class="politica" title="Noticais de Política" rel="noreferrer">Política</a></li>
#                                                                 <li class="side-menu__item side-menu__item--parent">
#                     <a href="https://www.perfil.com/seccion/economia/" target="_self" class="economia" title="Noticias de Economía" rel="noreferrer">Economía</a>
#                     <input type="checkbox" class="side-menu__item-toggler-checkbox" name="item-3" id="item-3">
#                     <label for="item-3" class="side-menu__item-button" id="label-menu"> <span class="chevron"></span> </label>
#                     <ul class="side-menu__item-children">
#                                                 <li><a href="https://www.perfil.com/seccion/pymes/" target="_self" rel="noreferrer">Pymes</a></li>
#                                             </ul>
#                 </li>
#                                                                 <li class="side-menu__item side-menu__item--parent">
#                     <a href="https://www.perfil.com/seccion/sociedad/" target="_self" class="sociedad" title="Noticias de Sociedad" rel="noreferrer">Sociedad</a>
#                     <input type="checkbox" class="side-menu__item-toggler-checkbox" name="item-4" id="item-4">
#                     <label for="item-4" class="side-menu__item-button" id="label-menu"> <span class="chevron"></span> </label>
#                     <ul class="side-menu__item-children">
#                                                 <li><a href="https://www.perfil.com/seccion/salud/" target="_self" rel="noreferrer">Salud</a></li>
#                                                 <li><a href="https://www.perfil.com/seccion/ciencia/" target="_self" rel="noreferrer">Ciencia</a></li>
#                                                 <li><a href="https://www.perfil.com/seccion/protagonistas/" target="_self" rel="noreferrer">Protagonistas</a></li>
#                                                 <li><a href="https://www.perfil.com/seccion/tecnologia/" target="_self" rel="noreferrer">Tecnología</a></li>
#                                                 <li><a href="https://www.perfil.com/seccion/cultura/" target="_self" rel="noreferrer">Cultura</a></li>
#                                                 <li><a href="https://www.perfil.com/seccion/arte/" target="_self" rel="noreferrer">Arte</a></li>
#                                                 <li><a href="https://www.perfil.com/seccion/educacion/" target="_self" rel="noreferrer">Educación</a></li>
#                                             </ul>
#                 </li>
#                                                                 <li class="side-menu__item"><a href="https://www.perfil.com/seccion/internacional" target="_self" class="internacional" title="Noticias Internaciolanes" rel="noreferrer">Internacional</a></li>
#                                                                 <li class="side-menu__item"><a href="https://www.perfil.com/seccion/clima" target="_self" class="" title="Clima" rel="noreferrer">Clima</a></li>
#                                                                 <li class="side-menu__item"><a href="https://442.perfil.com/" target="_self" class="deportes" title="Noticias de Deportes" rel="noreferrer">Deportes</a></li>
#                                                                 <li class="side-menu__item side-menu__item--parent">
#                     <a href="#" target="_self" class="ocio" title="Ocio" rel="noreferrer">Ocio</a>
#                     <input type="checkbox" class="side-menu__item-toggler-checkbox" name="item-8" id="item-8">
#                     <label for="item-8" class="side-menu__item-button" id="label-menu"> <span class="chevron"></span> </label>
#                     <ul class="side-menu__item-children">
#                                                 <li><a href="https://caras.perfil.com" target="_self" rel="noreferrer">CARAS</a></li>
#                                                 <li><a href="https://exitoina.perfil.com" target="_self" rel="noreferrer">Exitoina</a></li>
#                                                 <li><a href="https://www.perfil.com/seccion/turismo/" target="_self" rel="noreferrer">Turismo</a></li>
#                                                 <li><a href="https://www.perfil.com/seccion/video/" target="_self" rel="noreferrer">Videos</a></li>
#                                             </ul>
#                 </li>
#                                                                 <li class="side-menu__item"><a href="https://www.perfil.com/cordoba/" target="_self" class="cordoba" title="Noticias de Córdoba" rel="noreferrer">Córdoba</a></li>
#                                                                 <li class="side-menu__item"><a href="/reperfilar" target="_self" class="reperfilar" title="" rel="noreferrer">Reperfilar</a></li>
#                                                                 <li class="side-menu__item"><a href="https://www.perfil.com/seccion/bloomberg/" target="_self" class="bloomberg" title="Noticas de Bloomber" rel="noreferrer">Business</a></li>
#                                                                 <li class="side-menu__item"><a href="https://www.perfil.com/seccion/empresas-y-protagonistas" target="_self" class="" title="Empresas y Protagonistas" rel="noreferrer">Empresas y Protagonistas</a></li>
#                                                                 <li class="side-menu__item"><a href="https://noticias.perfil.com/" target="_blank" class="noticias" title="Revista Noticias" rel="noreferrer">Noticias</a></li>
#                                                                 <li class="side-menu__item"><a href="https://caras.perfil.com/" target="_blank" class="caras" title="Revista Caras" rel="noreferrer">Caras</a></li>
#                                                                 <li class="side-menu__item"><a href="https://exitoina.perfil.com" target="_blank" class="exitoina" title="Noticias de Exitoina" rel="noreferrer">Exitoina</a></li>
#                                                                 <li class="side-menu__item"><a href="https://www.perfil.com/seccion/gaming" target="_self" class="gaming" title="" rel="noreferrer">Gaming</a></li>
#                                                                 <li class="side-menu__item"><a href="https://www.perfil.com/seccion/vivo" target="_self" class="" title="" rel="noreferrer">Vivo</a></li>
#                                                                 <li class="side-menu__item"><a href="https://www.eldiariodeljuicio.com/" target="_self" class="" title="" rel="noreferrer">Diario del Juicio</a></li>
#                                             </ul>
#         </li>
#             </ul>
# </div>
#
# <div class="overlay" id="js-overlay"></div>
#
#
#         <div class="row reperfilar" id="page">
# 	<article class="article container" id="noticia">
# 		<div class="article__header max-width-md">
#     <div class="article__hat">
#         <div class="article__hat-channel">
#                                                             <a href="/reperfilar">REPERFILAR</a>
#         </div>
#                 <span class="article__hat-hat">Avance científico </span>
#                 <a href="#vf-comments" class="viafoura" aria-label="Ver comentarios">
#                 <svg xmlns="http://www.w3.org/2000/svg" fill="none" viewBox="0 0 24 24" stroke-width="1.5" stroke="currentColor" width="22" height="22">
# 					<path stroke-linecap="round" stroke-linejoin="round" d="M8.625 12a.375.375 0 1 1-.75 0 .375.375 0 0 1 .75 0Zm0 0H8.25m4.125 0a.375.375 0 1 1-.75 0 .375.375 0 0 1 .75 0Zm0 0H12m4.125 0a.375.375 0 1 1-.75 0 .375.375 0 0 1 .75 0Zm0 0h-.375M21 12c0 4.556-4.03 8.25-9 8.25a9.764 9.764 0 0 1-2.555-.337A5.972 5.972 0 0 1 5.41 20.97a5.969 5.969 0 0 1-.474-.065 4.48 4.48 0 0 0 .978-2.025c.09-.457-.133-.901-.467-1.226C3.93 16.178 3 14.189 3 12c0-4.556 4.03-8.25 9-8.25s9 3.694 9 8.25Z" />
# 				</svg>
#             <vf-conversations-count></vf-conversations-count>
#         </a>
#     </div>
#
#     <h1 class="article__title">Una mujer cuadripléjica volvió a hablar tras 18 años gracias a la Inteligencia Artificial</h1>
#         <h2 class="article__headline">
#         Se publicó en la revista científica Nature Neuroscience y representa un gran paso hacia la recuperación de la comunicación para personas con parálisis severa.
#             </h2>
#     </div>		<div class="col-fluid col-fluid-max col-fluid--clip">
# 			<div class="article__media">
#     <figure class="article__image" id="js-main-image">
#                  <picture class="cls-optimized">
#             <source media="(max-width: 570px)" srcset="https://fotos.perfil.com/2025/04/02/trim/570/321/una-mujer-cuadriplejica-volvio-a-hablar-tras-18-anos-gracias-a-la-inteligencia-artificial-1996489.jpg?webp" type="image/webp" />
#                 <source srcset="https://fotos.perfil.com/2025/04/02/trim/987/555/una-mujer-cuadriplejica-volvio-a-hablar-tras-18-anos-gracias-a-la-inteligencia-artificial-1996489.jpg?webp" type="image/webp" />
#                     <source media="(max-width: 570px)" srcset="https://fotos.perfil.com/2025/04/02/trim/570/321/una-mujer-cuadriplejica-volvio-a-hablar-tras-18-anos-gracias-a-la-inteligencia-artificial-1996489.jpg" />
#                 <img alt="Una mujer cuadripléjica volvió a hablar tras 18 años gracias a la Inteligencia Artificial" class="img-fluid" src="https://fotos.perfil.com/2025/04/02/trim/987/555/una-mujer-cuadriplejica-volvio-a-hablar-tras-18-anos-gracias-a-la-inteligencia-artificial-1996489.jpg" style="width: 100%" width="300" height="180" >
#         </picture>
#
#         <figcaption class="article__image-caption">Una mujer cuadripléjica volvió a hablar tras 18 años gracias a la Inteligencia Artificial<span class="credito-foto"> |
#                 Freepick</span></figcaption>
#     </figure>
#
# </div>
# 			 <div style="width: 100%;  max-height: 280px;  min-height: 90px; display: flex; flex-direction: column; align-items: center; margin: 10px auto 10px auto; overflow: hidden;" class="d-xs-none d-xxl-flex">
#     <div id="" class="ads-space d-xs-none d-xxl-flex" data-id="central_970x90x-pos-" data-w="970" data-h="90" data-loaded="false" data-reload="true"></div>
# </div>
#
#
# 			 <div style="width: 100%;  max-height: 250px;  min-height: 250px; display: flex; flex-direction: column; align-items: center; margin: 10px auto 10px auto; overflow: hidden;" class="d-lg-none">
#     <div id="" class="ads-space d-lg-none" data-id="central_300x250x-pos-" data-w="300" data-h="250" data-loaded="false" data-reload="true"></div>
# </div>
#
#
#
# 			<div class="article__main max-width-md">
# 				<div class="article__share">
# 	<ul>
# 		<li class="facebook">
# 			<a href="https://www.facebook.com/sharer/sharer.php?u=https://www.perfil.com/noticias/reperfilar/una-mujer-cuadriplejica-volvio-a-hablar-tras-18-anos-gracias-a-la-inteligencia-artificial.phtml" target="_blank" rel="noreferrer" aria-label="Compartir esta nota en Facebook">
# 			<svg  height="24" width="24" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 27.63 27.48"><path d="M945.07,551a12.85,12.85,0,0,1-12.8-12.92,13.06,13.06,0,1,1,26.12,0A13.31,13.31,0,0,1,945.07,551Z" transform="translate(-931.52 -524.27)" style="fill:none;stroke:#222;stroke-miterlimit:3;stroke-width:1.5px"/><path d="M949,541.27l.6-3.75H946v-2.63c0-1,.37-1.87,2-1.87h1.73v-3.45a20.46,20.46,0,0,0-3-.3c-3.08,0-4.25,1.87-4.25,5.25v3h-3.38v3.75h3.38v9.52a11.45,11.45,0,0,0,2.25.23c.75,0,.5-.08,1.25-.23v-9.52Z" transform="translate(-931.52 -524.27)" style="fill:#222"/></svg>
# 		</a>
# 		</li>
# 		<li class="twitter">
# 			<a href="https://twitter.com/intent/tweet?text=Una+mujer+cuadripl%C3%A9jica+volvi%C3%B3+a+hablar+tras+18+a%C3%B1os+gracias+a+la+Inteligencia+Artificial&url=https://www.perfil.com/noticias/reperfilar/una-mujer-cuadriplejica-volvio-a-hablar-tras-18-anos-gracias-a-la-inteligencia-artificial.phtml" target="_blank" rel="noreferrer" aria-label="Compartir esta nota en Twitter">
# 				<svg viewBox="0 0 24 24" aria-hidden="true" height="24" width="24">
# 					<g>
# 						<path d="M18.244 2.25h3.308l-7.227 8.26 8.502 11.24H16.17l-5.214-6.817L4.99 21.75H1.68l7.73-8.835L1.254 2.25H8.08l4.713 6.231zm-1.161 17.52h1.833L7.084 4.126H5.117z" fill="#222"></path>
# 					</g>
# 				</svg>
# 			</a>
# 		</li>
# 		<li class="whatsapp">
# 			<a href="whatsapp://send?text=Una+mujer+cuadripl%C3%A9jica+volvi%C3%B3+a+hablar+tras+18+a%C3%B1os+gracias+a+la+Inteligencia+Artificial https://www.perfil.com/noticias/reperfilar/una-mujer-cuadriplejica-volvio-a-hablar-tras-18-anos-gracias-a-la-inteligencia-artificial.phtml" data-action="share/whatsapp/share" target="_blank" rel="noreferrer" aria-label="Enviar enlace de esta nota por Whatsapp">
# ...
#     </div>
#     <div class="main-footer__redes">
#         <a href="https://www.facebook.com/perfilcom/" aria-label="Facebook" target="_blank" class="link-social-facebook" itemprop="sameAs" rel="noreferrer">
#             <svg width="22" height="22" viewBox="0 0 22 21.86">
#                 <path d="M22,11A11,11,0,1,0,8.93,21.8V13.46H6.43V10.25h2.5V7.49c0-2.37,1.26-3.61,4.07-3.61a11,11,0,0,1,2.62.39V7.41a7,7,0,0,0-2-.24c-.72,0-.87.29-.87,1v2h2.64v3.17H12.7v8.44A11,11,0,0,0,22,11Z" class="main-footer--contrast" />
#             </svg>
#         </a>
#
#         <a href="https://twitter.com/perfilcom" aria-label="X" target="_blank" class="link-social-twitter" itemprop="sameAs" rel="noreferrer">
#             <svg viewBox="0 0 22 22" aria-hidden="true" height="20" width="20">
#                 <g>
#                     <path d="M18.244 2.25h3.308l-7.227 8.26 8.502 11.24H16.17l-5.214-6.817L4.99 21.75H1.68l7.73-8.835L1.254 2.25H8.08l4.713 6.231zm-1.161 17.52h1.833L7.084 4.126H5.117z" class="main-footer--contrast"></path>
#                 </g>
#             </svg>
#         </a>
#
#         <a href="https://www.youtube.com/channel/perfilcom" aria-label="Youtube" target="_blank" class="link-social-youtube" itemprop="sameAs" rel="noreferrer">
#             <svg width="24" height="17" viewBox="0 0 23.95 16.87">
#                 <path d="M23.45,2.63A3,3,0,0,0,21.33.5C19.46,0,12,0,12,0S4.49,0,2.62.5A3,3,0,0,0,.5,2.63,31.67,31.67,0,0,0,0,8.44a31.58,31.58,0,0,0,.5,5.8,3,3,0,0,0,2.12,2.13c1.87.5,9.36.5,9.36.5s7.48,0,9.35-.5a3,3,0,0,0,2.12-2.13,31.58,31.58,0,0,0,.5-5.8A31.67,31.67,0,0,0,23.45,2.63ZM9.53,12V4.88l6.26,3.56Z" class="main-footer--contrast" />
#             </svg>
#         </a>
#
#         <a href="https://www.instagram.com/perfilcom/" aria-label="Instagram" target="_blank" class="link-social-instagram" itemprop="sameAs" rel="noreferrer">
#             <svg width="20" height="20" viewBox="0 0 20 20">
#                 <path d="M10,1.8c2.67,0,3,0,4,.06a5.61,5.61,0,0,1,1.86.34,3.33,3.33,0,0,1,1.9,1.9A5.61,5.61,0,0,1,18.14,6c.05,1,.06,1.37.06,4s0,3-.06,4a5.61,5.61,0,0,1-.34,1.86,3.33,3.33,0,0,1-1.9,1.9,5.61,5.61,0,0,1-1.86.34c-1,.05-1.37.06-4,.06s-3,0-4-.06A5.61,5.61,0,0,1,4.1,17.8a3.33,3.33,0,0,1-1.9-1.9A5.61,5.61,0,0,1,1.86,14c-.05-1-.06-1.37-.06-4s0-3,.06-4A5.61,5.61,0,0,1,2.2,4.1,3.33,3.33,0,0,1,4.1,2.2,5.61,5.61,0,0,1,6,1.86c1-.05,1.37-.06,4-.06M10,0C7.28,0,6.94,0,5.88.06A7.3,7.3,0,0,0,3.45.53,4.7,4.7,0,0,0,1.68,1.68,4.7,4.7,0,0,0,.53,3.45,7.3,7.3,0,0,0,.06,5.88C0,6.94,0,7.28,0,10s0,3.06.06,4.12a7.3,7.3,0,0,0,.47,2.43,4.7,4.7,0,0,0,1.15,1.77,4.85,4.85,0,0,0,1.77,1.16,7.59,7.59,0,0,0,2.43.46C6.94,20,7.28,20,10,20s3.06,0,4.12-.06a7.59,7.59,0,0,0,2.43-.46,5.19,5.19,0,0,0,2.93-2.93,7.59,7.59,0,0,0,.46-2.43c0-1.06.06-1.4.06-4.12s0-3.06-.06-4.12a7.59,7.59,0,0,0-.46-2.43,4.85,4.85,0,0,0-1.16-1.77A4.7,4.7,0,0,0,16.55.53,7.3,7.3,0,0,0,14.12.06C13.06,0,12.72,0,10,0" class="main-footer--contrast" />
#                 <path d="M10,4.86A5.14,5.14,0,1,0,15.14,10,5.14,5.14,0,0,0,10,4.86m0,8.47A3.33,3.33,0,1,1,13.33,10,3.33,3.33,0,0,1,10,13.33" class="main-footer--contrast" />
#                 <path d="M16.54,4.66a1.2,1.2,0,1,1-1.2-1.2,1.2,1.2,0,0,1,1.2,1.2" class="main-footer--contrast" />
#             </svg>
#         </a>
#
#         <a href="https://www.perfil.com/feed" aria-label="RSS" target="_blank" class="link-social-rss" rel="noreferrer">
#             <svg width="17" height="17" viewBox="0 0 17 17">
#                 <path d="M0,0V3.41a13.54,13.54,0,0,1,9.59,4,13.53,13.53,0,0,1,4,9.6H17A17,17,0,0,0,0,0Z" class="main-footer--contrast" />
#                 <path d="M2.3,12.4a2.3,2.3,0,1,0,2.31,2.3A2.3,2.3,0,0,0,2.3,12.4Z" class="main-footer--contrast" />
#                 <path d="M0,5.79V9.2A7.9,7.9,0,0,1,7.81,17h3.41A11.3,11.3,0,0,0,0,5.79Z" class="main-footer--contrast" />
#             </svg>
#         </a>
#
#         <a href="https://www.perfil.com/sitemap" aria-label="Sitemap" target="_blank" class="link-social-sitemap" rel="noreferrer">
#             <svg width="20" height="16" viewBox="0 0 19.84 15.13">
#                 <path d="M18.84,10.07H17.73V7.23h0V7.12H10.35V5.05h1.07a1,1,0,0,0,1-1V1a1,1,0,0,0-1-1h-3a1,1,0,0,0-1,1V4.05a1,1,0,0,0,1,1H9.49V7.12H2v.11H2v2.84H1a1,1,0,0,0-1,1v3.06a1,1,0,0,0,1,1H4a1,1,0,0,0,1-1V11.07a1,1,0,0,0-1-1H2.89V8h6.6v2.1H8.42a1,1,0,0,0-1,1v3.06a1,1,0,0,0,1,1h3a1,1,0,0,0,1-1V11.07a1,1,0,0,0-1-1H10.35V8h6.53v2.1h-1a1,1,0,0,0-1,1v3.06a1,1,0,0,0,1,1h3a1,1,0,0,0,1-1V11.07A1,1,0,0,0,18.84,10.07Z" class="main-footer--contrast" />
#             </svg>
#         </a>
#
#     </div>
#     <nav class="main-footer__nav max-width-md">
#         <ul class="footer-secciones">
#                         <li><a href="https://www.perfil.com/ultimo-momento/" target="_self" class="ultimo-momento" title="Noticias de Último Momento" rel="noreferrer">Ahora</a></li>
#                         <li><a href="https://www.perfil.com/columnistas/" target="_self" class="columnistas" title="Las ultimas notas de nuestros Columnistas" rel="noreferrer">Columnistas</a></li>
#                         <li><a href="https://www.perfil.com/seccion/politica/" target="_self" class="politica" title="Noticais de Política" rel="noreferrer">Política</a></li>
#                         <li><a href="https://www.perfil.com/seccion/economia/" target="_self" class="economia" title="Noticias de Economía" rel="noreferrer">Economía</a></li>
#                         <li><a href="https://www.perfil.com/seccion/sociedad/" target="_self" class="sociedad" title="Noticias de Sociedad" rel="noreferrer">Sociedad</a></li>
#                         <li><a href="https://www.perfil.com/seccion/internacional" target="_self" class="internacional" title="Noticias Internaciolanes" rel="noreferrer">Internacional</a></li>
#                         <li><a href="https://www.perfil.com/seccion/clima" target="_self" class="" title="Clima" rel="noreferrer">Clima</a></li>
#                         <li><a href="https://442.perfil.com/" target="_self" class="deportes" title="Noticias de Deportes" rel="noreferrer">Deportes</a></li>
#                         <li><a href="#" target="_self" class="ocio" title="Ocio" rel="noreferrer">Ocio</a></li>
#                         <li><a href="https://www.perfil.com/cordoba/" target="_self" class="cordoba" title="Noticias de Córdoba" rel="noreferrer">Córdoba</a></li>
#                         <li><a href="/reperfilar" target="_self" class="reperfilar" title="" rel="noreferrer">Reperfilar</a></li>
#                         <li><a href="https://www.perfil.com/seccion/bloomberg/" target="_self" class="bloomberg" title="Noticas de Bloomber" rel="noreferrer">Business</a></li>
#                         <li><a href="https://www.perfil.com/seccion/empresas-y-protagonistas" target="_self" class="" title="Empresas y Protagonistas" rel="noreferrer">Empresas y Protagonistas</a></li>
#                         <li><a href="https://noticias.perfil.com/" target="_blank" class="noticias" title="Revista Noticias" rel="noreferrer">Noticias</a></li>
#                         <li><a href="https://caras.perfil.com/" target="_blank" class="caras" title="Revista Caras" rel="noreferrer">Caras</a></li>
#                         <li><a href="https://exitoina.perfil.com" target="_blank" class="exitoina" title="Noticias de Exitoina" rel="noreferrer">Exitoina</a></li>
#                         <li><a href="https://www.perfil.com/seccion/gaming" target="_self" class="gaming" title="" rel="noreferrer">Gaming</a></li>
#                         <li><a href="https://www.perfil.com/seccion/vivo" target="_self" class="" title="" rel="noreferrer">Vivo</a></li>
#                         <li><a href="https://www.eldiariodeljuicio.com/" target="_self" class="" title="" rel="noreferrer">Diario del Juicio</a></li>
#                     </ul>
#
#         <ul class="footer-revistas">
#                         <li class="rev-caras"><a href="https://caras.perfil.com/" target="_blank" title="Revista Caras" rel="noreferrer">Caras</a></li>
#                         <li class="rev-noticias"><a href="https://noticias.perfil.com/" target="_blank" title="Revista Noticias" rel="noreferrer">Noticias</a></li>
#                         <li class="rev-weekend"><a href="https://weekend.perfil.com" target="_blank" title="Revista Weekend" rel="noreferrer">Weekend</a></li>
#                         <li class=""><a href="https://fortuna.perfil.com" target="_blank" title="" rel="noreferrer">Fortuna</a></li>
#                         <li class="rev-parabrisas"><a href="http://parabrisas.perfil.com" target="_blank" title="Revista Parabrisas" rel="noreferrer">Parabrisas</a></li>
#                         <li class="rev-rouge"><a href="https://rouge.perfil.com/" target="_blank" title="Venus el Leo: alimentá tu deseo" rel="noreferrer">Rouge</a></li>
#                         <li class="rev-mia"><a href="http://mia.perfil.com" target="_blank" title="Revista Mía" rel="noreferrer">Mía</a></li>
#                         <li class="rev-batimes"><a href="http://batimes.com.ar" target="_blank" title="Diario Buenos Aires Times" rel="noreferrer">BATimes</a></li>
#                         <li class=""><a href="https://horizonte.perfil.com" target="_blank" title="" rel="noreferrer">FM Horizonte</a></li>
#                     </ul>
#
#         <ul class="footer-revistas">
#             <li><a href="https://brasil.perfil.com/" target="_blank" title="Perfil Brasil" rel="noreferrer"><strong>Perfil Brasil:</strong></a></li>
#             <li><a href="https://caras.com.br/" target="_blank" title="Caras" rel="noreferrer">Caras</a></li>
#             <li><a href="https://contigo.com.br/" target="_blank" title="Contigo" rel="noreferrer">Contigo</a></li>
#             <li><a href="https://aventurasnahistoria.com.br/" target="_blank" title="Aventuras na historia" rel="noreferrer">Aventuras Na Historia</a></li>
#             <li><a href="https://rollingstone.com.br/" target="_blank" title="Rolling Stone" rel="noreferrer">Rolling Stone</a></li>
#             <li><a href="https://sportbuzz.com.br/" target="_blank" title="SportBuzz" rel="noreferrer">Sport Buzz</a></li>
#             <li><a href="https://recreio.com.br/" target="_blank" title="Recreio" rel="noreferrer">Recreio</a></li>
#             <li><a href="https://revistamaxima.com.br/" target="_blank" title="Maxima" rel="noreferrer">Maxima</a></li>
#         </ul>
#
#         <ul class="footer-fijas">
#             <li><a href="https://www.perfil.com/canales-rss">Canales RSS</a></li>
#             <li><a href="https://www.perfil.com/static/docs/brochure_perfil.pdf">Quienes Somos</a></li>
#             <li><a href="/cdn-cgi/l/email-protection#bfdadbd6cbd0cddacc91d0d1d3d6d1daffd8d2ded6d391dcd0d2" rel="noreferrer">Contáctenos</a></li>
#             <li><a href="https://www.perfil.com/terminos-privacidad">Privacidad</a></li>
#             <li><a href="https://www.perfil.com/staff">Equipo</a></li>
#             <li><a href="https://www.perfil.com/reglas-participacion">Reglas de participación</a></li>
#             <li><a href="https://www.perfil.com/transito">Tránsito</a></li>
#         </ul>
#     </nav>
#
#     <div class="main-footer__disclaimer">
#         <span itemprop="name">Perfil.com - Editorial Perfil S.A.</span> | © Perfil.com 2006-2025 - Todos los derechos reservados.<br />
#         Editor responsable: Carlos Piro.<br>
#         Registro de la propiedad intelectual RL-2024-31002957-APN-DNDA#MJ <span id="main-footer__edicion"></span> <br />
#         <div class="d-none d-xl-block" itemprop="address" itemscope itemtype="https://schema.org/PostalAddress">
#             Dirección: <span itemprop="streetAddress">California 2715</span>, <span itemprop="postalCode">C1289ABI</span>, <span itemprop="addressLocality">CABA, Argentina</span> | Teléfono: <span itemprop="telephone">(+5411) 7091-4921</span> / <span itemprop="telephone">(+5411) 7091-4922</span> | E-mail: <a href="/cdn-cgi/l/email-protection#f181948397989d929e9cb181948397989ddf929e9c" rel="noreferrer"><span itemprop="email"><span class="__cf_email__" data-cfemail="ccbca9beaaa5a0afa3a18cbca9beaaa5a0e2afa3a1">[email&#160;protected]</span></span></a><br>
#         </div>
#     </div>
# </footer>
#                 <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js"></script><script defer type="text/javascript" src="/js/viafoura.js?id=8849327a2d639d6d26c1"></script>
#         	<script type="text/javascript">
# 		window.paywallConfig.contentType = 'articulo';
# 			window.paywallConfig.type = window.sharedData.paywall.type;
# 			window.perfilContent = {
# 				id: window.sharedData.paywall.content_id,
# 				url: window.sharedData.paywall.content_canonical_url,
# 				canal: window.sharedData.paywall.content_canal,
# 				title: window.sharedData.paywall.content_title,
# 				show_metered_paywall: window.sharedData.paywall.show_metered_modal,
# 				paywall_type: window.sharedData.paywall.type,
# 				date: window.sharedData.paywall.content_date,
# 				body_length: window.sharedData.paywall.content_length,
# 				author: {
# 					id: window.sharedData.paywall.author_id,
# 					username: window.sharedData.paywall.author_username,
# 					fullname: window.sharedData.paywall.author_fullname
# 				}
# 			}
# 	</script>
#         <script defer type="text/javascript" src="/js/mi-perfil.js?id=507e8f3162733d0f1b85"></script>
#         	<script defer type="text/javascript" src="/js/news-show.js?id=73acc783e6122c42b2c5"></script>
# 			<script defer type="text/javascript"
# 				src="https://ads.us.e-planning.net/eb/3/24a92/reperfilar_articulo/teads?o=j&crs=UTF-8"></script>
# 				<script defer type="text/javascript" src="https://widgets.outbrain.com/outbrain.js"></script>
# 	            <script defer type="text/javascript" src="https://widgets.outbrain.com/outbrain.js"></script>
#
#         <script type="text/javascript">
#           var _rl_cn = _rl_cn || 0,_rl_ptc = ("https:" == window.location.protocol ? "https" : "http"); window._rl_ids = window._rl_ids || []; window._rely = window._rely || []; _rl_ids.push({pid:909,src:0}); _rely.send = _rely.send?_rely.send:function() {}; (function() { var rl = document.createElement("script"); rl.type = "text/javascript"; rl.defer = true; rl.src = _rl_ptc + "://api.retargetly.com/loader?id=" + _rl_ids[_rl_ids.length-1].pid; rl.id = "rely-api-"+(_rl_cn++); var s = document.getElementsByTagName("script")[0]; s.parentNode.insertBefore(rl, s); })();
#         </script>
#
#
#                     <script type="text/javascript">var eplDoc = document; var eplLL = false;</script>
#             <script type="text/javascript">
#                 var eplanning_exclude_refresh = ['central_300x250x4', 'sidebar_300x250x1'];
#             </script>
#             <script defer src="/js/eplanning.js?id=df2dd3c140a7aeea0609"></script>
#
#
#         <!-- Hotjar Tracking Code for https://www.perfil.com -->
#         <script>
#           (function(h,o,t,j,a,r){
#             h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};
#             h._hjSettings={hjid:3412531,hjsv:6};
#             a=o.getElementsByTagName('head')[0];
#             r=o.createElement('script');r.async=1;
#             r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;
#             a.appendChild(r);
#           })(window,document,'https://static.hotjar.com/c/hotjar-','.js?sv=');
#         </script>
#
#         <script>
#             function togglePwInfo() {
#                 let pwInfo = document.getElementById('js-pw-logged-info');
#                 pwInfo.classList.toggle('active');
#             }
#         </script>
#
#          <div style="width: 100%;  min-height: 1px; display: flex; flex-direction: column; align-items: center; margin: 0px auto 0px auto; overflow: hidden;" class="">
#     <div id="" class="ads-space " data-id="layer" data-w="1" data-h="1" data-loaded="false" data-reload="false"></div>
# </div>
#
#
#          <div style="width: 100%;  min-height: 1px; display: flex; flex-direction: column; align-items: center; margin: 0px auto 0px auto; overflow: hidden;" class="">
#     <div id="" class="ads-space " data-id="anuncioprevio" data-w="1" data-h="1" data-loaded="false" data-reload="false"></div>
# </div>
#
#
#
#     </body>
# </html>

# %%
soup = BeautifulSoup(contenido, "html.parser")

# %%
from collections import Counter

# %%
parrafos = str(soup.find_all("p"))

# %%
print(parrafos)
# Out:
# [<p><strong>Ann, una mujer de 47 años con cuadriplejía, logró hablar nuevamente luego de 18 años gracias a una neuroprótesis impulsada por <a href="https://www.perfil.com/noticias/canal-e/di-domenica-argentina-necesita-una-politica-integral-nacional-que-plantee-una-estrategia-a-mediano-y-largo-plazo.phtml" target="_blank">inteligencia artificial (IA)</a>,</strong> en uno de los avances más significativos en el campo de las <a href="https://www.perfil.com/noticias/opinion/argentina-podria-ser-una-potencia-en-inteligencia-artificial-pero-falta-algo.phtml" target="_blank">interfaces cerebro-computadora</a>. El procedimiento, desarrollado por investigadores de la Universidad de California en Berkeley y San Francisco, se publicó en la <strong>revista científica <em>Nature Neuroscience</em> y representa un gran paso hacia la recuperación de la comunicación para personas con parálisis severa.</strong></p>, <p>El dispositivo que hizo posible <strong>este hito consiste en una lámina delgada con 253 electrodos, implantada sobre la corteza cerebral de Ann.</strong> Esta neuroprótesis registró su actividad neuronal y envió las señales a una computadora, que transformó sus pensamientos en palabras audibles con una voz artificial personalizad<strong>a. Para reconstruir su tono original, los investigadores utilizaron grabaciones de un video de su boda, antes de que Ann</strong> sufriera un accidente cerebrovascular (ACV) a los 30 años que le quitó la capacidad de hablar y moverse.</p>, <p>A diferencia de los sistemas anteriores, que solo generaban sonido una vez que el paciente terminaba una frase entera, esta nueva interfaz cerebro-computadora permite convertir los pensamientos en voz en apenas tres segundos, casi en tiempo real. <strong>Los científicos explicaron que este avance tecnológico mejora notablemente el flujo natural de una conversación, </strong>algo esencial para que las personas con parálisis puedan interactuar con su entorno sin sentirse aisladas o frustradas.</p>, <p>Durante el entrenamiento del sistema, <strong>Ann leyó mentalmente alrededor de 100 frases seleccionadas de un conjunto de más de mil oraciones.</strong> Mientras tanto, el dispositivo registraba su actividad cerebral cada 80 milisegundos, incluso comenzando medio segundo antes de que ella intentara articular las palabras de manera silenciosa. <strong>El modelo logró generar entre 47 y 90 palabras por minuto, una cifra que, si bien no alcanza la velocidad de una conversación típica</strong> (que ronda las 160 palabras por minuto), supera ampliamente lo logrado hasta ahora con este tipo de tecnología.</p>, <p>El avance se basó en algoritmos de inteligencia artificial similares a los que utilizan asistentes virtuales como Siri o Alexa, adaptados para decodificar en tiempo real las señales cerebrales. <strong>Los investigadores explicaron que el mismo algoritmo podría usarse en distintos dispositivos, siempre que haya una buena calidad de señal neuronal.</strong> Además, el equipo está trabajando en mejorar la expresividad de la voz sintetizada, incorporando matices emocionales como variaciones de tono, timbre o volumen.</p>, <p>Ann había participado en estudios anteriores con tecnologías similares, pero ninguna había logrado una comunicación tan fluida. Hasta ahora, <strong>se valía de un sistema de asistencia que le llevaba más de 20 segundos para emitir una sola frase</strong>. Con esta nueva herramienta, no solo recuperó parte de su capacidad para comunicarse, sino también una parte fundamental de su identidad: su voz.</p>, <p>Este desarrollo representa un paso clave hacia la inclusión y la dignidad de las personas con discapacidades severas, abriendo nuevas oportunidades para que puedan participar activamente en conversaciones cotidianas. Aunque todavía está en etapa experimental, el éxito de esta tecnología alimenta la esperanza de que muy pronto más pacientes puedan beneficiarse de soluciones similares.</p>]

# %%
print(parrafos.count("inteligencia"))
# Out:
# 3

# %%
# Funcion para buscar palabras
def buscar_palabra(palabra):
  ocurrencias = str(soup).lower().count(palabra.lower())
  print(f"Encontraste la palabra '{palabra}' {ocurrencias} veces")

# %%
buscar_palabra("inteligencia")
# Out:
# Encontraste la palabra 'inteligencia' 47 veces

# %%
import random

# %%
parrafo = soup.find_all("p")
parrafo_aleatorio = random.choice(parrafo).text.strip()

# %%
print(parrafo_aleatorio)
# Out:
# Durante el entrenamiento del sistema, Ann leyó mentalmente alrededor de 100 frases seleccionadas de un conjunto de más de mil oraciones. Mientras tanto, el dispositivo registraba su actividad cerebral cada 80 milisegundos, incluso comenzando medio segundo antes de que ella intentara articular las palabras de manera silenciosa. El modelo logró generar entre 47 y 90 palabras por minuto, una cifra que, si bien no alcanza la velocidad de una conversación típica (que ronda las 160 palabras por minuto), supera ampliamente lo logrado hasta ahora con este tipo de tecnología.

# %%
print(len(parrafo_aleatorio.split()))
# Out:
# 89

# %%
from wordcloud import WordCloud
import numpy as np
from PIL import Image
import nltk
from nltk.corpus import stopwords
import re

# %%
import matplotlib.pyplot as plt

# %%
# Descarga corpus de stopwords en español
nltk.download('stopwords')
stopwords_es = set(stopwords.words('spanish'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#funcion para limpiar texto
def limpiar_texto(texto):
  palabra_a_eliminar= ['dijo', 'así', 'aunque', 'sino', 'luego', 'pues', 'mientras',
        'después', 'antes', 'porque', 'cuando', 'cómo', 'donde', 'cap',
        'capítulo', 'verso', 'canto', 'á', 'ó','si','oh','allí','cuanto','cerca','parece','ay','p','quien','sido','dice','quién','dio','se','tan']

#Anexa las palabras que queremos eliminar a la lista de Stopwords
  black_list = stopwords_es.union(palabra_a_eliminar)
  texto_minuscula = texto.lower()
  texto_limpio = re.sub(r'[^\w\s]', '', texto_minuscula)
  palabras = texto_limpio.split()
  palabras_importantes =[]
  for palabra in palabras:
    if palabra not in black_list:
      palabras_importantes.append(palabra)
  return(palabras_importantes)

texto_completo = soup.get_text()
palabras_limpias = limpiar_texto(texto_completo)
texto_limpio = ' '.join(palabras_limpias)

# %%
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(texto_limpio)

# %%
wordcloud = WordCloud(width=800, height=400, background_color="black", colormap = "magma").generate(texto_limpio)
plt.figure(figsize=(15, 10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
#cargo el modelo
nlp =spacy.load("es_core_news_lg")
import es_core_news_lg
nlp = es_core_news_lg.load()

# %%
doc = nlp(texto_limpio) #tokenizacion

# %%
tokens = [token.text for token in doc]
print(tokens)
# Out:
# ['mujer', 'cuadripléjica', 'volvió', 'hablar', 'tras', '18', 'años', 'gracias', 'inteligencia', 'artificial', 'perfil', 'jueves', '03', 'abril', '2025', 'business', 'noticias', 'caras', 'exitoína', 'perfil', 'brasil', 'últimas', 'noticias', 'política', 'opinión', 'sociedad', 'ingresar', 'suscribite', '20día', 'último', 'momento', 'secciones', 'ahora', 'columnistas', 'opinión', 'política', 'economía', 'pymes', 'sociedad', 'salud', 'ciencia', 'protagonistas', 'tecnología', 'cultura', 'arte', 'educación', 'internacional', 'clima', 'deportes', 'ocio', 'caras', 'exitoina', 'turismo', 'videos', 'córdoba', 'reperfilar', 'business', 'empresas', 'protagonistas', 'noticias', 'caras', 'exitoina', 'gaming', 'vivo', 'diario', 'juicio', 'reperfilar', 'avance', 'científico', 'mujer', 'cuadripléjica', 'volvió', 'hablar', 'tras', '18', 'años', 'gracias', 'inteligencia', 'artificial', 'publicó', 'revista', 'científica', 'nature', 'neuroscience', 'representa', 'gran', 'paso', 'hacia', 'recuperación', 'comunicación', 'personas', 'parálisis', 'severa', 'mujer', 'cuadripléjica', 'volvió', 'hablar', 'tras', '18', 'años', 'gracias', 'inteligencia', 'artificial', 'freepick', 'ayer', '1105', 'ann', 'mujer', '47', 'años', 'cuadriplejía', 'logró', 'hablar', 'nuevamente', '18', 'años', 'gracias', 'neuroprótesis', 'impulsada', 'inteligencia', 'artificial', 'ia', 'avances', 'significativos', 'campo', 'interfaces', 'cerebrocomputadora', 'procedimiento', 'desarrollado', 'investigadores', 'universidad', 'california', 'berkeley', 'san', 'francisco', 'publicó', 'revista', 'científica', 'nature', 'neuroscience', 'representa', 'gran', 'paso', 'hacia', 'recuperación', 'comunicación', 'personas', 'parálisis', 'severa', 'dispositivo', 'hizo', 'posible', 'hito', 'consiste', 'lámina', 'delgada', '253', 'electrodos', 'implantada', 'corteza', 'cerebral', 'ann', 'neuroprótesis', 'registró', 'actividad', 'neuronal', 'envió', 'señales', 'computadora', 'transformó', 'pensamientos', 'palabras', 'audibles', 'voz', 'artificial', 'personalizada', 'reconstruir', 'tono', 'original', 'investigadores', 'utilizaron', 'grabaciones', 'video', 'boda', 'ann', 'sufriera', 'accidente', 'cerebrovascular', 'acv', '30', 'años', 'quitó', 'capacidad', 'hablar', 'moverse', 'diferencia', 'sistemas', 'anteriores', 'solo', 'generaban', 'sonido', 'vez', 'paciente', 'terminaba', 'frase', 'entera', 'nueva', 'interfaz', 'cerebrocomputadora', 'permite', 'convertir', 'pensamientos', 'voz', 'apenas', 'tres', 'segundos', 'casi', 'tiempo', 'real', 'científicos', 'explicaron', 'avance', 'tecnológico', 'mejora', 'notablemente', 'flujo', 'natural', 'conversación', 'esencial', 'personas', 'parálisis', 'puedan', 'interactuar', 'entorno', 'sentirse', 'aisladas', 'frustradas', 'gusta', 'autoritarios', 'ejercicio', 'periodismo', 'profesional', 'crítico', 'pilar', 'fundamental', 'democracia', 'molesta', 'creen', 'ser', 'dueños', 'verdad', 'hoy', 'nunca', 'suscribite', 'entrenamiento', 'sistema', 'ann', 'leyó', 'mentalmente', 'alrededor', '100', 'frases', 'seleccionadas', 'conjunto', 'mil', 'oraciones', 'dispositivo', 'registraba', 'actividad', 'cerebral', 'cada', '80', 'milisegundos', 'incluso', 'comenzando', 'medio', 'segundo', 'intentara', 'articular', 'palabras', 'manera', 'silenciosa', 'modelo', 'logró', 'generar', '47', '90', 'palabras', 'minuto', 'cifra', 'bien', 'alcanza', 'velocidad', 'conversación', 'típica', 'ronda', '160', 'palabras', 'minuto', 'supera', 'ampliamente', 'logrado', 'ahora', 'tipo', 'tecnología', 'avance', 'basó', 'algoritmos', 'inteligencia', 'artificial', 'similares', 'utilizan', 'asistentes', 'virtuales', 'siri', 'alexa', 'adaptados', 'decodificar', 'tiempo', 'real', 'señales', 'cerebrales', 'investigadores', 'explicaron', 'mismo', 'algoritmo', 'podría', 'usarse', 'distintos', 'dispositivos', 'siempre', 'buena', 'calidad', 'señal', 'neuronal', 'además', 'equipo', 'trabajando', 'mejorar', 'expresividad', 'voz', 'sintetizada', 'incorporando', 'matices', 'emocionales', 'variaciones', 'tono', ...

# %%
# Lematizacion: forma base (raiz) de cada token
for token in doc:
  #ignoramos puntuacion y espacios para mayor claridad
  if not token.is_punct and not token.is_space:
    print(f"{token.text}, {token.lemma_}")
# Out:
# mujer, mujer
# cuadripléjica, cuadripléjico
# volvió, volver
# hablar, hablar
# tras, tras
# 18, 18
# años, año
# gracias, gracias
# inteligencia, inteligencia
# artificial, artificial
# perfil, perfil
# jueves, jueves
# 03, 03
# abril, abril
# 2025, 2025
# business, business
# noticias, noticia
# caras, caro
# exitoína, exitoíno
# perfil, perfil
# brasil, brasil
# últimas, último
# noticias, noticia
# política, político
# opinión, opinión
# sociedad, sociedad
# ingresar, ingresar
# suscribite, suscribite
# 20día, 20día
# último, último
# momento, momento
# secciones, sección
# ahora, ahora
# columnistas, columnista
# opinión, opinión
# política, político
# economía, economío
# pymes, pym
# sociedad, sociedad
# salud, salud
# ciencia, ciencia
# protagonistas, protagonista
# tecnología, tecnologío
# cultura, cultura
# arte, arte
# educación, educación
# internacional, internacional
# clima, clima
# deportes, deportes
# ocio, ocio
# caras, cara
# exitoina, exitoín
# turismo, turismo
# videos, videos
# córdoba, córdoba
# reperfilar, reperfilar
# business, business
# empresas, empresa
# protagonistas, protagonista
# noticias, noticia
# caras, caro
# exitoina, exitoín
# gaming, gaming
# vivo, vivo
# diario, diario
# juicio, juicio
# reperfilar, reperfilar
# avance, avance
# científico, científico
# mujer, mujer
# cuadripléjica, cuadripléjico
# volvió, volver
# hablar, hablar
# tras, tras
# 18, 18
# años, año
# gracias, gracias
# inteligencia, inteligencia
# artificial, artificial
# publicó, publicar
# revista, revista
# científica, científico
# nature, nature
# neuroscience, neuroscience
# representa, representar
# gran, gran
# paso, paso
# hacia, hacia
# recuperación, recuperación
# comunicación, comunicación
# personas, persona
# parálisis, parálisis
# severa, severo
# mujer, mujer
# cuadripléjica, cuadripléjico
# volvió, volver
# hablar, hablar
# tras, tras
# 18, 18
# años, año
# gracias, gracias
# inteligencia, inteligencia
# artificial, artificial
# freepick, freepick
# ayer, ayer
# 1105, 1105
# ann, ann
# mujer, mujer
# 47, 47
# años, año
# cuadriplejía, cuadriplejía
# logró, lograr
# hablar, hablar
# nuevamente, nuevamente
# 18, 18
# años, año
# gracias, gracias
# neuroprótesis, neuroprótesis
# impulsada, impulsado
# inteligencia, inteligencia
# artificial, artificial
# ia, ia
# avances, avance
# significativos, significativo
# campo, campo
# interfaces, interfaces
# cerebrocomputadora, cerebrocomputadoro
# procedimiento, procedimiento
# desarrollado, desarrollado
# investigadores, investigador
# universidad, universidad
# california, california
# berkeley, berkeley
# san, san
# francisco, francisco
# publicó, publicar
# revista, revista
# científica, científico
# nature, nature
# neuroscience, neuroscience
# representa, representar
# gran, gran
# paso, paso
# hacia, hacia
# recuperación, recuperación
# comunicación, comunicación
# personas, persona
# parálisis, parálisis
# severa, severo
# dispositivo, dispositivo
# hizo, hacer
# posible, posible
# hito, hito
# consiste, consistir
# lámina, lámina
# delgada, delgado
# 253, 253
# electrodos, electrodo
# implantada, implantado
# corteza, corteza
# cerebral, cerebral
# ann, ann
# neuroprótesis, neuroprótesis
# registró, registrar
# actividad, actividad
# neuronal, neuronal
# envió, enviar
# señales, señal
# computadora, computadoro
# transformó, transformar
# pensamientos, pensamiento
# palabras, palabra
# audibles, audibl
# voz, voz
# artificial, artificial
# personalizada, personalizado
# reconstruir, reconstruir
# tono, tono
# original, original
# investigadores, investigador
# utilizaron, utilizar
# grabaciones, grabación
# video, video
# boda, boda
# ann, ann
# sufriera, sufrir
# accidente, accidente
# cerebrovascular, cerebrovascular
# acv, acv
# 30, 30
# años, año
# quitó, quitar
# capacidad, capacidad
# hablar, hablar
# moverse, mover él
# diferencia, diferencia
# sistemas, sistema
# anteriores, anterior
# solo, solo
# generaban, generar
# sonido, sonido
# vez, vez
# paciente, paciente
# terminaba, terminar
# frase, frase
# entera, entero
# nueva, nuevo
# interfaz, interfaz
# cerebrocomputadora, cerebrocomputadoro
# permite, permitir
# convertir, convertir
# pensamientos, pensamiento
# voz, voz
# apenas, apenas
# tres, tres
# segundos, segundo
# casi, casi
# tiempo, tiempo
# real, real
# científicos, científico
# explicaron, explicar
# avance, avance
# tecnológico, tecnológico
# mejora, mejorar
# notablemente, notablemente
# flujo, flujo
# natural, natural
# conversación, conversación
# esencial, esencial
# personas, persona
# parálisis, parálisis
# puedan, poder
# interactuar, interactuar
# entorno, entorno
# sentirse, sentir él
# aisladas, aislado
# frustradas, frustrado
# gusta, gustar
# autoritarios, autoritario
# ejercicio, ejercicio
# periodismo, periodismo
# profesional, profesional
# crítico, crítico
# pilar, pilar
# fundamental, fundamental
# democracia, democracia
# molesta, molesto
# creen, creer
# ser, ser
# dueños, dueño
# verdad, verdad
# hoy, hoy
# nunca, nunca
# suscribite, suscribitir
# entrenamiento, entrenamiento
# sistema, sistema
# ann, ann
# leyó, leer
# mentalmente, mentalmente
# alrededor, alrededor
# 100, 100
# frases, frase
# seleccionadas, seleccionado
# conjunto, conjunto
# mil, mil
# oraciones, oración
# dispositivo, dispositivo
# registraba, registrar
# actividad, actividad
# cerebral, cerebral
# cada, cada
# 80, 80
# milisegundos, milisegundo
# incluso, incluso
# comenzando, comenzar
# medio, medio
# segundo, segundo
# intentara, intentar
# articular, articular
# palabras, palabra
# manera, manera
# silenciosa, silencioso
# modelo, modelo
# logró, lograr
# generar, generar
# 47, 47
# 90, 90
# palabras, palabra
# minuto, minuto
# cifra, cifro
# bien, bien
# alcanza, alcanzar
# velocidad, velocidad
# conversación, conversación
# típica, típico
# ronda, ronda
# 160, 160
# palabras, palabra
# minuto, minuto
# supera, superar
# ampliamente, ampliamente
# logrado, logrado
# ahora, ahora
# tipo, tipo
# tecnología, tecnologío
# avance, avance
# basó, basar
# algoritmos, algoritmo
# inteligencia, inteligencia
# artificial, artificial
# similares, similar
# utilizan, utilizar
# asistentes, asistente
# virtuales, virtual
# siri, siri
# alexa, alexa
# adaptados, adaptado
# decodificar, decodificar
# tiempo, tiempo
# real, real
# señales, señal
# cerebrales, cerebral
# investigadores, investigador
# explicaron, explicar
# mismo, mismo
# algoritmo, algoritmo
# podría, poder
# usarse, usar él
# distintos, distinto
# dispositivos, dispositivo
# siempre, siempre
# buena, buen
# calidad, calidad
# señal, señal
# neuronal, neuronal
# además, además
# equipo, equipo
# trabajando, trabajar
# mejorar, mejorar
# expresividad, expresividad
# voz, voz
# sintetizada, sintetizado
# incorporando, incorporar
# matices, matiz
# emocionales, emocional
# variaciones, variación
# tono, tono
# timbre, timbre
# volumen, volumen
# ann, ann
# participado, participado
# estudios, estudio
# anteriores, anterior
# tecnologías, tecnología
# similares, similar
# ninguna, ninguno
# logrado, logrado
# comunicación, comunicación
# fluida, fluido
# ahora, ahora
# valía, valer
# sistema, sistema
# asistencia, asistencia
# llevaba, llevar
# 20, 20
# segundos, segundo
# emitir, emitir
# sola, solo
# frase, frase
# nueva, nuevo
# herramienta, herramienta
# solo, solo
# recuperó, recuperar
# parte, parte
# capacidad, capacidad
# comunicarse, comunicar él
# parte, parte
# fundamental, fundamental
# identidad, identidad
# voz, voz
# desarrollo, desarrollo
# representa, representar
# paso, paso
# clave, clave
# hacia, hacia
# inclusión, inclusión
# dignidad, dignidad
# personas, persona
# discapacidades, discapacidad
# severas, severo
# abriendo, abrir
# nuevas, nuevo
# oportunidades, oportunidad
# puedan, poder
# participar, participar
# activamente, activamente
# conversaciones, conversación
# cotidianas, cotidiano
# todavía, todavía
# etapa, etapa
# experimental, experimental
# éxito, éxito
# tecnología, tecnologío
# alimenta, alimentar
# esperanza, esperanza
# pronto, pronto
# pacientes, paciente
# puedan, poder
# beneficiarse, beneficiar él
# soluciones, solución
# similares, similar
# puede, poder
# interesar, interesar
# quiénes, quién
# seis, seis
# argentinos, argentino
# ricos, rico
# mundo, mundo
# comenzó, comenzar
# vacunación, vacunación
# gripe, gripe
# caba, car
# mujer, mujer
# cuadripléjica, cuadripléjico
# volvió, volver
# hablar, hablar
# inteligencia, inteligencia
# artificial, artificial
# 18, 18
# años, año
# córdoba, córdoba
# cárcel, cárcel
# máxima, máximo
# seguridad, seguridad
# construirá, construir
# 1000, 1000
# presos, preso
# nota, notar
# inteligencia, inteligencia
# artificial, artificial
# mujer, mujer
# cuadripléjica, cuadripléjico
# ahora, ahora
# columnistas, columnista
# política, político
# economía, economío
# sociedad, sociedad
# internacional, internacional
# clima, clima
# deportes, deportes
# ocio, ocio
# córdoba, córdoba
# reperfilar, reperfilar
# business, business
# empresas, empresa
# protagonistas, protagonista
# noticias, noticia
# caras, caro
# exitoina, exitoín
# gaming, gaming
# vivo, vivo
# diario, diario
# juicio, juicio
# caras, cara
# noticias, noticia
# weekend, weekend
# fortuna, fortuna
# parabrisas, parabrisas
# rouge, rouge
# batimes, batimes
# fm, fm
# horizonte, horizonte
# perfil, perfil
# brasil, brasil
# caras, caras
# contigo, contigo
# aventuras, aventura
# na, na
# historia, historia
# rolling, rolling
# stone, stone
# sport, sport
# buzz, buzz
# recreio, recreio
# maxima, maxima
# canales, canales
# rss, rss
# contáctenos, contácteno
# privacidad, privacidad
# equipo, equipo
# reglas, regla
# participación, participación
# tránsito, tránsito
# perfilcom, perfilcom
# editorial, editorial
# perfil, perfil
# sa, sa
# perfilcom, perfilcom
# 20062025, 20062025
# derechos, derecho
# reservados, reservado
# editor, editor
# responsable, responsable
# carlos, carlos
# piro, piro
# registro, registro
# propiedad, propiedad
# intelectual, intelectual
# rl202431002957apndndamj, rl202431002957apndndamj
# dirección, dirección
# california, california
# 2715, 2715
# c1289abi, c1289abi
# caba, car
# argentina, argentino
# teléfono, teléfono
# 5411, 5411
# 70914921, 70914921
# 5411, 5411
# 70914922, 70914922
# email, email
# email, email
# protected, protected

# %%
# Etiquetado gramatical
for token in doc:
    if not token.is_space: # Ignoramos espacios
        print(f"'{token.text}' -> {token.pos_} ({spacy.explain(token.pos_)}) -> {token.tag_}")
# Out:
# 'mujer' -> NOUN (noun) -> NOUN
# 'cuadripléjica' -> ADJ (adjective) -> ADJ
# 'volvió' -> VERB (verb) -> VERB
# 'hablar' -> VERB (verb) -> VERB
# 'tras' -> ADP (adposition) -> ADP
# '18' -> NUM (numeral) -> NUM
# 'años' -> NOUN (noun) -> NOUN
# 'gracias' -> ADP (adposition) -> ADP
# 'inteligencia' -> NOUN (noun) -> NOUN
# 'artificial' -> ADJ (adjective) -> ADJ
# 'perfil' -> NOUN (noun) -> NOUN
# 'jueves' -> NOUN (noun) -> NOUN
# '03' -> NUM (numeral) -> NUM
# 'abril' -> NOUN (noun) -> NOUN
# '2025' -> NUM (numeral) -> NUM
# 'business' -> NOUN (noun) -> NOUN
# 'noticias' -> NOUN (noun) -> NOUN
# 'caras' -> ADJ (adjective) -> ADJ
# 'exitoína' -> ADJ (adjective) -> ADJ
# 'perfil' -> PROPN (proper noun) -> PROPN
# 'brasil' -> PROPN (proper noun) -> PROPN
# 'últimas' -> ADJ (adjective) -> ADJ
# 'noticias' -> NOUN (noun) -> NOUN
# 'política' -> ADJ (adjective) -> ADJ
# 'opinión' -> NOUN (noun) -> NOUN
# 'sociedad' -> NOUN (noun) -> NOUN
# 'ingresar' -> VERB (verb) -> VERB
# 'suscribite' -> ADV (adverb) -> ADV
# '20día' -> NUM (numeral) -> NUM
# 'último' -> ADJ (adjective) -> ADJ
# 'momento' -> NOUN (noun) -> NOUN
# 'secciones' -> NOUN (noun) -> NOUN
# 'ahora' -> ADV (adverb) -> ADV
# 'columnistas' -> NOUN (noun) -> NOUN
# 'opinión' -> NOUN (noun) -> NOUN
# 'política' -> ADJ (adjective) -> ADJ
# 'economía' -> ADJ (adjective) -> ADJ
# 'pymes' -> ADJ (adjective) -> ADJ
# 'sociedad' -> NOUN (noun) -> NOUN
# 'salud' -> PROPN (proper noun) -> PROPN
# 'ciencia' -> PROPN (proper noun) -> PROPN
# 'protagonistas' -> NOUN (noun) -> NOUN
# 'tecnología' -> ADJ (adjective) -> ADJ
# 'cultura' -> NOUN (noun) -> NOUN
# 'arte' -> ADJ (adjective) -> ADJ
# 'educación' -> NOUN (noun) -> NOUN
# 'internacional' -> ADJ (adjective) -> ADJ
# 'clima' -> PROPN (proper noun) -> PROPN
# 'deportes' -> PROPN (proper noun) -> PROPN
# 'ocio' -> ADJ (adjective) -> ADJ
# 'caras' -> NOUN (noun) -> NOUN
# 'exitoina' -> ADJ (adjective) -> ADJ
# 'turismo' -> PROPN (proper noun) -> PROPN
# 'videos' -> PROPN (proper noun) -> PROPN
# 'córdoba' -> PROPN (proper noun) -> PROPN
# 'reperfilar' -> VERB (verb) -> VERB
# 'business' -> NOUN (noun) -> NOUN
# 'empresas' -> NOUN (noun) -> NOUN
# 'protagonistas' -> ADJ (adjective) -> ADJ
# 'noticias' -> NOUN (noun) -> NOUN
# 'caras' -> ADJ (adjective) -> ADJ
# 'exitoina' -> ADJ (adjective) -> ADJ
# 'gaming' -> NOUN (noun) -> NOUN
# 'vivo' -> ADJ (adjective) -> ADJ
# 'diario' -> ADJ (adjective) -> ADJ
# 'juicio' -> NOUN (noun) -> NOUN
# 'reperfilar' -> VERB (verb) -> VERB
# 'avance' -> NOUN (noun) -> NOUN
# 'científico' -> ADJ (adjective) -> ADJ
# 'mujer' -> NOUN (noun) -> NOUN
# 'cuadripléjica' -> ADJ (adjective) -> ADJ
# 'volvió' -> VERB (verb) -> VERB
# 'hablar' -> VERB (verb) -> VERB
# 'tras' -> ADP (adposition) -> ADP
# '18' -> NUM (numeral) -> NUM
# 'años' -> NOUN (noun) -> NOUN
# 'gracias' -> ADP (adposition) -> ADP
# 'inteligencia' -> NOUN (noun) -> NOUN
# 'artificial' -> ADJ (adjective) -> ADJ
# 'publicó' -> VERB (verb) -> VERB
# 'revista' -> NOUN (noun) -> NOUN
# 'científica' -> ADJ (adjective) -> ADJ
# 'nature' -> PROPN (proper noun) -> PROPN
# 'neuroscience' -> PROPN (proper noun) -> PROPN
# 'representa' -> VERB (verb) -> VERB
# 'gran' -> ADJ (adjective) -> ADJ
# 'paso' -> NOUN (noun) -> NOUN
# 'hacia' -> ADP (adposition) -> ADP
# 'recuperación' -> NOUN (noun) -> NOUN
# 'comunicación' -> NOUN (noun) -> NOUN
# 'personas' -> NOUN (noun) -> NOUN
# 'parálisis' -> NOUN (noun) -> NOUN
# 'severa' -> ADJ (adjective) -> ADJ
# 'mujer' -> NOUN (noun) -> NOUN
# 'cuadripléjica' -> ADJ (adjective) -> ADJ
# 'volvió' -> VERB (verb) -> VERB
# 'hablar' -> VERB (verb) -> VERB
# 'tras' -> ADP (adposition) -> ADP
# '18' -> NUM (numeral) -> NUM
# 'años' -> NOUN (noun) -> NOUN
# 'gracias' -> ADP (adposition) -> ADP
# 'inteligencia' -> NOUN (noun) -> NOUN
# 'artificial' -> ADJ (adjective) -> ADJ
# 'freepick' -> PROPN (proper noun) -> PROPN
# 'ayer' -> ADV (adverb) -> ADV
# '1105' -> NUM (numeral) -> NUM
# 'ann' -> NOUN (noun) -> NOUN
# 'mujer' -> NOUN (noun) -> NOUN
# '47' -> NUM (numeral) -> NUM
# 'años' -> NOUN (noun) -> NOUN
# 'cuadriplejía' -> PROPN (proper noun) -> PROPN
# 'logró' -> VERB (verb) -> VERB
# 'hablar' -> VERB (verb) -> VERB
# 'nuevamente' -> ADV (adverb) -> ADV
# '18' -> NUM (numeral) -> NUM
# 'años' -> NOUN (noun) -> NOUN
# 'gracias' -> ADP (adposition) -> ADP
# 'neuroprótesis' -> NOUN (noun) -> NOUN
# 'impulsada' -> ADJ (adjective) -> ADJ
# 'inteligencia' -> NOUN (noun) -> NOUN
# 'artificial' -> ADJ (adjective) -> ADJ
# 'ia' -> INTJ (interjection) -> INTJ
# 'avances' -> NOUN (noun) -> NOUN
# 'significativos' -> ADJ (adjective) -> ADJ
# 'campo' -> NOUN (noun) -> NOUN
# 'interfaces' -> ADJ (adjective) -> ADJ
# 'cerebrocomputadora' -> ADJ (adjective) -> ADJ
# 'procedimiento' -> NOUN (noun) -> NOUN
# 'desarrollado' -> ADJ (adjective) -> ADJ
# 'investigadores' -> NOUN (noun) -> NOUN
# 'universidad' -> PROPN (proper noun) -> PROPN
# 'california' -> PROPN (proper noun) -> PROPN
# 'berkeley' -> PROPN (proper noun) -> PROPN
# 'san' -> PROPN (proper noun) -> PROPN
# 'francisco' -> PROPN (proper noun) -> PROPN
# 'publicó' -> VERB (verb) -> VERB
# 'revista' -> NOUN (noun) -> NOUN
# 'científica' -> ADJ (adjective) -> ADJ
# 'nature' -> PROPN (proper noun) -> PROPN
# 'neuroscience' -> PROPN (proper noun) -> PROPN
# 'representa' -> VERB (verb) -> VERB
# 'gran' -> ADJ (adjective) -> ADJ
# 'paso' -> NOUN (noun) -> NOUN
# 'hacia' -> ADP (adposition) -> ADP
# 'recuperación' -> NOUN (noun) -> NOUN
# 'comunicación' -> NOUN (noun) -> NOUN
# 'personas' -> NOUN (noun) -> NOUN
# 'parálisis' -> NOUN (noun) -> NOUN
# 'severa' -> ADJ (adjective) -> ADJ
# 'dispositivo' -> NOUN (noun) -> NOUN
# 'hizo' -> VERB (verb) -> VERB
# 'posible' -> ADJ (adjective) -> ADJ
# 'hito' -> NOUN (noun) -> NOUN
# 'consiste' -> VERB (verb) -> VERB
# 'lámina' -> NOUN (noun) -> NOUN
# 'delgada' -> ADJ (adjective) -> ADJ
# '253' -> NUM (numeral) -> NUM
# 'electrodos' -> NOUN (noun) -> NOUN
# 'implantada' -> ADJ (adjective) -> ADJ
# 'corteza' -> NOUN (noun) -> NOUN
# 'cerebral' -> ADJ (adjective) -> ADJ
# 'ann' -> PROPN (proper noun) -> PROPN
# 'neuroprótesis' -> PROPN (proper noun) -> PROPN
# 'registró' -> VERB (verb) -> VERB
# 'actividad' -> NOUN (noun) -> NOUN
# 'neuronal' -> ADJ (adjective) -> ADJ
# 'envió' -> VERB (verb) -> VERB
# 'señales' -> NOUN (noun) -> NOUN
# 'computadora' -> ADJ (adjective) -> ADJ
# 'transformó' -> VERB (verb) -> VERB
# 'pensamientos' -> NOUN (noun) -> NOUN
# 'palabras' -> NOUN (noun) -> NOUN
# 'audibles' -> ADJ (adjective) -> ADJ
# 'voz' -> NOUN (noun) -> NOUN
# 'artificial' -> ADJ (adjective) -> ADJ
# 'personalizada' -> ADJ (adjective) -> ADJ
# 'reconstruir' -> VERB (verb) -> VERB
# 'tono' -> NOUN (noun) -> NOUN
# 'original' -> ADJ (adjective) -> ADJ
# 'investigadores' -> NOUN (noun) -> NOUN
# 'utilizaron' -> VERB (verb) -> VERB
# 'grabaciones' -> NOUN (noun) -> NOUN
# 'video' -> NOUN (noun) -> NOUN
# 'boda' -> NOUN (noun) -> NOUN
# 'ann' -> PROPN (proper noun) -> PROPN
# 'sufriera' -> VERB (verb) -> VERB
# 'accidente' -> NOUN (noun) -> NOUN
# 'cerebrovascular' -> ADJ (adjective) -> ADJ
# 'acv' -> PROPN (proper noun) -> PROPN
# '30' -> NUM (numeral) -> NUM
# 'años' -> NOUN (noun) -> NOUN
# 'quitó' -> VERB (verb) -> VERB
# 'capacidad' -> NOUN (noun) -> NOUN
# 'hablar' -> VERB (verb) -> VERB
# 'moverse' -> VERB (verb) -> VERB
# 'diferencia' -> NOUN (noun) -> NOUN
# 'sistemas' -> NOUN (noun) -> NOUN
# 'anteriores' -> ADJ (adjective) -> ADJ
# 'solo' -> ADJ (adjective) -> ADJ
# 'generaban' -> VERB (verb) -> VERB
# 'sonido' -> NOUN (noun) -> NOUN
# 'vez' -> NOUN (noun) -> NOUN
# 'paciente' -> ADJ (adjective) -> ADJ
# 'terminaba' -> VERB (verb) -> VERB
# 'frase' -> NOUN (noun) -> NOUN
# 'entera' -> ADJ (adjective) -> ADJ
# 'nueva' -> ADJ (adjective) -> ADJ
# 'interfaz' -> NOUN (noun) -> NOUN
# 'cerebrocomputadora' -> ADJ (adjective) -> ADJ
# 'permite' -> VERB (verb) -> VERB
# 'convertir' -> VERB (verb) -> VERB
# 'pensamientos' -> NOUN (noun) -> NOUN
# 'voz' -> VERB (verb) -> VERB
# 'apenas' -> ADV (adverb) -> ADV
# 'tres' -> NUM (numeral) -> NUM
# 'segundos' -> NOUN (noun) -> NOUN
# 'casi' -> ADV (adverb) -> ADV
# 'tiempo' -> NOUN (noun) -> NOUN
# 'real' -> ADJ (adjective) -> ADJ
# 'científicos' -> ADJ (adjective) -> ADJ
# 'explicaron' -> VERB (verb) -> VERB
# 'avance' -> NOUN (noun) -> NOUN
# 'tecnológico' -> ADJ (adjective) -> ADJ
# 'mejora' -> VERB (verb) -> VERB
# 'notablemente' -> ADV (adverb) -> ADV
# 'flujo' -> NOUN (noun) -> NOUN
# 'natural' -> ADJ (adjective) -> ADJ
# 'conversación' -> NOUN (noun) -> NOUN
# 'esencial' -> ADJ (adjective) -> ADJ
# 'personas' -> NOUN (noun) -> NOUN
# 'parálisis' -> NOUN (noun) -> NOUN
# 'puedan' -> AUX (auxiliary) -> AUX
# 'interactuar' -> VERB (verb) -> VERB
# 'entorno' -> NOUN (noun) -> NOUN
# 'sentirse' -> VERB (verb) -> VERB
# 'aisladas' -> ADJ (adjective) -> ADJ
# 'frustradas' -> ADJ (adjective) -> ADJ
# 'gusta' -> VERB (verb) -> VERB
# 'autoritarios' -> ADJ (adjective) -> ADJ
# 'ejercicio' -> NOUN (noun) -> NOUN
# 'periodismo' -> ADJ (adjective) -> ADJ
# 'profesional' -> ADJ (adjective) -> ADJ
# 'crítico' -> ADJ (adjective) -> ADJ
# 'pilar' -> PROPN (proper noun) -> PROPN
# 'fundamental' -> ADJ (adjective) -> ADJ
# 'democracia' -> NOUN (noun) -> NOUN
# 'molesta' -> ADJ (adjective) -> ADJ
# 'creen' -> VERB (verb) -> VERB
# 'ser' -> AUX (auxiliary) -> AUX
# 'dueños' -> NOUN (noun) -> NOUN
# 'verdad' -> NOUN (noun) -> NOUN
# 'hoy' -> ADV (adverb) -> ADV
# 'nunca' -> ADV (adverb) -> ADV
# 'suscribite' -> VERB (verb) -> VERB
# 'entrenamiento' -> NOUN (noun) -> NOUN
# 'sistema' -> PROPN (proper noun) -> PROPN
# 'ann' -> PROPN (proper noun) -> PROPN
# 'leyó' -> VERB (verb) -> VERB
# 'mentalmente' -> ADV (adverb) -> ADV
# 'alrededor' -> ADV (adverb) -> ADV
# '100' -> NUM (numeral) -> NUM
# 'frases' -> NOUN (noun) -> NOUN
# 'seleccionadas' -> ADJ (adjective) -> ADJ
# 'conjunto' -> ADJ (adjective) -> ADJ
# 'mil' -> NUM (numeral) -> NUM
# 'oraciones' -> NOUN (noun) -> NOUN
# 'dispositivo' -> ADJ (adjective) -> ADJ
# 'registraba' -> VERB (verb) -> VERB
# 'actividad' -> NOUN (noun) -> NOUN
# 'cerebral' -> ADJ (adjective) -> ADJ
# 'cada' -> DET (determiner) -> DET
# '80' -> NUM (numeral) -> NUM
# 'milisegundos' -> NOUN (noun) -> NOUN
# 'incluso' -> ADV (adverb) -> ADV
# 'comenzando' -> VERB (verb) -> VERB
# 'medio' -> NUM (numeral) -> NUM
# 'segundo' -> ADJ (adjective) -> ADJ
# 'intentara' -> VERB (verb) -> VERB
# 'articular' -> VERB (verb) -> VERB
# 'palabras' -> NOUN (noun) -> NOUN
# 'manera' -> NOUN (noun) -> NOUN
# 'silenciosa' -> ADJ (adjective) -> ADJ
# 'modelo' -> NOUN (noun) -> NOUN
# 'logró' -> VERB (verb) -> VERB
# 'generar' -> VERB (verb) -> VERB
# '47' -> NUM (numeral) -> NUM
# '90' -> NUM (numeral) -> NUM
# 'palabras' -> NOUN (noun) -> NOUN
# 'minuto' -> ADJ (adjective) -> ADJ
# 'cifra' -> ADJ (adjective) -> ADJ
# 'bien' -> ADV (adverb) -> ADV
# 'alcanza' -> VERB (verb) -> VERB
# 'velocidad' -> NOUN (noun) -> NOUN
# 'conversación' -> NOUN (noun) -> NOUN
# 'típica' -> ADJ (adjective) -> ADJ
# 'ronda' -> NOUN (noun) -> NOUN
# '160' -> NUM (numeral) -> NUM
# 'palabras' -> NOUN (noun) -> NOUN
# 'minuto' -> ADJ (adjective) -> ADJ
# 'supera' -> VERB (verb) -> VERB
# 'ampliamente' -> ADV (adverb) -> ADV
# 'logrado' -> ADJ (adjective) -> ADJ
# 'ahora' -> ADV (adverb) -> ADV
# 'tipo' -> NOUN (noun) -> NOUN
# 'tecnología' -> ADJ (adjective) -> ADJ
# 'avance' -> NOUN (noun) -> NOUN
# 'basó' -> VERB (verb) -> VERB
# 'algoritmos' -> NOUN (noun) -> NOUN
# 'inteligencia' -> NOUN (noun) -> NOUN
# 'artificial' -> ADJ (adjective) -> ADJ
# 'similares' -> ADJ (adjective) -> ADJ
# 'utilizan' -> VERB (verb) -> VERB
# 'asistentes' -> NOUN (noun) -> NOUN
# 'virtuales' -> ADJ (adjective) -> ADJ
# 'siri' -> PROPN (proper noun) -> PROPN
# 'alexa' -> PROPN (proper noun) -> PROPN
# 'adaptados' -> ADJ (adjective) -> ADJ
# 'decodificar' -> VERB (verb) -> VERB
# 'tiempo' -> NOUN (noun) -> NOUN
# 'real' -> ADJ (adjective) -> ADJ
# 'señales' -> NOUN (noun) -> NOUN
# 'cerebrales' -> ADJ (adjective) -> ADJ
# 'investigadores' -> NOUN (noun) -> NOUN
# 'explicaron' -> VERB (verb) -> VERB
# 'mismo' -> DET (determiner) -> DET
# 'algoritmo' -> NOUN (noun) -> NOUN
# 'podría' -> AUX (auxiliary) -> AUX
# 'usarse' -> VERB (verb) -> VERB
# 'distintos' -> DET (determiner) -> DET
# 'dispositivos' -> NOUN (noun) -> NOUN
# 'siempre' -> ADV (adverb) -> ADV
# 'buena' -> ADJ (adjective) -> ADJ
# 'calidad' -> NOUN (noun) -> NOUN
# 'señal' -> NOUN (noun) -> NOUN
# 'neuronal' -> ADJ (adjective) -> ADJ
# 'además' -> ADV (adverb) -> ADV
# 'equipo' -> NOUN (noun) -> NOUN
# 'trabajando' -> VERB (verb) -> VERB
# 'mejorar' -> VERB (verb) -> VERB
# 'expresividad' -> NOUN (noun) -> NOUN
# 'voz' -> NOUN (noun) -> NOUN
# 'sintetizada' -> ADJ (adjective) -> ADJ
# 'incorporando' -> VERB (verb) -> VERB
# 'matices' -> NOUN (noun) -> NOUN
# 'emocionales' -> ADJ (adjective) -> ADJ
# 'variaciones' -> NOUN (noun) -> NOUN
# 'tono' -> ADJ (adjective) -> ADJ
# 'timbre' -> ADJ (adjective) -> ADJ
# 'volumen' -> NOUN (noun) -> NOUN
# 'ann' -> PROPN (proper noun) -> PROPN
# 'participado' -> ADJ (adjective) -> ADJ
# 'estudios' -> NOUN (noun) -> NOUN
# 'anteriores' -> ADJ (adjective) -> ADJ
# 'tecnologías' -> NOUN (noun) -> NOUN
# 'similares' -> ADJ (adjective) -> ADJ
# 'ninguna' -> DET (determiner) -> DET
# 'logrado' -> ADJ (adjective) -> ADJ
# 'comunicación' -> NOUN (noun) -> NOUN
# 'fluida' -> ADJ (adjective) -> ADJ
# 'ahora' -> ADV (adverb) -> ADV
# 'valía' -> VERB (verb) -> VERB
# 'sistema' -> NOUN (noun) -> NOUN
# 'asistencia' -> NOUN (noun) -> NOUN
# 'llevaba' -> VERB (verb) -> VERB
# '20' -> NUM (numeral) -> NUM
# 'segundos' -> NOUN (noun) -> NOUN
# 'emitir' -> VERB (verb) -> VERB
# 'sola' -> ADJ (adjective) -> ADJ
# 'frase' -> NOUN (noun) -> NOUN
# 'nueva' -> ADJ (adjective) -> ADJ
# 'herramienta' -> NOUN (noun) -> NOUN
# 'solo' -> ADJ (adjective) -> ADJ
# 'recuperó' -> VERB (verb) -> VERB
# 'parte' -> NOUN (noun) -> NOUN
# 'capacidad' -> NOUN (noun) -> NOUN
# 'comunicarse' -> VERB (verb) -> VERB
# 'parte' -> NOUN (noun) -> NOUN
# 'fundamental' -> ADJ (adjective) -> ADJ
# 'identidad' -> NOUN (noun) -> NOUN
# 'voz' -> NOUN (noun) -> NOUN
# 'desarrollo' -> NOUN (noun) -> NOUN
# 'representa' -> VERB (verb) -> VERB
# 'paso' -> NOUN (noun) -> NOUN
# 'clave' -> NOUN (noun) -> NOUN
# 'hacia' -> ADP (adposition) -> ADP
# 'inclusión' -> NOUN (noun) -> NOUN
# 'dignidad' -> NOUN (noun) -> NOUN
# 'personas' -> NOUN (noun) -> NOUN
# 'discapacidades' -> ADJ (adjective) -> ADJ
# 'severas' -> ADJ (adjective) -> ADJ
# 'abriendo' -> VERB (verb) -> VERB
# 'nuevas' -> ADJ (adjective) -> ADJ
# 'oportunidades' -> NOUN (noun) -> NOUN
# 'puedan' -> AUX (auxiliary) -> AUX
# 'participar' -> VERB (verb) -> VERB
# 'activamente' -> ADV (adverb) -> ADV
# 'conversaciones' -> NOUN (noun) -> NOUN
# 'cotidianas' -> ADJ (adjective) -> ADJ
# 'todavía' -> ADV (adverb) -> ADV
# 'etapa' -> NOUN (noun) -> NOUN
# 'experimental' -> ADJ (adjective) -> ADJ
# 'éxito' -> NOUN (noun) -> NOUN
# 'tecnología' -> ADJ (adjective) -> ADJ
# 'alimenta' -> VERB (verb) -> VERB
# 'esperanza' -> NOUN (noun) -> NOUN
# 'pronto' -> ADV (adverb) -> ADV
# 'pacientes' -> NOUN (noun) -> NOUN
# 'puedan' -> AUX (auxiliary) -> AUX
# 'beneficiarse' -> VERB (verb) -> VERB
# 'soluciones' -> NOUN (noun) -> NOUN
# 'similares' -> ADJ (adjective) -> ADJ
# 'puede' -> AUX (auxiliary) -> AUX
# 'interesar' -> VERB (verb) -> VERB
# 'quiénes' -> PRON (pronoun) -> PRON
# 'seis' -> NUM (numeral) -> NUM
# 'argentinos' -> NOUN (noun) -> NOUN
# 'ricos' -> ADJ (adjective) -> ADJ
# 'mundo' -> NOUN (noun) -> NOUN
# 'comenzó' -> VERB (verb) -> VERB
# 'vacunación' -> NOUN (noun) -> NOUN
# 'gripe' -> NOUN (noun) -> NOUN
# 'caba' -> VERB (verb) -> VERB
# 'mujer' -> NOUN (noun) -> NOUN
# 'cuadripléjica' -> ADJ (adjective) -> ADJ
# 'volvió' -> VERB (verb) -> VERB
# 'hablar' -> VERB (verb) -> VERB
# 'inteligencia' -> NOUN (noun) -> NOUN
# 'artificial' -> ADJ (adjective) -> ADJ
# '18' -> NUM (numeral) -> NUM
# 'años' -> NOUN (noun) -> NOUN
# 'córdoba' -> PROPN (proper noun) -> PROPN
# 'cárcel' -> NOUN (noun) -> NOUN
# 'máxima' -> ADJ (adjective) -> ADJ
# 'seguridad' -> NOUN (noun) -> NOUN
# 'construirá' -> VERB (verb) -> VERB
# '1000' -> NUM (numeral) -> NUM
# 'presos' -> NOUN (noun) -> NOUN
# 'nota' -> VERB (verb) -> VERB
# 'inteligencia' -> NOUN (noun) -> NOUN
# 'artificial' -> ADJ (adjective) -> ADJ
# 'mujer' -> NOUN (noun) -> NOUN
# 'cuadripléjica' -> ADJ (adjective) -> ADJ
# 'ahora' -> ADV (adverb) -> ADV
# 'columnistas' -> NOUN (noun) -> NOUN
# 'política' -> ADJ (adjective) -> ADJ
# 'economía' -> ADJ (adjective) -> ADJ
# 'sociedad' -> NOUN (noun) -> NOUN
# 'internacional' -> ADJ (adjective) -> ADJ
# 'clima' -> PROPN (proper noun) -> PROPN
# 'deportes' -> PROPN (proper noun) -> PROPN
# 'ocio' -> PROPN (proper noun) -> PROPN
# 'córdoba' -> PROPN (proper noun) -> PROPN
# 'reperfilar' -> VERB (verb) -> VERB
# 'business' -> NOUN (noun) -> NOUN
# 'empresas' -> NOUN (noun) -> NOUN
# 'protagonistas' -> ADJ (adjective) -> ADJ
# 'noticias' -> NOUN (noun) -> NOUN
# 'caras' -> ADJ (adjective) -> ADJ
# 'exitoina' -> ADJ (adjective) -> ADJ
# 'gaming' -> NOUN (noun) -> NOUN
# 'vivo' -> ADJ (adjective) -> ADJ
# 'diario' -> ADJ (adjective) -> ADJ
# 'juicio' -> NOUN (noun) -> NOUN
# 'caras' -> NOUN (noun) -> NOUN
# 'noticias' -> NOUN (noun) -> NOUN
# 'weekend' -> NOUN (noun) -> NOUN
# 'fortuna' -> NOUN (noun) -> NOUN
# 'parabrisas' -> NOUN (noun) -> NOUN
# 'rouge' -> PROPN (proper noun) -> PROPN
# 'batimes' -> PROPN (proper noun) -> PROPN
# 'fm' -> ADP (adposition) -> ADP
# 'horizonte' -> NOUN (noun) -> NOUN
# 'perfil' -> PROPN (proper noun) -> PROPN
# 'brasil' -> PROPN (proper noun) -> PROPN
# 'caras' -> PROPN (proper noun) -> PROPN
# 'contigo' -> PROPN (proper noun) -> PROPN
# 'aventuras' -> NOUN (noun) -> NOUN
# 'na' -> AUX (auxiliary) -> AUX
# 'historia' -> PROPN (proper noun) -> PROPN
# 'rolling' -> PROPN (proper noun) -> PROPN
# 'stone' -> PROPN (proper noun) -> PROPN
# 'sport' -> PROPN (proper noun) -> PROPN
# 'buzz' -> PROPN (proper noun) -> PROPN
# 'recreio' -> PROPN (proper noun) -> PROPN
# 'maxima' -> PROPN (proper noun) -> PROPN
# 'canales' -> PROPN (proper noun) -> PROPN
# 'rss' -> PROPN (proper noun) -> PROPN
# 'contáctenos' -> ADJ (adjective) -> ADJ
# 'privacidad' -> NOUN (noun) -> NOUN
# 'equipo' -> NOUN (noun) -> NOUN
# 'reglas' -> NOUN (noun) -> NOUN
# 'participación' -> ADJ (adjective) -> ADJ
# 'tránsito' -> NOUN (noun) -> NOUN
# 'perfilcom' -> ADJ (adjective) -> ADJ
# 'editorial' -> PROPN (proper noun) -> PROPN
# 'perfil' -> PROPN (proper noun) -> PROPN
# 'sa' -> PROPN (proper noun) -> PROPN
# 'perfilcom' -> VERB (verb) -> VERB
# '20062025' -> NUM (numeral) -> NUM
# 'derechos' -> NOUN (noun) -> NOUN
# 'reservados' -> ADJ (adjective) -> ADJ
# 'editor' -> NOUN (noun) -> NOUN
# 'responsable' -> ADJ (adjective) -> ADJ
# 'carlos' -> PROPN (proper noun) -> PROPN
# 'piro' -> PROPN (proper noun) -> PROPN
# 'registro' -> PROPN (proper noun) -> PROPN
# 'propiedad' -> NOUN (noun) -> NOUN
# 'intelectual' -> ADJ (adjective) -> ADJ
# 'rl202431002957apndndamj' -> VERB (verb) -> VERB
# 'dirección' -> NOUN (noun) -> NOUN
# 'california' -> PROPN (proper noun) -> PROPN
# '2715' -> NUM (numeral) -> NUM
# 'c1289abi' -> NOUN (noun) -> NOUN
# 'caba' -> VERB (verb) -> VERB
# 'argentina' -> ADJ (adjective) -> ADJ
# 'teléfono' -> NOUN (noun) -> NOUN
# '5411' -> NUM (numeral) -> NUM
# '70914921' -> NUM (numeral) -> NUM
# '5411' -> NUM (numeral) -> NUM
# '70914922' -> NUM (numeral) -> NUM
# 'email' -> PROPN (proper noun) -> PROPN
# 'email' -> PROPN (proper noun) -> PROPN
# 'protected' -> PROPN (proper noun) -> PROPN

# %%
print(doc)
# Out:
# mujer cuadripléjica volvió hablar tras 18 años gracias inteligencia artificial perfil jueves 03 abril 2025 business noticias caras exitoína perfil brasil últimas noticias política opinión sociedad ingresar suscribite 20día último momento secciones ahora columnistas opinión política economía pymes sociedad salud ciencia protagonistas tecnología cultura arte educación internacional clima deportes ocio caras exitoina turismo videos córdoba reperfilar business empresas protagonistas noticias caras exitoina gaming vivo diario juicio reperfilar avance científico mujer cuadripléjica volvió hablar tras 18 años gracias inteligencia artificial publicó revista científica nature neuroscience representa gran paso hacia recuperación comunicación personas parálisis severa mujer cuadripléjica volvió hablar tras 18 años gracias inteligencia artificial freepick ayer 1105 ann mujer 47 años cuadriplejía logró hablar nuevamente 18 años gracias neuroprótesis impulsada inteligencia artificial ia avances significativos campo interfaces cerebrocomputadora procedimiento desarrollado investigadores universidad california berkeley san francisco publicó revista científica nature neuroscience representa gran paso hacia recuperación comunicación personas parálisis severa dispositivo hizo posible hito consiste lámina delgada 253 electrodos implantada corteza cerebral ann neuroprótesis registró actividad neuronal envió señales computadora transformó pensamientos palabras audibles voz artificial personalizada reconstruir tono original investigadores utilizaron grabaciones video boda ann sufriera accidente cerebrovascular acv 30 años quitó capacidad hablar moverse diferencia sistemas anteriores solo generaban sonido vez paciente terminaba frase entera nueva interfaz cerebrocomputadora permite convertir pensamientos voz apenas tres segundos casi tiempo real científicos explicaron avance tecnológico mejora notablemente flujo natural conversación esencial personas parálisis puedan interactuar entorno sentirse aisladas frustradas gusta autoritarios ejercicio periodismo profesional crítico pilar fundamental democracia molesta creen ser dueños verdad hoy nunca suscribite entrenamiento sistema ann leyó mentalmente alrededor 100 frases seleccionadas conjunto mil oraciones dispositivo registraba actividad cerebral cada 80 milisegundos incluso comenzando medio segundo intentara articular palabras manera silenciosa modelo logró generar 47 90 palabras minuto cifra bien alcanza velocidad conversación típica ronda 160 palabras minuto supera ampliamente logrado ahora tipo tecnología avance basó algoritmos inteligencia artificial similares utilizan asistentes virtuales siri alexa adaptados decodificar tiempo real señales cerebrales investigadores explicaron mismo algoritmo podría usarse distintos dispositivos siempre buena calidad señal neuronal además equipo trabajando mejorar expresividad voz sintetizada incorporando matices emocionales variaciones tono timbre volumen ann participado estudios anteriores tecnologías similares ninguna logrado comunicación fluida ahora valía sistema asistencia llevaba 20 segundos emitir sola frase nueva herramienta solo recuperó parte capacidad comunicarse parte fundamental identidad voz desarrollo representa paso clave hacia inclusión dignidad personas discapacidades severas abriendo nuevas oportunidades puedan participar activamente conversaciones cotidianas todavía etapa experimental éxito tecnología alimenta esperanza pronto pacientes puedan beneficiarse soluciones similares puede interesar quiénes seis argentinos ricos mundo comenzó vacunación gripe caba mujer cuadripléjica volvió hablar inteligencia artificial 18 años córdoba cárcel máxima seguridad construirá 1000 presos nota inteligencia artificial mujer cuadripléjica ahora columnistas política economía sociedad internacional clima deportes ocio córdoba reperfilar business empresas protagonistas noticias caras exitoina gaming vivo diario juicio caras noticias weekend fortuna parabrisas  ...

# %%
# Etiquetado gramatical
for token in doc:
    if not token.is_space: # Ignoramos espacios
        print(f"'{token.text}' -> {token.pos_} ({spacy.explain(token.pos_)}) -> {token.tag_}")
# Out:
# 'mujer' -> NOUN (noun) -> NOUN
# 'cuadripléjica' -> ADJ (adjective) -> ADJ
# 'volvió' -> VERB (verb) -> VERB
# 'hablar' -> VERB (verb) -> VERB
# 'tras' -> ADP (adposition) -> ADP
# '18' -> NUM (numeral) -> NUM
# 'años' -> NOUN (noun) -> NOUN
# 'gracias' -> ADP (adposition) -> ADP
# 'inteligencia' -> NOUN (noun) -> NOUN
# 'artificial' -> ADJ (adjective) -> ADJ
# 'perfil' -> NOUN (noun) -> NOUN
# 'jueves' -> NOUN (noun) -> NOUN
# '03' -> NUM (numeral) -> NUM
# 'abril' -> NOUN (noun) -> NOUN
# '2025' -> NUM (numeral) -> NUM
# 'business' -> NOUN (noun) -> NOUN
# 'noticias' -> NOUN (noun) -> NOUN
# 'caras' -> ADJ (adjective) -> ADJ
# 'exitoína' -> ADJ (adjective) -> ADJ
# 'perfil' -> PROPN (proper noun) -> PROPN
# 'brasil' -> PROPN (proper noun) -> PROPN
# 'últimas' -> ADJ (adjective) -> ADJ
# 'noticias' -> NOUN (noun) -> NOUN
# 'política' -> ADJ (adjective) -> ADJ
# 'opinión' -> NOUN (noun) -> NOUN
# 'sociedad' -> NOUN (noun) -> NOUN
# 'ingresar' -> VERB (verb) -> VERB
# 'suscribite' -> ADV (adverb) -> ADV
# '20día' -> NUM (numeral) -> NUM
# 'último' -> ADJ (adjective) -> ADJ
# 'momento' -> NOUN (noun) -> NOUN
# 'secciones' -> NOUN (noun) -> NOUN
# 'ahora' -> ADV (adverb) -> ADV
# 'columnistas' -> NOUN (noun) -> NOUN
# 'opinión' -> NOUN (noun) -> NOUN
# 'política' -> ADJ (adjective) -> ADJ
# 'economía' -> ADJ (adjective) -> ADJ
# 'pymes' -> ADJ (adjective) -> ADJ
# 'sociedad' -> NOUN (noun) -> NOUN
# 'salud' -> PROPN (proper noun) -> PROPN
# 'ciencia' -> PROPN (proper noun) -> PROPN
# 'protagonistas' -> NOUN (noun) -> NOUN
# 'tecnología' -> ADJ (adjective) -> ADJ
# 'cultura' -> NOUN (noun) -> NOUN
# 'arte' -> ADJ (adjective) -> ADJ
# 'educación' -> NOUN (noun) -> NOUN
# 'internacional' -> ADJ (adjective) -> ADJ
# 'clima' -> PROPN (proper noun) -> PROPN
# 'deportes' -> PROPN (proper noun) -> PROPN
# 'ocio' -> ADJ (adjective) -> ADJ
# 'caras' -> NOUN (noun) -> NOUN
# 'exitoina' -> ADJ (adjective) -> ADJ
# 'turismo' -> PROPN (proper noun) -> PROPN
# 'videos' -> PROPN (proper noun) -> PROPN
# 'córdoba' -> PROPN (proper noun) -> PROPN
# 'reperfilar' -> VERB (verb) -> VERB
# 'business' -> NOUN (noun) -> NOUN
# 'empresas' -> NOUN (noun) -> NOUN
# 'protagonistas' -> ADJ (adjective) -> ADJ
# 'noticias' -> NOUN (noun) -> NOUN
# 'caras' -> ADJ (adjective) -> ADJ
# 'exitoina' -> ADJ (adjective) -> ADJ
# 'gaming' -> NOUN (noun) -> NOUN
# 'vivo' -> ADJ (adjective) -> ADJ
# 'diario' -> ADJ (adjective) -> ADJ
# 'juicio' -> NOUN (noun) -> NOUN
# 'reperfilar' -> VERB (verb) -> VERB
# 'avance' -> NOUN (noun) -> NOUN
# 'científico' -> ADJ (adjective) -> ADJ
# 'mujer' -> NOUN (noun) -> NOUN
# 'cuadripléjica' -> ADJ (adjective) -> ADJ
# 'volvió' -> VERB (verb) -> VERB
# 'hablar' -> VERB (verb) -> VERB
# 'tras' -> ADP (adposition) -> ADP
# '18' -> NUM (numeral) -> NUM
# 'años' -> NOUN (noun) -> NOUN
# 'gracias' -> ADP (adposition) -> ADP
# 'inteligencia' -> NOUN (noun) -> NOUN
# 'artificial' -> ADJ (adjective) -> ADJ
# 'publicó' -> VERB (verb) -> VERB
# 'revista' -> NOUN (noun) -> NOUN
# 'científica' -> ADJ (adjective) -> ADJ
# 'nature' -> PROPN (proper noun) -> PROPN
# 'neuroscience' -> PROPN (proper noun) -> PROPN
# 'representa' -> VERB (verb) -> VERB
# 'gran' -> ADJ (adjective) -> ADJ
# 'paso' -> NOUN (noun) -> NOUN
# 'hacia' -> ADP (adposition) -> ADP
# 'recuperación' -> NOUN (noun) -> NOUN
# 'comunicación' -> NOUN (noun) -> NOUN
# 'personas' -> NOUN (noun) -> NOUN
# 'parálisis' -> NOUN (noun) -> NOUN
# 'severa' -> ADJ (adjective) -> ADJ
# 'mujer' -> NOUN (noun) -> NOUN
# 'cuadripléjica' -> ADJ (adjective) -> ADJ
# 'volvió' -> VERB (verb) -> VERB
# 'hablar' -> VERB (verb) -> VERB
# 'tras' -> ADP (adposition) -> ADP
# '18' -> NUM (numeral) -> NUM
# 'años' -> NOUN (noun) -> NOUN
# 'gracias' -> ADP (adposition) -> ADP
# 'inteligencia' -> NOUN (noun) -> NOUN
# 'artificial' -> ADJ (adjective) -> ADJ
# 'freepick' -> PROPN (proper noun) -> PROPN
# 'ayer' -> ADV (adverb) -> ADV
# '1105' -> NUM (numeral) -> NUM
# 'ann' -> NOUN (noun) -> NOUN
# 'mujer' -> NOUN (noun) -> NOUN
# '47' -> NUM (numeral) -> NUM
# 'años' -> NOUN (noun) -> NOUN
# 'cuadriplejía' -> PROPN (proper noun) -> PROPN
# 'logró' -> VERB (verb) -> VERB
# 'hablar' -> VERB (verb) -> VERB
# 'nuevamente' -> ADV (adverb) -> ADV
# '18' -> NUM (numeral) -> NUM
# 'años' -> NOUN (noun) -> NOUN
# 'gracias' -> ADP (adposition) -> ADP
# 'neuroprótesis' -> NOUN (noun) -> NOUN
# 'impulsada' -> ADJ (adjective) -> ADJ
# 'inteligencia' -> NOUN (noun) -> NOUN
# 'artificial' -> ADJ (adjective) -> ADJ
# 'ia' -> INTJ (interjection) -> INTJ
# 'avances' -> NOUN (noun) -> NOUN
# 'significativos' -> ADJ (adjective) -> ADJ
# 'campo' -> NOUN (noun) -> NOUN
# 'interfaces' -> ADJ (adjective) -> ADJ
# 'cerebrocomputadora' -> ADJ (adjective) -> ADJ
# 'procedimiento' -> NOUN (noun) -> NOUN
# 'desarrollado' -> ADJ (adjective) -> ADJ
# 'investigadores' -> NOUN (noun) -> NOUN
# 'universidad' -> PROPN (proper noun) -> PROPN
# 'california' -> PROPN (proper noun) -> PROPN
# 'berkeley' -> PROPN (proper noun) -> PROPN
# 'san' -> PROPN (proper noun) -> PROPN
# 'francisco' -> PROPN (proper noun) -> PROPN
# 'publicó' -> VERB (verb) -> VERB
# 'revista' -> NOUN (noun) -> NOUN
# 'científica' -> ADJ (adjective) -> ADJ
# 'nature' -> PROPN (proper noun) -> PROPN
# 'neuroscience' -> PROPN (proper noun) -> PROPN
# 'representa' -> VERB (verb) -> VERB
# 'gran' -> ADJ (adjective) -> ADJ
# 'paso' -> NOUN (noun) -> NOUN
# 'hacia' -> ADP (adposition) -> ADP
# 'recuperación' -> NOUN (noun) -> NOUN
# 'comunicación' -> NOUN (noun) -> NOUN
# 'personas' -> NOUN (noun) -> NOUN
# 'parálisis' -> NOUN (noun) -> NOUN
# 'severa' -> ADJ (adjective) -> ADJ
# 'dispositivo' -> NOUN (noun) -> NOUN
# 'hizo' -> VERB (verb) -> VERB
# 'posible' -> ADJ (adjective) -> ADJ
# 'hito' -> NOUN (noun) -> NOUN
# 'consiste' -> VERB (verb) -> VERB
# 'lámina' -> NOUN (noun) -> NOUN
# 'delgada' -> ADJ (adjective) -> ADJ
# '253' -> NUM (numeral) -> NUM
# 'electrodos' -> NOUN (noun) -> NOUN
# 'implantada' -> ADJ (adjective) -> ADJ
# 'corteza' -> NOUN (noun) -> NOUN
# 'cerebral' -> ADJ (adjective) -> ADJ
# 'ann' -> PROPN (proper noun) -> PROPN
# 'neuroprótesis' -> PROPN (proper noun) -> PROPN
# 'registró' -> VERB (verb) -> VERB
# 'actividad' -> NOUN (noun) -> NOUN
# 'neuronal' -> ADJ (adjective) -> ADJ
# 'envió' -> VERB (verb) -> VERB
# 'señales' -> NOUN (noun) -> NOUN
# 'computadora' -> ADJ (adjective) -> ADJ
# 'transformó' -> VERB (verb) -> VERB
# 'pensamientos' -> NOUN (noun) -> NOUN
# 'palabras' -> NOUN (noun) -> NOUN
# 'audibles' -> ADJ (adjective) -> ADJ
# 'voz' -> NOUN (noun) -> NOUN
# 'artificial' -> ADJ (adjective) -> ADJ
# 'personalizada' -> ADJ (adjective) -> ADJ
# 'reconstruir' -> VERB (verb) -> VERB
# 'tono' -> NOUN (noun) -> NOUN
# 'original' -> ADJ (adjective) -> ADJ
# 'investigadores' -> NOUN (noun) -> NOUN
# 'utilizaron' -> VERB (verb) -> VERB
# 'grabaciones' -> NOUN (noun) -> NOUN
# 'video' -> NOUN (noun) -> NOUN
# 'boda' -> NOUN (noun) -> NOUN
# 'ann' -> PROPN (proper noun) -> PROPN
# 'sufriera' -> VERB (verb) -> VERB
# 'accidente' -> NOUN (noun) -> NOUN
# 'cerebrovascular' -> ADJ (adjective) -> ADJ
# 'acv' -> PROPN (proper noun) -> PROPN
# '30' -> NUM (numeral) -> NUM
# 'años' -> NOUN (noun) -> NOUN
# 'quitó' -> VERB (verb) -> VERB
# 'capacidad' -> NOUN (noun) -> NOUN
# 'hablar' -> VERB (verb) -> VERB
# 'moverse' -> VERB (verb) -> VERB
# 'diferencia' -> NOUN (noun) -> NOUN
# 'sistemas' -> NOUN (noun) -> NOUN
# 'anteriores' -> ADJ (adjective) -> ADJ
# 'solo' -> ADJ (adjective) -> ADJ
# 'generaban' -> VERB (verb) -> VERB
# 'sonido' -> NOUN (noun) -> NOUN
# 'vez' -> NOUN (noun) -> NOUN
# 'paciente' -> ADJ (adjective) -> ADJ
# 'terminaba' -> VERB (verb) -> VERB
# 'frase' -> NOUN (noun) -> NOUN
# 'entera' -> ADJ (adjective) -> ADJ
# 'nueva' -> ADJ (adjective) -> ADJ
# 'interfaz' -> NOUN (noun) -> NOUN
# 'cerebrocomputadora' -> ADJ (adjective) -> ADJ
# 'permite' -> VERB (verb) -> VERB
# 'convertir' -> VERB (verb) -> VERB
# 'pensamientos' -> NOUN (noun) -> NOUN
# 'voz' -> VERB (verb) -> VERB
# 'apenas' -> ADV (adverb) -> ADV
# 'tres' -> NUM (numeral) -> NUM
# 'segundos' -> NOUN (noun) -> NOUN
# 'casi' -> ADV (adverb) -> ADV
# 'tiempo' -> NOUN (noun) -> NOUN
# 'real' -> ADJ (adjective) -> ADJ
# 'científicos' -> ADJ (adjective) -> ADJ
# 'explicaron' -> VERB (verb) -> VERB
# 'avance' -> NOUN (noun) -> NOUN
# 'tecnológico' -> ADJ (adjective) -> ADJ
# 'mejora' -> VERB (verb) -> VERB
# 'notablemente' -> ADV (adverb) -> ADV
# 'flujo' -> NOUN (noun) -> NOUN
# 'natural' -> ADJ (adjective) -> ADJ
# 'conversación' -> NOUN (noun) -> NOUN
# 'esencial' -> ADJ (adjective) -> ADJ
# 'personas' -> NOUN (noun) -> NOUN
# 'parálisis' -> NOUN (noun) -> NOUN
# 'puedan' -> AUX (auxiliary) -> AUX
# 'interactuar' -> VERB (verb) -> VERB
# 'entorno' -> NOUN (noun) -> NOUN
# 'sentirse' -> VERB (verb) -> VERB
# 'aisladas' -> ADJ (adjective) -> ADJ
# 'frustradas' -> ADJ (adjective) -> ADJ
# 'gusta' -> VERB (verb) -> VERB
# 'autoritarios' -> ADJ (adjective) -> ADJ
# 'ejercicio' -> NOUN (noun) -> NOUN
# 'periodismo' -> ADJ (adjective) -> ADJ
# 'profesional' -> ADJ (adjective) -> ADJ
# 'crítico' -> ADJ (adjective) -> ADJ
# 'pilar' -> PROPN (proper noun) -> PROPN
# 'fundamental' -> ADJ (adjective) -> ADJ
# 'democracia' -> NOUN (noun) -> NOUN
# 'molesta' -> ADJ (adjective) -> ADJ
# 'creen' -> VERB (verb) -> VERB
# 'ser' -> AUX (auxiliary) -> AUX
# 'dueños' -> NOUN (noun) -> NOUN
# 'verdad' -> NOUN (noun) -> NOUN
# 'hoy' -> ADV (adverb) -> ADV
# 'nunca' -> ADV (adverb) -> ADV
# 'suscribite' -> VERB (verb) -> VERB
# 'entrenamiento' -> NOUN (noun) -> NOUN
# 'sistema' -> PROPN (proper noun) -> PROPN
# 'ann' -> PROPN (proper noun) -> PROPN
# 'leyó' -> VERB (verb) -> VERB
# 'mentalmente' -> ADV (adverb) -> ADV
# 'alrededor' -> ADV (adverb) -> ADV
# '100' -> NUM (numeral) -> NUM
# 'frases' -> NOUN (noun) -> NOUN
# 'seleccionadas' -> ADJ (adjective) -> ADJ
# 'conjunto' -> ADJ (adjective) -> ADJ
# 'mil' -> NUM (numeral) -> NUM
# 'oraciones' -> NOUN (noun) -> NOUN
# 'dispositivo' -> ADJ (adjective) -> ADJ
# 'registraba' -> VERB (verb) -> VERB
# 'actividad' -> NOUN (noun) -> NOUN
# 'cerebral' -> ADJ (adjective) -> ADJ
# 'cada' -> DET (determiner) -> DET
# '80' -> NUM (numeral) -> NUM
# 'milisegundos' -> NOUN (noun) -> NOUN
# 'incluso' -> ADV (adverb) -> ADV
# 'comenzando' -> VERB (verb) -> VERB
# 'medio' -> NUM (numeral) -> NUM
# 'segundo' -> ADJ (adjective) -> ADJ
# 'intentara' -> VERB (verb) -> VERB
# 'articular' -> VERB (verb) -> VERB
# 'palabras' -> NOUN (noun) -> NOUN
# 'manera' -> NOUN (noun) -> NOUN
# 'silenciosa' -> ADJ (adjective) -> ADJ
# 'modelo' -> NOUN (noun) -> NOUN
# 'logró' -> VERB (verb) -> VERB
# 'generar' -> VERB (verb) -> VERB
# '47' -> NUM (numeral) -> NUM
# '90' -> NUM (numeral) -> NUM
# 'palabras' -> NOUN (noun) -> NOUN
# 'minuto' -> ADJ (adjective) -> ADJ
# 'cifra' -> ADJ (adjective) -> ADJ
# 'bien' -> ADV (adverb) -> ADV
# 'alcanza' -> VERB (verb) -> VERB
# 'velocidad' -> NOUN (noun) -> NOUN
# 'conversación' -> NOUN (noun) -> NOUN
# 'típica' -> ADJ (adjective) -> ADJ
# 'ronda' -> NOUN (noun) -> NOUN
# '160' -> NUM (numeral) -> NUM
# 'palabras' -> NOUN (noun) -> NOUN
# 'minuto' -> ADJ (adjective) -> ADJ
# 'supera' -> VERB (verb) -> VERB
# 'ampliamente' -> ADV (adverb) -> ADV
# 'logrado' -> ADJ (adjective) -> ADJ
# 'ahora' -> ADV (adverb) -> ADV
# 'tipo' -> NOUN (noun) -> NOUN
# 'tecnología' -> ADJ (adjective) -> ADJ
# 'avance' -> NOUN (noun) -> NOUN
# 'basó' -> VERB (verb) -> VERB
# 'algoritmos' -> NOUN (noun) -> NOUN
# 'inteligencia' -> NOUN (noun) -> NOUN
# 'artificial' -> ADJ (adjective) -> ADJ
# 'similares' -> ADJ (adjective) -> ADJ
# 'utilizan' -> VERB (verb) -> VERB
# 'asistentes' -> NOUN (noun) -> NOUN
# 'virtuales' -> ADJ (adjective) -> ADJ
# 'siri' -> PROPN (proper noun) -> PROPN
# 'alexa' -> PROPN (proper noun) -> PROPN
# 'adaptados' -> ADJ (adjective) -> ADJ
# 'decodificar' -> VERB (verb) -> VERB
# 'tiempo' -> NOUN (noun) -> NOUN
# 'real' -> ADJ (adjective) -> ADJ
# 'señales' -> NOUN (noun) -> NOUN
# 'cerebrales' -> ADJ (adjective) -> ADJ
# 'investigadores' -> NOUN (noun) -> NOUN
# 'explicaron' -> VERB (verb) -> VERB
# 'mismo' -> DET (determiner) -> DET
# 'algoritmo' -> NOUN (noun) -> NOUN
# 'podría' -> AUX (auxiliary) -> AUX
# 'usarse' -> VERB (verb) -> VERB
# 'distintos' -> DET (determiner) -> DET
# 'dispositivos' -> NOUN (noun) -> NOUN
# 'siempre' -> ADV (adverb) -> ADV
# 'buena' -> ADJ (adjective) -> ADJ
# 'calidad' -> NOUN (noun) -> NOUN
# 'señal' -> NOUN (noun) -> NOUN
# 'neuronal' -> ADJ (adjective) -> ADJ
# 'además' -> ADV (adverb) -> ADV
# 'equipo' -> NOUN (noun) -> NOUN
# 'trabajando' -> VERB (verb) -> VERB
# 'mejorar' -> VERB (verb) -> VERB
# 'expresividad' -> NOUN (noun) -> NOUN
# 'voz' -> NOUN (noun) -> NOUN
# 'sintetizada' -> ADJ (adjective) -> ADJ
# 'incorporando' -> VERB (verb) -> VERB
# 'matices' -> NOUN (noun) -> NOUN
# 'emocionales' -> ADJ (adjective) -> ADJ
# 'variaciones' -> NOUN (noun) -> NOUN
# 'tono' -> ADJ (adjective) -> ADJ
# 'timbre' -> ADJ (adjective) -> ADJ
# 'volumen' -> NOUN (noun) -> NOUN
# 'ann' -> PROPN (proper noun) -> PROPN
# 'participado' -> ADJ (adjective) -> ADJ
# 'estudios' -> NOUN (noun) -> NOUN
# 'anteriores' -> ADJ (adjective) -> ADJ
# 'tecnologías' -> NOUN (noun) -> NOUN
# 'similares' -> ADJ (adjective) -> ADJ
# 'ninguna' -> DET (determiner) -> DET
# 'logrado' -> ADJ (adjective) -> ADJ
# 'comunicación' -> NOUN (noun) -> NOUN
# 'fluida' -> ADJ (adjective) -> ADJ
# 'ahora' -> ADV (adverb) -> ADV
# 'valía' -> VERB (verb) -> VERB
# 'sistema' -> NOUN (noun) -> NOUN
# 'asistencia' -> NOUN (noun) -> NOUN
# 'llevaba' -> VERB (verb) -> VERB
# '20' -> NUM (numeral) -> NUM
# 'segundos' -> NOUN (noun) -> NOUN
# 'emitir' -> VERB (verb) -> VERB
# 'sola' -> ADJ (adjective) -> ADJ
# 'frase' -> NOUN (noun) -> NOUN
# 'nueva' -> ADJ (adjective) -> ADJ
# 'herramienta' -> NOUN (noun) -> NOUN
# 'solo' -> ADJ (adjective) -> ADJ
# 'recuperó' -> VERB (verb) -> VERB
# 'parte' -> NOUN (noun) -> NOUN
# 'capacidad' -> NOUN (noun) -> NOUN
# 'comunicarse' -> VERB (verb) -> VERB
# 'parte' -> NOUN (noun) -> NOUN
# 'fundamental' -> ADJ (adjective) -> ADJ
# 'identidad' -> NOUN (noun) -> NOUN
# 'voz' -> NOUN (noun) -> NOUN
# 'desarrollo' -> NOUN (noun) -> NOUN
# 'representa' -> VERB (verb) -> VERB
# 'paso' -> NOUN (noun) -> NOUN
# 'clave' -> NOUN (noun) -> NOUN
# 'hacia' -> ADP (adposition) -> ADP
# 'inclusión' -> NOUN (noun) -> NOUN
# 'dignidad' -> NOUN (noun) -> NOUN
# 'personas' -> NOUN (noun) -> NOUN
# 'discapacidades' -> ADJ (adjective) -> ADJ
# 'severas' -> ADJ (adjective) -> ADJ
# 'abriendo' -> VERB (verb) -> VERB
# 'nuevas' -> ADJ (adjective) -> ADJ
# 'oportunidades' -> NOUN (noun) -> NOUN
# 'puedan' -> AUX (auxiliary) -> AUX
# 'participar' -> VERB (verb) -> VERB
# 'activamente' -> ADV (adverb) -> ADV
# 'conversaciones' -> NOUN (noun) -> NOUN
# 'cotidianas' -> ADJ (adjective) -> ADJ
# 'todavía' -> ADV (adverb) -> ADV
# 'etapa' -> NOUN (noun) -> NOUN
# 'experimental' -> ADJ (adjective) -> ADJ
# 'éxito' -> NOUN (noun) -> NOUN
# 'tecnología' -> ADJ (adjective) -> ADJ
# 'alimenta' -> VERB (verb) -> VERB
# 'esperanza' -> NOUN (noun) -> NOUN
# 'pronto' -> ADV (adverb) -> ADV
# 'pacientes' -> NOUN (noun) -> NOUN
# 'puedan' -> AUX (auxiliary) -> AUX
# 'beneficiarse' -> VERB (verb) -> VERB
# 'soluciones' -> NOUN (noun) -> NOUN
# 'similares' -> ADJ (adjective) -> ADJ
# 'puede' -> AUX (auxiliary) -> AUX
# 'interesar' -> VERB (verb) -> VERB
# 'quiénes' -> PRON (pronoun) -> PRON
# 'seis' -> NUM (numeral) -> NUM
# 'argentinos' -> NOUN (noun) -> NOUN
# 'ricos' -> ADJ (adjective) -> ADJ
# 'mundo' -> NOUN (noun) -> NOUN
# 'comenzó' -> VERB (verb) -> VERB
# 'vacunación' -> NOUN (noun) -> NOUN
# 'gripe' -> NOUN (noun) -> NOUN
# 'caba' -> VERB (verb) -> VERB
# 'mujer' -> NOUN (noun) -> NOUN
# 'cuadripléjica' -> ADJ (adjective) -> ADJ
# 'volvió' -> VERB (verb) -> VERB
# 'hablar' -> VERB (verb) -> VERB
# 'inteligencia' -> NOUN (noun) -> NOUN
# 'artificial' -> ADJ (adjective) -> ADJ
# '18' -> NUM (numeral) -> NUM
# 'años' -> NOUN (noun) -> NOUN
# 'córdoba' -> PROPN (proper noun) -> PROPN
# 'cárcel' -> NOUN (noun) -> NOUN
# 'máxima' -> ADJ (adjective) -> ADJ
# 'seguridad' -> NOUN (noun) -> NOUN
# 'construirá' -> VERB (verb) -> VERB
# '1000' -> NUM (numeral) -> NUM
# 'presos' -> NOUN (noun) -> NOUN
# 'nota' -> VERB (verb) -> VERB
# 'inteligencia' -> NOUN (noun) -> NOUN
# 'artificial' -> ADJ (adjective) -> ADJ
# 'mujer' -> NOUN (noun) -> NOUN
# 'cuadripléjica' -> ADJ (adjective) -> ADJ
# 'ahora' -> ADV (adverb) -> ADV
# 'columnistas' -> NOUN (noun) -> NOUN
# 'política' -> ADJ (adjective) -> ADJ
# 'economía' -> ADJ (adjective) -> ADJ
# 'sociedad' -> NOUN (noun) -> NOUN
# 'internacional' -> ADJ (adjective) -> ADJ
# 'clima' -> PROPN (proper noun) -> PROPN
# 'deportes' -> PROPN (proper noun) -> PROPN
# 'ocio' -> PROPN (proper noun) -> PROPN
# 'córdoba' -> PROPN (proper noun) -> PROPN
# 'reperfilar' -> VERB (verb) -> VERB
# 'business' -> NOUN (noun) -> NOUN
# 'empresas' -> NOUN (noun) -> NOUN
# 'protagonistas' -> ADJ (adjective) -> ADJ
# 'noticias' -> NOUN (noun) -> NOUN
# 'caras' -> ADJ (adjective) -> ADJ
# 'exitoina' -> ADJ (adjective) -> ADJ
# 'gaming' -> NOUN (noun) -> NOUN
# 'vivo' -> ADJ (adjective) -> ADJ
# 'diario' -> ADJ (adjective) -> ADJ
# 'juicio' -> NOUN (noun) -> NOUN
# 'caras' -> NOUN (noun) -> NOUN
# 'noticias' -> NOUN (noun) -> NOUN
# 'weekend' -> NOUN (noun) -> NOUN
# 'fortuna' -> NOUN (noun) -> NOUN
# 'parabrisas' -> NOUN (noun) -> NOUN
# 'rouge' -> PROPN (proper noun) -> PROPN
# 'batimes' -> PROPN (proper noun) -> PROPN
# 'fm' -> ADP (adposition) -> ADP
# 'horizonte' -> NOUN (noun) -> NOUN
# 'perfil' -> PROPN (proper noun) -> PROPN
# 'brasil' -> PROPN (proper noun) -> PROPN
# 'caras' -> PROPN (proper noun) -> PROPN
# 'contigo' -> PROPN (proper noun) -> PROPN
# 'aventuras' -> NOUN (noun) -> NOUN
# 'na' -> AUX (auxiliary) -> AUX
# 'historia' -> PROPN (proper noun) -> PROPN
# 'rolling' -> PROPN (proper noun) -> PROPN
# 'stone' -> PROPN (proper noun) -> PROPN
# 'sport' -> PROPN (proper noun) -> PROPN
# 'buzz' -> PROPN (proper noun) -> PROPN
# 'recreio' -> PROPN (proper noun) -> PROPN
# 'maxima' -> PROPN (proper noun) -> PROPN
# 'canales' -> PROPN (proper noun) -> PROPN
# 'rss' -> PROPN (proper noun) -> PROPN
# 'contáctenos' -> ADJ (adjective) -> ADJ
# 'privacidad' -> NOUN (noun) -> NOUN
# 'equipo' -> NOUN (noun) -> NOUN
# 'reglas' -> NOUN (noun) -> NOUN
# 'participación' -> ADJ (adjective) -> ADJ
# 'tránsito' -> NOUN (noun) -> NOUN
# 'perfilcom' -> ADJ (adjective) -> ADJ
# 'editorial' -> PROPN (proper noun) -> PROPN
# 'perfil' -> PROPN (proper noun) -> PROPN
# 'sa' -> PROPN (proper noun) -> PROPN
# 'perfilcom' -> VERB (verb) -> VERB
# '20062025' -> NUM (numeral) -> NUM
# 'derechos' -> NOUN (noun) -> NOUN
# 'reservados' -> ADJ (adjective) -> ADJ
# 'editor' -> NOUN (noun) -> NOUN
# 'responsable' -> ADJ (adjective) -> ADJ
# 'carlos' -> PROPN (proper noun) -> PROPN
# 'piro' -> PROPN (proper noun) -> PROPN
# 'registro' -> PROPN (proper noun) -> PROPN
# 'propiedad' -> NOUN (noun) -> NOUN
# 'intelectual' -> ADJ (adjective) -> ADJ
# 'rl202431002957apndndamj' -> VERB (verb) -> VERB
# 'dirección' -> NOUN (noun) -> NOUN
# 'california' -> PROPN (proper noun) -> PROPN
# '2715' -> NUM (numeral) -> NUM
# 'c1289abi' -> NOUN (noun) -> NOUN
# 'caba' -> VERB (verb) -> VERB
# 'argentina' -> ADJ (adjective) -> ADJ
# 'teléfono' -> NOUN (noun) -> NOUN
# '5411' -> NUM (numeral) -> NUM
# '70914921' -> NUM (numeral) -> NUM
# '5411' -> NUM (numeral) -> NUM
# '70914922' -> NUM (numeral) -> NUM
# 'email' -> PROPN (proper noun) -> PROPN
# 'email' -> PROPN (proper noun) -> PROPN
# 'protected' -> PROPN (proper noun) -> PROPN

# %%
# Analisis de dependencia sintactica
for token in doc:
     if not token.is_space:
        print(f"'{token.text}' -> {token.dep_} ({spacy.explain(token.dep_)}) -> '{token.head.text}'")
# Out:
# 'mujer' -> nsubj (nominal subject) -> 'volvió'
# 'cuadripléjica' -> amod (adjectival modifier) -> 'mujer'
# 'volvió' -> ROOT (root) -> 'volvió'
# 'hablar' -> xcomp (open clausal complement) -> 'volvió'
# 'tras' -> case (case marking) -> 'años'
# '18' -> nummod (numeric modifier) -> 'años'
# 'años' -> obl (oblique nominal) -> 'volvió'
# 'gracias' -> case (case marking) -> 'inteligencia'
# 'inteligencia' -> obl (oblique nominal) -> 'volvió'
# 'artificial' -> amod (adjectival modifier) -> 'inteligencia'
# 'perfil' -> appos (appositional modifier) -> 'inteligencia'
# 'jueves' -> appos (appositional modifier) -> 'perfil'
# '03' -> compound (compound) -> 'jueves'
# 'abril' -> compound (compound) -> 'jueves'
# '2025' -> compound (compound) -> 'jueves'
# 'business' -> compound (compound) -> 'jueves'
# 'noticias' -> obj (object) -> 'hablar'
# 'caras' -> amod (adjectival modifier) -> 'noticias'
# 'exitoína' -> xcomp (open clausal complement) -> 'volvió'
# 'perfil' -> obj (object) -> 'exitoína'
# 'brasil' -> appos (appositional modifier) -> 'perfil'
# 'últimas' -> amod (adjectival modifier) -> 'noticias'
# 'noticias' -> obl (oblique nominal) -> 'volvió'
# 'política' -> amod (adjectival modifier) -> 'noticias'
# 'opinión' -> appos (appositional modifier) -> 'noticias'
# 'sociedad' -> amod (adjectival modifier) -> 'opinión'
# 'ingresar' -> acl (clausal modifier of noun (adjectival clause)) -> 'noticias'
# 'suscribite' -> obj (object) -> 'ingresar'
# '20día' -> nmod (modifier of nominal) -> 'secciones'
# 'último' -> amod (adjectival modifier) -> 'momento'
# 'momento' -> nmod (modifier of nominal) -> '20día'
# 'secciones' -> obj (object) -> 'ingresar'
# 'ahora' -> advmod (adverbial modifier) -> 'columnistas'
# 'columnistas' -> nsubj (nominal subject) -> 'volvió'
# 'opinión' -> obj (object) -> 'columnistas'
# 'política' -> amod (adjectival modifier) -> 'opinión'
# 'economía' -> amod (adjectival modifier) -> 'columnistas'
# 'pymes' -> amod (adjectival modifier) -> 'columnistas'
# 'sociedad' -> obj (object) -> 'pymes'
# 'salud' -> flat (flat multiword expression) -> 'sociedad'
# 'ciencia' -> nmod (modifier of nominal) -> 'columnistas'
# 'protagonistas' -> amod (adjectival modifier) -> 'columnistas'
# 'tecnología' -> amod (adjectival modifier) -> 'columnistas'
# 'cultura' -> amod (adjectival modifier) -> 'columnistas'
# 'arte' -> amod (adjectival modifier) -> 'columnistas'
# 'educación' -> obj (object) -> 'columnistas'
# 'internacional' -> flat (flat multiword expression) -> 'educación'
# 'clima' -> flat (flat multiword expression) -> 'educación'
# 'deportes' -> flat (flat multiword expression) -> 'educación'
# 'ocio' -> amod (adjectival modifier) -> 'educación'
# 'caras' -> appos (appositional modifier) -> 'educación'
# 'exitoina' -> amod (adjectival modifier) -> 'caras'
# 'turismo' -> flat (flat multiword expression) -> 'educación'
# 'videos' -> flat (flat multiword expression) -> 'educación'
# 'córdoba' -> flat (flat multiword expression) -> 'educación'
# 'reperfilar' -> advcl (adverbial clause modifier) -> 'columnistas'
# 'business' -> obj (object) -> 'reperfilar'
# 'empresas' -> obj (object) -> 'reperfilar'
# 'protagonistas' -> amod (adjectival modifier) -> 'empresas'
# 'noticias' -> obj (object) -> 'reperfilar'
# 'caras' -> obj (object) -> 'reperfilar'
# 'exitoina' -> amod (adjectival modifier) -> 'caras'
# 'gaming' -> obj (object) -> 'reperfilar'
# 'vivo' -> obj (object) -> 'reperfilar'
# 'diario' -> obj (object) -> 'reperfilar'
# 'juicio' -> nmod (modifier of nominal) -> 'columnistas'
# 'reperfilar' -> xcomp (open clausal complement) -> 'juicio'
# 'avance' -> obj (object) -> 'reperfilar'
# 'científico' -> amod (adjectival modifier) -> 'avance'
# 'mujer' -> obj (object) -> 'reperfilar'
# 'cuadripléjica' -> amod (adjectival modifier) -> 'mujer'
# 'volvió' -> conj (conjunct) -> 'hablar'
# 'hablar' -> xcomp (open clausal complement) -> 'volvió'
# 'tras' -> case (case marking) -> 'años'
# '18' -> nummod (numeric modifier) -> 'años'
# 'años' -> obl (oblique nominal) -> 'volvió'
# 'gracias' -> case (case marking) -> 'inteligencia'
# 'inteligencia' -> obl (oblique nominal) -> 'volvió'
# 'artificial' -> amod (adjectival modifier) -> 'inteligencia'
# 'publicó' -> advcl (adverbial clause modifier) -> 'hablar'
# 'revista' -> obj (object) -> 'publicó'
# 'científica' -> amod (adjectival modifier) -> 'revista'
# 'nature' -> appos (appositional modifier) -> 'revista'
# 'neuroscience' -> appos (appositional modifier) -> 'revista'
# 'representa' -> advcl (adverbial clause modifier) -> 'volvió'
# 'gran' -> amod (adjectival modifier) -> 'paso'
# 'paso' -> obj (object) -> 'representa'
# 'hacia' -> case (case marking) -> 'recuperación'
# 'recuperación' -> nmod (modifier of nominal) -> 'paso'
# 'comunicación' -> amod (adjectival modifier) -> 'recuperación'
# 'personas' -> appos (appositional modifier) -> 'paso'
# 'parálisis' -> nsubj (nominal subject) -> 'volvió'
# 'severa' -> amod (adjectival modifier) -> 'mujer'
# 'mujer' -> nmod (modifier of nominal) -> 'parálisis'
# 'cuadripléjica' -> amod (adjectival modifier) -> 'mujer'
# 'volvió' -> acl (clausal modifier of noun (adjectival clause)) -> 'paso'
# 'hablar' -> xcomp (open clausal complement) -> 'volvió'
# 'tras' -> case (case marking) -> 'años'
# '18' -> nummod (numeric modifier) -> 'años'
# 'años' -> obl (oblique nominal) -> 'volvió'
# 'gracias' -> case (case marking) -> 'inteligencia'
# 'inteligencia' -> obl (oblique nominal) -> 'volvió'
# 'artificial' -> amod (adjectival modifier) -> 'inteligencia'
# 'freepick' -> appos (appositional modifier) -> 'inteligencia'
# 'ayer' -> advmod (adverbial modifier) -> 'inteligencia'
# '1105' -> nummod (numeric modifier) -> 'inteligencia'
# 'ann' -> flat (flat multiword expression) -> '1105'
# 'mujer' -> flat (flat multiword expression) -> '1105'
# '47' -> nummod (numeric modifier) -> 'años'
# 'años' -> obl (oblique nominal) -> 'volvió'
# 'cuadriplejía' -> conj (conjunct) -> 'hablar'
# 'logró' -> advcl (adverbial clause modifier) -> 'volvió'
# 'hablar' -> xcomp (open clausal complement) -> 'logró'
# 'nuevamente' -> advmod (adverbial modifier) -> 'hablar'
# '18' -> nummod (numeric modifier) -> 'años'
# 'años' -> obj (object) -> 'hablar'
# 'gracias' -> case (case marking) -> 'neuroprótesis'
# 'neuroprótesis' -> obl (oblique nominal) -> 'hablar'
# 'impulsada' -> amod (adjectival modifier) -> 'neuroprótesis'
# 'inteligencia' -> obj (object) -> 'impulsada'
# 'artificial' -> amod (adjectival modifier) -> 'inteligencia'
# 'ia' -> dep (unclassified dependent) -> 'logró'
# 'avances' -> obj (object) -> 'logró'
# 'significativos' -> amod (adjectival modifier) -> 'campo'
# 'campo' -> nmod (modifier of nominal) -> 'avances'
# 'interfaces' -> amod (adjectival modifier) -> 'campo'
# 'cerebrocomputadora' -> amod (adjectival modifier) -> 'campo'
# 'procedimiento' -> appos (appositional modifier) -> 'campo'
# 'desarrollado' -> amod (adjectival modifier) -> 'campo'
# 'investigadores' -> nmod (modifier of nominal) -> 'avances'
# 'universidad' -> appos (appositional modifier) -> 'avances'
# 'california' -> flat (flat multiword expression) -> 'universidad'
# 'berkeley' -> flat (flat multiword expression) -> 'universidad'
# 'san' -> flat (flat multiword expression) -> 'universidad'
# 'francisco' -> flat (flat multiword expression) -> 'universidad'
# 'publicó' -> advcl (adverbial clause modifier) -> 'volvió'
# 'revista' -> obj (object) -> 'publicó'
# 'científica' -> amod (adjectival modifier) -> 'revista'
# 'nature' -> appos (appositional modifier) -> 'revista'
# 'neuroscience' -> appos (appositional modifier) -> 'revista'
# 'representa' -> advcl (adverbial clause modifier) -> 'volvió'
# 'gran' -> amod (adjectival modifier) -> 'paso'
# 'paso' -> obj (object) -> 'representa'
# 'hacia' -> case (case marking) -> 'recuperación'
# 'recuperación' -> nmod (modifier of nominal) -> 'paso'
# 'comunicación' -> amod (adjectival modifier) -> 'recuperación'
# 'personas' -> appos (appositional modifier) -> 'paso'
# 'parálisis' -> nsubj (nominal subject) -> 'hizo'
# 'severa' -> amod (adjectival modifier) -> 'parálisis'
# 'dispositivo' -> nmod (modifier of nominal) -> 'parálisis'
# 'hizo' -> acl (clausal modifier of noun (adjectival clause)) -> 'paso'
# 'posible' -> amod (adjectival modifier) -> 'hito'
# 'hito' -> obj (object) -> 'hizo'
# 'consiste' -> advcl (adverbial clause modifier) -> 'volvió'
# 'lámina' -> obj (object) -> 'consiste'
# 'delgada' -> amod (adjectival modifier) -> 'lámina'
# '253' -> nummod (numeric modifier) -> 'electrodos'
# 'electrodos' -> nsubj (nominal subject) -> 'registró'
# 'implantada' -> amod (adjectival modifier) -> 'electrodos'
# 'corteza' -> obj (object) -> 'implantada'
# 'cerebral' -> amod (adjectival modifier) -> 'corteza'
# 'ann' -> appos (appositional modifier) -> 'corteza'
# 'neuroprótesis' -> amod (adjectival modifier) -> 'corteza'
# 'registró' -> conj (conjunct) -> 'volvió'
# 'actividad' -> obj (object) -> 'registró'
# 'neuronal' -> amod (adjectival modifier) -> 'actividad'
# 'envió' -> advcl (adverbial clause modifier) -> 'registró'
# 'señales' -> obj (object) -> 'envió'
# 'computadora' -> amod (adjectival modifier) -> 'señales'
# 'transformó' -> advcl (adverbial clause modifier) -> 'envió'
# 'pensamientos' -> obj (object) -> 'transformó'
# 'palabras' -> nmod (modifier of nominal) -> 'pensamientos'
# 'audibles' -> amod (adjectival modifier) -> 'palabras'
# 'voz' -> appos (appositional modifier) -> 'pensamientos'
# 'artificial' -> amod (adjectival modifier) -> 'voz'
# 'personalizada' -> amod (adjectival modifier) -> 'voz'
# 'reconstruir' -> advcl (adverbial clause modifier) -> 'transformó'
# 'tono' -> obj (object) -> 'reconstruir'
# 'original' -> amod (adjectival modifier) -> 'tono'
# 'investigadores' -> nsubj (nominal subject) -> 'utilizaron'
# 'utilizaron' -> advcl (adverbial clause modifier) -> 'registró'
# 'grabaciones' -> obj (object) -> 'utilizaron'
# 'video' -> amod (adjectival modifier) -> 'grabaciones'
# 'boda' -> appos (appositional modifier) -> 'grabaciones'
# 'ann' -> flat (flat multiword expression) -> 'boda'
# 'sufriera' -> acl (clausal modifier of noun (adjectival clause)) -> 'grabaciones'
# 'accidente' -> obj (object) -> 'sufriera'
# 'cerebrovascular' -> amod (adjectival modifier) -> 'accidente'
# 'acv' -> obl (oblique nominal) -> 'sufriera'
# '30' -> nummod (numeric modifier) -> 'años'
# 'años' -> obl (oblique nominal) -> 'sufriera'
# 'quitó' -> advcl (adverbial clause modifier) -> 'registró'
# 'capacidad' -> obj (object) -> 'quitó'
# 'hablar' -> advcl (adverbial clause modifier) -> 'quitó'
# 'moverse' -> xcomp (open clausal complement) -> 'hablar'
# 'diferencia' -> obj (object) -> 'hablar'
# 'sistemas' -> obj (object) -> 'hablar'
# 'anteriores' -> amod (adjectival modifier) -> 'sistemas'
# 'solo' -> amod (adjectival modifier) -> 'sistemas'
# 'generaban' -> advcl (adverbial clause modifier) -> 'quitó'
# 'sonido' -> obj (object) -> 'generaban'
# 'vez' -> advmod (adverbial modifier) -> 'generaban'
# 'paciente' -> obj (object) -> 'generaban'
# 'terminaba' -> advcl (adverbial clause modifier) -> 'generaban'
# 'frase' -> obj (object) -> 'terminaba'
# 'entera' -> amod (adjectival modifier) -> 'frase'
# 'nueva' -> amod (adjectival modifier) -> 'interfaz'
# 'interfaz' -> appos (appositional modifier) -> 'frase'
# 'cerebrocomputadora' -> amod (adjectival modifier) -> 'frase'
# 'permite' -> advcl (adverbial clause modifier) -> 'registró'
# 'convertir' -> xcomp (open clausal complement) -> 'permite'
# 'pensamientos' -> obj (object) -> 'convertir'
# 'voz' -> amod (adjectival modifier) -> 'pensamientos'
# 'apenas' -> advmod (adverbial modifier) -> 'segundos'
# 'tres' -> nummod (numeric modifier) -> 'segundos'
# 'segundos' -> amod (adjectival modifier) -> 'tiempo'
# 'casi' -> advmod (adverbial modifier) -> 'tiempo'
# 'tiempo' -> obj (object) -> 'convertir'
# 'real' -> amod (adjectival modifier) -> 'tiempo'
# 'científicos' -> amod (adjectival modifier) -> 'tiempo'
# 'explicaron' -> advcl (adverbial clause modifier) -> 'registró'
# 'avance' -> obj (object) -> 'explicaron'
# 'tecnológico' -> amod (adjectival modifier) -> 'avance'
# 'mejora' -> obj (object) -> 'explicaron'
# 'notablemente' -> advmod (adverbial modifier) -> 'flujo'
# 'flujo' -> appos (appositional modifier) -> 'mejora'
# 'natural' -> amod (adjectival modifier) -> 'conversación'
# 'conversación' -> obj (object) -> 'explicaron'
# 'esencial' -> amod (adjectival modifier) -> 'conversación'
# 'personas' -> nsubj (nominal subject) -> 'interactuar'
# 'parálisis' -> amod (adjectival modifier) -> 'personas'
# 'puedan' -> aux (auxiliary) -> 'interactuar'
# 'interactuar' -> acl (clausal modifier of noun (adjectival clause)) -> 'conversación'
# 'entorno' -> obj (object) -> 'interactuar'
# 'sentirse' -> xcomp (open clausal complement) -> 'interactuar'
# 'aisladas' -> obj (object) -> 'sentirse'
# 'frustradas' -> advmod (adverbial modifier) -> 'sentirse'
# 'gusta' -> advcl (adverbial clause modifier) -> 'explicaron'
# 'autoritarios' -> amod (adjectival modifier) -> 'ejercicio'
# 'ejercicio' -> nsubj (nominal subject) -> 'gusta'
# 'periodismo' -> amod (adjectival modifier) -> 'ejercicio'
# 'profesional' -> amod (adjectival modifier) -> 'ejercicio'
# 'crítico' -> amod (adjectival modifier) -> 'ejercicio'
# 'pilar' -> appos (appositional modifier) -> 'ejercicio'
# 'fundamental' -> amod (adjectival modifier) -> 'pilar'
# 'democracia' -> amod (adjectival modifier) -> 'pilar'
# 'molesta' -> amod (adjectival modifier) -> 'democracia'
# 'creen' -> advcl (adverbial clause modifier) -> 'explicaron'
# 'ser' -> cop (copula) -> 'dueños'
# 'dueños' -> xcomp (open clausal complement) -> 'creen'
# 'verdad' -> nmod (modifier of nominal) -> 'dueños'
# 'hoy' -> advmod (adverbial modifier) -> 'suscribite'
# 'nunca' -> advmod (adverbial modifier) -> 'suscribite'
# 'suscribite' -> ccomp (clausal complement) -> 'creen'
# 'entrenamiento' -> nsubj (nominal subject) -> 'suscribite'
# 'sistema' -> nsubj (nominal subject) -> 'suscribite'
# 'ann' -> flat (flat multiword expression) -> 'sistema'
# 'leyó' -> ccomp (clausal complement) -> 'creen'
# 'mentalmente' -> advmod (adverbial modifier) -> 'leyó'
# 'alrededor' -> advmod (adverbial modifier) -> 'frases'
# '100' -> nummod (numeric modifier) -> 'frases'
# 'frases' -> obj (object) -> 'leyó'
# 'seleccionadas' -> amod (adjectival modifier) -> 'frases'
# 'conjunto' -> amod (adjectival modifier) -> 'frases'
# 'mil' -> nummod (numeric modifier) -> 'oraciones'
# 'oraciones' -> nsubj (nominal subject) -> 'registraba'
# 'dispositivo' -> amod (adjectival modifier) -> 'oraciones'
# 'registraba' -> acl (clausal modifier of noun (adjectival clause)) -> 'frases'
# 'actividad' -> obj (object) -> 'registraba'
# 'cerebral' -> amod (adjectival modifier) -> 'actividad'
# 'cada' -> det (determiner) -> 'milisegundos'
# '80' -> nummod (numeric modifier) -> 'milisegundos'
# 'milisegundos' -> obj (object) -> 'registraba'
# 'incluso' -> advmod (adverbial modifier) -> 'comenzando'
# 'comenzando' -> advcl (adverbial clause modifier) -> 'registraba'
# 'medio' -> obj (object) -> 'comenzando'
# 'segundo' -> advmod (adverbial modifier) -> 'comenzando'
# 'intentara' -> advcl (adverbial clause modifier) -> 'registraba'
# 'articular' -> xcomp (open clausal complement) -> 'intentara'
# 'palabras' -> obj (object) -> 'articular'
# 'manera' -> case (case marking) -> 'modelo'
# 'silenciosa' -> amod (adjectival modifier) -> 'modelo'
# 'modelo' -> obj (object) -> 'articular'
# 'logró' -> advcl (adverbial clause modifier) -> 'leyó'
# 'generar' -> xcomp (open clausal complement) -> 'logró'
# '47' -> nmod (modifier of nominal) -> '90'
# '90' -> nummod (numeric modifier) -> 'palabras'
# 'palabras' -> obj (object) -> 'generar'
# 'minuto' -> amod (adjectival modifier) -> 'palabras'
# 'cifra' -> amod (adjectival modifier) -> 'palabras'
# 'bien' -> advmod (adverbial modifier) -> 'generar'
# 'alcanza' -> advcl (adverbial clause modifier) -> 'generar'
# 'velocidad' -> obj (object) -> 'alcanza'
# 'conversación' -> obj (object) -> 'alcanza'
# 'típica' -> amod (adjectival modifier) -> 'conversación'
# 'ronda' -> obl (oblique nominal) -> 'generar'
# '160' -> nummod (numeric modifier) -> 'palabras'
# 'palabras' -> nsubj (nominal subject) -> 'supera'
# 'minuto' -> amod (adjectival modifier) -> 'palabras'
# 'supera' -> advcl (adverbial clause modifier) -> 'generar'
# 'ampliamente' -> advmod (adverbial modifier) -> 'logrado'
# 'logrado' -> obj (object) -> 'supera'
# 'ahora' -> advmod (adverbial modifier) -> 'logrado'
# 'tipo' -> nsubj (nominal subject) -> 'basó'
# 'tecnología' -> amod (adjectival modifier) -> 'tipo'
# 'avance' -> amod (adjectival modifier) -> 'tipo'
# 'basó' -> advcl (adverbial clause modifier) -> 'leyó'
# 'algoritmos' -> obj (object) -> 'basó'
# 'inteligencia' -> nmod (modifier of nominal) -> 'algoritmos'
# 'artificial' -> amod (adjectival modifier) -> 'inteligencia'
# 'similares' -> amod (adjectival modifier) -> 'inteligencia'
# 'utilizan' -> advcl (adverbial clause modifier) -> 'basó'
# 'asistentes' -> obj (object) -> 'utilizan'
# 'virtuales' -> amod (adjectival modifier) -> 'asistentes'
# 'siri' -> appos (appositional modifier) -> 'asistentes'
# 'alexa' -> flat (flat multiword expression) -> 'siri'
# 'adaptados' -> amod (adjectival modifier) -> 'asistentes'
# 'decodificar' -> xcomp (open clausal complement) -> 'adaptados'
# 'tiempo' -> obj (object) -> 'decodificar'
# 'real' -> amod (adjectival modifier) -> 'tiempo'
# 'señales' -> obj (object) -> 'decodificar'
# 'cerebrales' -> amod (adjectival modifier) -> 'señales'
# 'investigadores' -> obj (object) -> 'decodificar'
# 'explicaron' -> advcl (adverbial clause modifier) -> 'leyó'
# 'mismo' -> det (determiner) -> 'algoritmo'
# 'algoritmo' -> obj (object) -> 'explicaron'
# 'podría' -> aux (auxiliary) -> 'usarse'
# 'usarse' -> xcomp (open clausal complement) -> 'explicaron'
# 'distintos' -> det (determiner) -> 'dispositivos'
# 'dispositivos' -> obj (object) -> 'usarse'
# 'siempre' -> advmod (adverbial modifier) -> 'buena'
# 'buena' -> amod (adjectival modifier) -> 'calidad'
# 'calidad' -> obj (object) -> 'usarse'
# 'señal' -> amod (adjectival modifier) -> 'calidad'
# 'neuronal' -> amod (adjectival modifier) -> 'señal'
# 'además' -> advmod (adverbial modifier) -> 'equipo'
# 'equipo' -> nsubj (nominal subject) -> 'valía'
# 'trabajando' -> acl (clausal modifier of noun (adjectival clause)) -> 'equipo'
# 'mejorar' -> xcomp (open clausal complement) -> 'trabajando'
# 'expresividad' -> obj (object) -> 'mejorar'
# 'voz' -> obj (object) -> 'mejorar'
# 'sintetizada' -> obj (object) -> 'mejorar'
# 'incorporando' -> advcl (adverbial clause modifier) -> 'mejorar'
# 'matices' -> obj (object) -> 'incorporando'
# 'emocionales' -> amod (adjectival modifier) -> 'matices'
# 'variaciones' -> obj (object) -> 'incorporando'
# 'tono' -> nmod (modifier of nominal) -> 'variaciones'
# 'timbre' -> nmod (modifier of nominal) -> 'variaciones'
# 'volumen' -> amod (adjectival modifier) -> 'variaciones'
# 'ann' -> flat (flat multiword expression) -> 'volumen'
# 'participado' -> amod (adjectival modifier) -> 'estudios'
# 'estudios' -> obj (object) -> 'incorporando'
# 'anteriores' -> amod (adjectival modifier) -> 'tecnologías'
# 'tecnologías' -> nmod (modifier of nominal) -> 'estudios'
# 'similares' -> amod (adjectival modifier) -> 'tecnologías'
# 'ninguna' -> det (determiner) -> 'comunicación'
# 'logrado' -> amod (adjectival modifier) -> 'comunicación'
# 'comunicación' -> appos (appositional modifier) -> 'estudios'
# 'fluida' -> amod (adjectival modifier) -> 'comunicación'
# 'ahora' -> advmod (adverbial modifier) -> 'valía'
# 'valía' -> conj (conjunct) -> 'explicaron'
# 'sistema' -> obj (object) -> 'valía'
# 'asistencia' -> obj (object) -> 'valía'
# 'llevaba' -> advcl (adverbial clause modifier) -> 'valía'
# '20' -> nummod (numeric modifier) -> 'segundos'
# 'segundos' -> obj (object) -> 'llevaba'
# 'emitir' -> xcomp (open clausal complement) -> 'llevaba'
# 'sola' -> amod (adjectival modifier) -> 'frase'
# 'frase' -> obj (object) -> 'emitir'
# 'nueva' -> amod (adjectival modifier) -> 'herramienta'
# 'herramienta' -> obj (object) -> 'emitir'
# 'solo' -> amod (adjectival modifier) -> 'herramienta'
# 'recuperó' -> advcl (adverbial clause modifier) -> 'volvió'
# 'parte' -> obj (object) -> 'recuperó'
# 'capacidad' -> amod (adjectival modifier) -> 'parte'
# 'comunicarse' -> advcl (adverbial clause modifier) -> 'recuperó'
# 'parte' -> obj (object) -> 'comunicarse'
# 'fundamental' -> amod (adjectival modifier) -> 'parte'
# 'identidad' -> appos (appositional modifier) -> 'parte'
# 'voz' -> amod (adjectival modifier) -> 'parte'
# 'desarrollo' -> appos (appositional modifier) -> 'parte'
# 'representa' -> advcl (adverbial clause modifier) -> 'volvió'
# 'paso' -> obj (object) -> 'representa'
# 'clave' -> nmod (modifier of nominal) -> 'paso'
# 'hacia' -> case (case marking) -> 'inclusión'
# 'inclusión' -> nmod (modifier of nominal) -> 'paso'
# 'dignidad' -> nmod (modifier of nominal) -> 'inclusión'
# 'personas' -> nsubj (nominal subject) -> 'participar'
# 'discapacidades' -> amod (adjectival modifier) -> 'personas'
# 'severas' -> amod (adjectival modifier) -> 'personas'
# 'abriendo' -> advcl (adverbial clause modifier) -> 'severas'
# 'nuevas' -> amod (adjectival modifier) -> 'oportunidades'
# 'oportunidades' -> obj (object) -> 'abriendo'
# 'puedan' -> aux (auxiliary) -> 'participar'
# 'participar' -> xcomp (open clausal complement) -> 'volvió'
# 'activamente' -> advmod (adverbial modifier) -> 'participar'
# 'conversaciones' -> obj (object) -> 'participar'
# 'cotidianas' -> amod (adjectival modifier) -> 'conversaciones'
# 'todavía' -> advmod (adverbial modifier) -> 'etapa'
# 'etapa' -> obj (object) -> 'participar'
# 'experimental' -> amod (adjectival modifier) -> 'éxito'
# 'éxito' -> nmod (modifier of nominal) -> 'etapa'
# 'tecnología' -> amod (adjectival modifier) -> 'éxito'
# 'alimenta' -> conj (conjunct) -> 'hablar'
# 'esperanza' -> obj (object) -> 'alimenta'
# 'pronto' -> advmod (adverbial modifier) -> 'esperanza'
# 'pacientes' -> nsubj (nominal subject) -> 'beneficiarse'
# 'puedan' -> aux (auxiliary) -> 'beneficiarse'
# 'beneficiarse' -> xcomp (open clausal complement) -> 'alimenta'
# 'soluciones' -> obj (object) -> 'beneficiarse'
# 'similares' -> amod (adjectival modifier) -> 'soluciones'
# 'puede' -> aux (auxiliary) -> 'interesar'
# 'interesar' -> advcl (adverbial clause modifier) -> 'volvió'
# 'quiénes' -> det (determiner) -> 'argentinos'
# 'seis' -> nummod (numeric modifier) -> 'argentinos'
# 'argentinos' -> nsubj (nominal subject) -> 'comenzó'
# 'ricos' -> amod (adjectival modifier) -> 'argentinos'
# 'mundo' -> amod (adjectival modifier) -> 'argentinos'
# 'comenzó' -> conj (conjunct) -> 'volvió'
# 'vacunación' -> obj (object) -> 'comenzó'
# 'gripe' -> nsubj (nominal subject) -> 'caba'
# 'caba' -> advcl (adverbial clause modifier) -> 'comenzó'
# 'mujer' -> obj (object) -> 'caba'
# 'cuadripléjica' -> amod (adjectival modifier) -> 'mujer'
# 'volvió' -> advcl (adverbial clause modifier) -> 'comenzó'
# 'hablar' -> xcomp (open clausal complement) -> 'volvió'
# 'inteligencia' -> obj (object) -> 'hablar'
# 'artificial' -> amod (adjectival modifier) -> 'inteligencia'
# '18' -> nummod (numeric modifier) -> 'años'
# 'años' -> obj (object) -> 'hablar'
# 'córdoba' -> flat (flat multiword expression) -> 'años'
# 'cárcel' -> obj (object) -> 'hablar'
# 'máxima' -> amod (adjectival modifier) -> 'cárcel'
# 'seguridad' -> nsubj (nominal subject) -> 'construirá'
# 'construirá' -> advcl (adverbial clause modifier) -> 'volvió'
# '1000' -> nummod (numeric modifier) -> 'presos'
# 'presos' -> obj (object) -> 'construirá'
# 'nota' -> amod (adjectival modifier) -> 'presos'
# 'inteligencia' -> obj (object) -> 'nota'
# 'artificial' -> amod (adjectival modifier) -> 'inteligencia'
# 'mujer' -> appos (appositional modifier) -> 'presos'
# 'cuadripléjica' -> amod (adjectival modifier) -> 'mujer'
# 'ahora' -> advmod (adverbial modifier) -> 'columnistas'
# 'columnistas' -> appos (appositional modifier) -> 'presos'
# 'política' -> amod (adjectival modifier) -> 'columnistas'
# 'economía' -> amod (adjectival modifier) -> 'columnistas'
# 'sociedad' -> appos (appositional modifier) -> 'columnistas'
# 'internacional' -> flat (flat multiword expression) -> 'sociedad'
# 'clima' -> flat (flat multiword expression) -> 'sociedad'
# 'deportes' -> flat (flat multiword expression) -> 'sociedad'
# 'ocio' -> flat (flat multiword expression) -> 'sociedad'
# 'córdoba' -> flat (flat multiword expression) -> 'sociedad'
# 'reperfilar' -> advcl (adverbial clause modifier) -> 'construirá'
# 'business' -> obj (object) -> 'reperfilar'
# 'empresas' -> obj (object) -> 'reperfilar'
# 'protagonistas' -> amod (adjectival modifier) -> 'empresas'
# 'noticias' -> obj (object) -> 'reperfilar'
# 'caras' -> obj (object) -> 'reperfilar'
# 'exitoina' -> amod (adjectival modifier) -> 'caras'
# 'gaming' -> obj (object) -> 'reperfilar'
# 'vivo' -> amod (adjectival modifier) -> 'gaming'
# 'diario' -> obj (object) -> 'reperfilar'
# 'juicio' -> compound (compound) -> 'construirá'
# 'caras' -> obj (object) -> 'construirá'
# 'noticias' -> obj (object) -> 'construirá'
# 'weekend' -> flat (flat multiword expression) -> 'noticias'
# 'fortuna' -> flat (flat multiword expression) -> 'noticias'
# 'parabrisas' -> amod (adjectival modifier) -> 'noticias'
# 'rouge' -> flat (flat multiword expression) -> 'noticias'
# 'batimes' -> amod (adjectival modifier) -> 'noticias'
# 'fm' -> case (case marking) -> 'horizonte'
# 'horizonte' -> nmod (modifier of nominal) -> 'noticias'
# 'perfil' -> obj (object) -> 'construirá'
# 'brasil' -> flat (flat multiword expression) -> 'perfil'
# 'caras' -> obj (object) -> 'construirá'
# 'contigo' -> obj (object) -> 'construirá'
# 'aventuras' -> obj (object) -> 'construirá'
# 'na' -> fixed (fixed multiword expression) -> 'aventuras'
# 'historia' -> obl (oblique nominal) -> 'construirá'
# 'rolling' -> flat (flat multiword expression) -> 'historia'
# 'stone' -> flat (flat multiword expression) -> 'historia'
# 'sport' -> flat (flat multiword expression) -> 'historia'
# 'buzz' -> conj (conjunct) -> 'historia'
# 'recreio' -> flat (flat multiword expression) -> 'historia'
# 'maxima' -> flat (flat multiword expression) -> 'historia'
# 'canales' -> obj (object) -> 'construirá'
# 'rss' -> flat (flat multiword expression) -> 'canales'
# 'contáctenos' -> amod (adjectival modifier) -> 'canales'
# 'privacidad' -> nmod (modifier of nominal) -> 'canales'
# 'equipo' -> amod (adjectival modifier) -> 'canales'
# 'reglas' -> nsubj (nominal subject) -> 'perfilcom'
# 'participación' -> amod (adjectival modifier) -> 'reglas'
# 'tránsito' -> nmod (modifier of nominal) -> 'reglas'
# 'perfilcom' -> amod (adjectival modifier) -> 'reglas'
# 'editorial' -> obj (object) -> 'perfilcom'
# 'perfil' -> obj (object) -> 'perfilcom'
# 'sa' -> flat (flat multiword expression) -> 'perfil'
# 'perfilcom' -> advcl (adverbial clause modifier) -> 'construirá'
# '20062025' -> nummod (numeric modifier) -> 'derechos'
# 'derechos' -> obj (object) -> 'perfilcom'
# 'reservados' -> amod (adjectival modifier) -> 'derechos'
# 'editor' -> nmod (modifier of nominal) -> 'derechos'
# 'responsable' -> amod (adjectival modifier) -> 'editor'
# 'carlos' -> appos (appositional modifier) -> 'editor'
# 'piro' -> flat (flat multiword expression) -> 'carlos'
# 'registro' -> flat (flat multiword expression) -> 'carlos'
# 'propiedad' -> flat (flat multiword expression) -> 'carlos'
# 'intelectual' -> amod (adjectival modifier) -> 'propiedad'
# 'rl202431002957apndndamj' -> conj (conjunct) -> 'hablar'
# 'dirección' -> obj (object) -> 'rl202431002957apndndamj'
# 'california' -> obj (object) -> 'rl202431002957apndndamj'
# '2715' -> obl (oblique nominal) -> 'rl202431002957apndndamj'
# 'c1289abi' -> obj (object) -> 'rl202431002957apndndamj'
# 'caba' -> advcl (adverbial clause modifier) -> 'hablar'
# 'argentina' -> amod (adjectival modifier) -> 'caba'
# 'teléfono' -> obl (oblique nominal) -> 'volvió'
# '5411' -> appos (appositional modifier) -> 'teléfono'
# '70914921' -> nummod (numeric modifier) -> '5411'
# '5411' -> nmod (modifier of nominal) -> '70914922'
# '70914922' -> det (determiner) -> 'email'
# 'email' -> ROOT (root) -> 'email'
# 'email' -> appos (appositional modifier) -> 'email'
# 'protected' -> appos (appositional modifier) -> 'email'

# %%
displacy.render(doc, style ="dep", jupyter=True, options={"distance": 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="es" id="5f2795f0cb434960960a87c78d3c5e71-0" class="displacy" width="62810" height="1817.0" direction="ltr" style="max-width: none; height: 1817.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1727.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">mujer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1727.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">cuadripléjica</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1727.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">volvió</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1727.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">hablar</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1727.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">tras</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1727.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">18</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1727.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">años</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1727.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">gracias</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1727.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">inteligencia</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1727.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">artificial</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1727.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">perfil</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1727.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">jueves</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1727.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">03</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1727.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">abril</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1727.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">2025</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1727.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">business</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1727.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">noticias</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1727.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">caras</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1727.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">exitoína</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1727.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">perfil</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1727.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">brasil</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1727.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">últimas</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1727.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">noticias</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1727.0">
#     <tspan class="displacy-word" fill="currentColor" x="2810">política</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2810">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1727.0">
#     <tspan class="displacy-word" fill="currentColor" x="2930">opinión</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2930">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1727.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">sociedad</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1727.0">
#     <tspan class="displacy-word" fill="currentColor" x="3170">ingresar</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3170">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1727.0">
#     <tspan class="displacy-word" fill="currentColor" x="3290">suscribite</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3290">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1727.0">
#     <tspan class="displacy-word" fill="currentColor" x="3410">20día</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3410">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1727.0">
#     <tspan class="displacy-word" fill="currentColor" x="3530">último</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3530">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1727.0">
#     <tspan class="displacy-word" fill="currentColor"

# %%
# Entidades nombradas

if doc.ents:
  print("Entidades encontradas:")
  print("texto de la entidad ... Etiqueta (tipo)")
  for ent in doc.ents:
    print(f"{ent.text} --- {ent.label_} --- {spacy.explain(ent.label_)}")
else:
  print("No se encontraron entidades nombradas")
# Out:
# Entidades encontradas:
# texto de la entidad ... Etiqueta (tipo)
# brasil --- LOC --- Non-GPE locations, mountain ranges, bodies of water
# córdoba --- LOC --- Non-GPE locations, mountain ranges, bodies of water
# nature neuroscience --- PER --- Named person or family.
# freepick --- MISC --- Miscellaneous entities, e.g. events, nationalities, products or works of art
# ann --- PER --- Named person or family.
# cuadriplejía --- PER --- Named person or family.
# california --- LOC --- Non-GPE locations, mountain ranges, bodies of water
# san francisco --- PER --- Named person or family.
# nature neuroscience --- PER --- Named person or family.
# ann neuroprótesis --- PER --- Named person or family.
# ann --- PER --- Named person or family.
# ann --- MISC --- Miscellaneous entities, e.g. events, nationalities, products or works of art
# alexa --- PER --- Named person or family.
# córdoba --- LOC --- Non-GPE locations, mountain ranges, bodies of water
# córdoba --- LOC --- Non-GPE locations, mountain ranges, bodies of water
# weekend --- ORG --- Companies, agencies, institutions, etc.
# brasil --- LOC --- Non-GPE locations, mountain ranges, bodies of water
# na historia rolling stone sport buzz --- MISC --- Miscellaneous entities, e.g. events, nationalities, products or works of art
# perfil sa perfilcom 20062025 --- MISC --- Miscellaneous entities, e.g. events, nationalities, products or works of art
# carlos piro --- PER --- Named person or family.
# california 2715 --- ORG --- Companies, agencies, institutions, etc.
# c1289abi --- PER --- Named person or family.
# argentina --- LOC --- Non-GPE locations, mountain ranges, bodies of water

# %%
displacy.render(doc, style="ent", jupyter=True, options={"distance": 200})
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">mujer cuadripléjica volvió hablar tras 18 años gracias inteligencia artificial perfil jueves 03 abril 2025 business noticias caras exitoína perfil
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     brasil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  últimas noticias política opinión sociedad ingresar suscribite 20día último momento secciones ahora columnistas opinión política economía pymes sociedad salud ciencia protagonistas tecnología cultura arte educación internacional clima deportes ocio caras exitoina turismo videos
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     córdoba
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  reperfilar business empresas protagonistas noticias caras exitoina gaming vivo diario juicio reperfilar avance científico mujer cuadripléjica volvió hablar tras 18 años gracias inteligencia artificial publicó revista científica
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nature neuroscience
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  representa gran paso hacia recuperación comunicación personas parálisis severa mujer cuadripléjica volvió hablar tras 18 años gracias inteligencia artificial
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     freepick
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  ayer 1105
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ann
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  mujer 47 años
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cuadriplejía
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  logró hablar nuevamente 18 años gracias neuroprótesis impulsada inteligencia artificial ia avances significativos campo interfaces cerebrocomputadora procedimiento desarrollado investigadores universidad
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     california
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  berkeley
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     san francisco
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  publicó revista científica
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nature neuroscience
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  representa gran paso hacia recuperación comunicación personas parálisis severa dispositivo hizo posible hito consiste lámina delgada 253 electrodos implantada corteza cerebral
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ann neuroprótesis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  registró actividad neuronal envió señales computadora transformó pensamientos palabras audibles voz artificial personalizada reconstruir tono original investigadores utilizaron grabaciones video boda
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ann
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  sufriera accidente cerebrovascular acv 30 años quitó capacidad hablar moverse diferencia sistemas anteriores solo generaban sonido vez paciente terminaba frase entera nueva interfaz cerebrocomputadora permite convertir pensamientos voz apenas tres segundos casi tiempo real científicos explicaron avance tecnológico mejora notablemente flujo natural conversación esencial personas parálisis puedan interactuar entorno sentirse aisladas frustradas gusta autoritarios ejercicio periodismo profesional crítico pilar fundamental democracia molesta creen ser dueños verdad hoy nunca suscribite entrenamiento sistema
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ann
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  leyó mentalmente alrededor 100 frases seleccionadas conjunto mil oraciones dispositivo registraba actividad cerebral cada 80 milisegundos incluso comenzando medio segundo intentara articular palabras manera silenciosa modelo logró generar 47 90 palabras minuto cifra bien alcanza velocidad conversación típica ronda 160 palabras minuto supera ampliamente logrado ahora tipo tecnología avance basó algoritmos inteligencia artificial similares utilizan asistentes virtuales siri
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     alexa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  adaptados decodificar tiempo real señales cerebrales investigadores explicaron mismo algoritmo podría usarse distintos dispositivos siempre buena calidad señal neuronal además equipo trabajando mejorar expresividad voz sintetizada incorporando matices emocionales variaciones tono timbre volumen ann participado estudios anteriores tecnologías similares ninguna logrado comunicación fluida ahora valía sistema asistencia llevaba 20 segundos emitir sola frase nueva herramienta solo recuperó parte capacidad comunicarse parte fundamental identidad voz desarrollo representa paso clave hacia inclusión dignidad personas discapacidades severas abriendo nuevas oportunidades puedan participar activamente conversaciones cotidianas todavía etapa experimental éxito tecnología alimenta esperanza pronto pacientes puedan beneficiarse soluciones similares puede interesar quiénes seis argentinos ricos mundo comenzó vacunación gripe caba mujer cuadripléjica volvió hablar inteligencia artificial 18 años
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     córdoba
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  cárcel máxima seguridad construirá 1000 presos nota inteligencia artificial mujer cuadripléjica ahora columnistas política economía socied
