# %%
# %pip install -U -q google-genai

# %% [markdown]
# # Procesamiento de Lenguaje Natural con Google Gemini API
# Este script demuestra diversas aplicaciones de PLN utilizando el modelo Gemini de Google a través de la librería `google-generativeai`.

# %%
from google.colab import userdata
import os

GOOGLE_API_KEY = userdata.get('GOOGLE_API_KEY')

from google import genai
from google.genai import types

cliente = genai.Client(api_key=GOOGLE_API_KEY)

# %%
text_to_process = """Estimado Amazon, la semana pasada pedí una figura de acción de Optimus Prime
en su tienda en línea en Alemania. Desafortunadamente, cuando abrí el paquete,
descubrí con horror que me habían enviado una figura de acción de Megatron
en su lugar. Como enemigo de toda la vida de los Decepticons, espero que pueda
entender mi dilema. Para resolver el problema, exijo un cambio de Megatron por
la figura de Optimus Prime que pedí. Adjunto copias de mis registros relativos
a esta compra. Espero tener noticias suyas pronto. Atentamente, Bumblebee."""

print("\nTexto de entrada definido.")

MODEL_ID = "gemini-2.0-flash"

# %%
print("\n📌 Sumarización")
prompt = f"""Sumariza el siguiente texto en dos oraciones de rapida lectura

Texto: {text_to_process}"""
respuesta = cliente.models.generate_content(
    model=MODEL_ID,
    contents=[prompt]
)
print(respuesta.text)

# %%
print("\n📌 Clasificación de Sentimiento")
prompt = f"""Clasificá el siguiente texto como positivo, negativo o neutral y explicá por qué:

Texto: {text_to_process}"""
respuesta = cliente.models.generate_content(
    model=MODEL_ID,
    contents=[prompt]
)
print(respuesta.text)

# %%
print("\n📌 Reconocimiento de Entidades Nombradas (NER)")
prompt = f"""Extraé todas las entidades nombradas del siguiente texto (personas, organizaciones, lugares, objetos) y clasificálas:

Texto: {text_to_process}"""
respuesta = cliente.models.generate_content(
    model=MODEL_ID,
    contents=[prompt]
)
print(respuesta.text)

# %%
print("\n📌 Pregunta y respuesta")
prompt = f"""Respondé la siguiente pregunta basada en el texto:

Texto: text_to_process
Pregunta: ¿Qué producto recibió el cliente?

Texto: {text_to_process}"""
respuesta = cliente.models.generate_content(
    model=MODEL_ID,
    contents=[prompt]
)
print(respuesta.text)

# %%
print("\n📌 Resumen automático")
prompt = f"""Resumí el siguiente texto en no más de 3 líneas:

Texto: {text_to_process}"""
respuesta = cliente.models.generate_content(
    model=MODEL_ID,
    contents=[prompt]
)
print(respuesta.text)

# %%
print("\n📌 Traducción Español-Inglés")
prompt = f"""Traducí al inglés este texto:

Texto: {text_to_process}"""
respuesta = cliente.models.generate_content(
    model=MODEL_ID,
    contents=[prompt]
)
print(respuesta.text)

# %%
print("\n📌 Generación de respuesta")
prompt = f"""Redactá una respuesta del servicio de atención al cliente que comience así:

"Estimado cliente, lamentamos mucho lo ocurrido con su pedido. "

Cuya extension no supere las 4 lineas.

Texto: {text_to_process}"""
respuesta = cliente.models.generate_content(
    model=MODEL_ID,
    contents=[prompt]
)
print(respuesta.text)

# %%
print("\n📌 Clasificación Zero-Shot")
prompt = f"""Clasificá el siguiente texto en una de estas categorías: queja, elogio, consulta, pedido, agradecimiento. Justificá tu elección.

Texto: {text_to_process}"""
respuesta = cliente.models.generate_content(
    model=MODEL_ID,
    contents=[prompt]
)
print(respuesta.text)

# %% [markdown]
# ## Ejercicio: Texto libre sobre experiencia en transporte público

# %%
texto_ejercicio = """
El lunes a las 7 de la mañana tomé el colectivo 60 desde Belgrano hacia el centro.
Estaba lleno, como siempre. Un pasajero empezó a discutir con el chofer porque no le funcionaba la SUBE.
La tensión subió y varias personas intervinieron para calmar la situación.
Finalmente, el colectivero lo dejó subir. Llegué al trabajo con 10 minutos de retraso.
"""
print("Texto de entrada:\n", texto_ejercicio)

# %%
prompt_resumen = f"""Resumí el siguiente texto en no más de 3 líneas:

Texto: {texto_ejercicio}"""
respuesta = cliente.models.generate_content(
    model=MODEL_ID,
    contents=[prompt_resumen]
)
print("\n📝 Resumen:")
print(respuesta.text)

# %%
prompt_clasificación_de_sentimiento = f"""Clasificá el siguiente texto como positivo, negativo o neutral y explicá por qué:

Texto: {texto_ejercicio}"""
respuesta = cliente.models.generate_content(
    model=MODEL_ID,
    contents=[prompt_clasificación_de_sentimiento]
)
print("\n😠 Clasificación de Sentimiento:")
print(respuesta.text)

# %%
prompt_entidades_nombradas = f"""Extraé todas las entidades nombradas del siguiente texto (personas, organizaciones, lugares, objetos, fechas, horarios) y clasificálas:

Texto: {texto_ejercicio}"""
respuesta = cliente.models.generate_content(
    model=MODEL_ID,
    contents=[prompt_entidades_nombradas]
)
print("\n🏷️ Entidades Nombradas:")
print(respuesta.text)
